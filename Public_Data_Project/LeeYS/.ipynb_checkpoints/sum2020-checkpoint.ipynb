# %%
import pandas as pd
import numpy as np
import csv
import	koreanize_matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## 국민연금 가입

# %%
f1 = "국민연금 가입 사업장 내역_202106.csv"
pensionDF = pd.read_csv(f1, encoding="cp949")
# Out:
# C:\Users\kdp\AppData\Local\Temp\ipykernel_22220\3747439663.py:2: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   pensionDF = pd.read_csv(f1, encoding="cp949")

# %%
pensionDF.head()
# Out:
#   자료생성년월(자격마감일(사유발생일이 속하는 달의 다음달 15일)까지 신고분 반영)          사업장명   사업자등록번호  \
# 0                                       2021-05       우성기전(주)    126811
# 1                                       2021-05  서능공원묘지운영회(재)    102820
# 2                                       2021-05       노들새마을금고    108820
# 3                                       2021-05       유창성업(주)    122812
# 4                                       2021-05       희성전자(주)    106810
#
#     사업장가입상태코드 1 등록 2 탈퇴   우편번호       사업장지번상세주소         사업장도로명상세주소   고객법정동주소코드  \
# 0                     1  12816     경기도 광주시 도척면   경기도 광주시 도척면 도척윗로  4161033025
# 1                     1  11191     경기도 포천시 내촌면                     4165032022
# 2                     1  06923  서울특별시 동작구 노량진동      서울특별시 동작구 만양로  1159010100
# 3                     1  22849    인천광역시 서구 오류동      인천광역시 서구 갑문2로  2826011900
# 4                     1  04410   서울특별시 용산구 한남동  서울특별시 용산구 독서당로14길  1117013100
#
#     고객행정동주소코드   법정동주소광역시도코드  ...   사업장형태구분코드 1 법인 2 개인   사업장업종코드  \
# 0  4161033025            41  ...                     1    292201
# 1  4165032022            41  ...                     1    701700
# 2  1159051000            11  ...                     1    659202
# 3  2826072000            28  ...                     1    749604
# 4  1117067000            11  ...                     1    701201
#
#                         사업장업종코드명        적용일자  재등록일자  탈퇴일자  가입자수(고지인원 수 포함)  \
# 0                  동력식 수지 공구 제조업  1988-01-01    NaN   NaN                5
# 1            화장터 운영  묘지 분양 및 관리업  1988-01-01    NaN   NaN               12
# 2                           신용조합  1988-01-01    NaN   NaN               14
# 3  그 외 기타 분류 안된 사업 지원 서비스업(기타임가공  1988-01-01    NaN   NaN               25
# 4           비주거용 건물 임대업(점포  자기땅)  1988-01-01    NaN   NaN              437
#
#    당월고지금액( 국민연금법 시행령 제5조에 의거 기준소득월액 상한액 적용으로 실제소득과 고지금액은 상이할 수 있음  상한액 2019.7.~2020.6. 4860000원(2019.7.1.기준) 상한액 2020.7.~2021.6. 5030000원(2020.7.1.기준) 상한액 2021.7.~2022.6.  5240000원(2021.7.1.기준) )  \
# 0                                             792720
# 1                                            3235900
# 2                                            4794440
# 3                                            5166520
# 4                                          184540080
#
#     신규취득자수(납부재개 포함  전달 고지대상자와 비교하므로 실제 취득자와 상이할 수 있음(초일취득 고지 초일이 아닌경우. 미고지(다음달 취득자수에 반영))  \
# 0                                                  0
# 1                                                  1
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#     상실가입자수(납부예외 포함  전달 고지대상자와 비교하므로 실제 퇴사자와 상이할 수 있음(초일이 아닌 상실자는 다음달 상실자수에 반영) 국민연금법 제6조 8조 동법 시행령 제18조에 의거 60세 도달하거나 퇴직연금수급자 조기노령연금 수급권을 취득한 자는 가입대상에서 제외되며 18세미만 기초수급자는 본인희망에 의해 제외될 수 있음)
# 0                                                  0
# 1                                                  2
# 2                                                  0
# 3                                                  1
# 4                                                  1
#
# [5 rows x 22 columns]

# %%
pensionDF.columns
# Out:
# Index(['자료생성년월(자격마감일(사유발생일이 속하는 달의 다음달 15일)까지 신고분 반영)', ' 사업장명', ' 사업자등록번호',
#        ' 사업장가입상태코드 1 등록 2 탈퇴', ' 우편번호', ' 사업장지번상세주소', ' 사업장도로명상세주소',
#        ' 고객법정동주소코드', ' 고객행정동주소코드', ' 법정동주소광역시도코드', ' 법정동주소광역시시군구코드',
#        ' 법정동주소광역시시군구읍면동코드', ' 사업장형태구분코드 1 법인 2 개인', ' 사업장업종코드', ' 사업장업종코드명',
#        ' 적용일자', ' 재등록일자', ' 탈퇴일자', ' 가입자수(고지인원 수 포함)',
#        ' 당월고지금액( 국민연금법 시행령 제5조에 의거 기준소득월액 상한액 적용으로 실제소득과 고지금액은 상이할 수 있음  상한액 2019.7.~2020.6. 4860000원(2019.7.1.기준) 상한액 2020.7.~2021.6. 5030000원(2020.7.1.기준) 상한액 2021.7.~2022.6.  5240000원(2021.7.1.기준) )',
#        ' 신규취득자수(납부재개 포함  전달 고지대상자와 비교하므로 실제 취득자와 상이할 수 있음(초일취득 고지 초일이 아닌경우. 미고지(다음달 취득자수에 반영))',
#        ' 상실가입자수(납부예외 포함  전달 고지대상자와 비교하므로 실제 퇴사자와 상이할 수 있음(초일이 아닌 상실자는 다음달 상실자수에 반영) 국민연금법 제6조 8조 동법 시행령 제18조에 의거 60세 도달하거나 퇴직연금수급자 조기노령연금 수급권을 취득한 자는 가입대상에서 제외되며 18세미만 기초수급자는 본인희망에 의해 제외될 수 있음)'],
#       dtype='object')

# %% [markdown]
# 사용할 데이터 col을 뽑아보자

# %%
pensionDF = pensionDF[[" 사업장명", " 사업장지번상세주소",' 가입자수(고지인원 수 포함)',' 당월고지금액( 국민연금법 시행령 제5조에 의거 기준소득월액 상한액 적용으로 실제소득과 고지금액은 상이할 수 있음  상한액 2019.7.~2020.6. 4860000원(2019.7.1.기준) 상한액 2020.7.~2021.6. 5030000원(2020.7.1.기준) 상한액 2021.7.~2022.6.  5240000원(2021.7.1.기준) )']]

# %% [markdown]
# "사업장지번상세주소" -> "본사주소"로 변경

# %%
pensionDF.columns = ["사업장명", "본사주소", "가입자수", "당월고지금액"]
pensionDF.columns
# Out:
# Index(['사업장명', '본사주소', '가입자수', '당월고지금액'], dtype='object')

# %% [markdown]
# ### 주소분리

# %%
pensionDF.sort_values("당월고지금액")
# Out:
#                                                  사업장명             본사주소  \
# 386249                                 주식회사바이더엠(학동지점)    서울특별시 강남구 논현동
# 471711                  로드건설주식회사/일용/운곡초등학교내진보강및외벽수선공사     충청남도 청양군 운곡면
# 471714  반도장식산업주식회사-(일용)위례 A3-4a블럭 공동주택 신축사업 도배공사(2공구)      경기도 하남시 학암동
# 471718         금장건설주식회사/상용/국도1호선 나주 매성지구 등 3개소 도로정비공사     전라남도 나주시 공산면
# 187523                                       （주）제이투케이     인천광역시 서구 마전동
# ...                                               ...              ...
# 166280                                     엘지디스플레이(주)  서울특별시 영등포구 여의도동
# 149675                                  에스케이하이닉스 주식회사      경기도 이천시 부발읍
# 14324                                         엘지전자(주)  서울특별시 영등포구 여의도동
# 3357                                         현대자동차(주)    서울특별시 서초구 양재동
# 4586                                          삼성전자(주)  경기도 수원시 영통구 매탄동
#
#           가입자수       당월고지금액
# 386249       0            0
# 471711       0            0
# 471714       0            0
# 471718       0            0
# 187523       0            0
# ...        ...          ...
# 166280   26440  11009314300
# 149675   28291  12420446400
# 14324    40132  17213815200
# 3357     68501  29639369740
# 4586    108331  47499892520
#
# [529221 rows x 4 columns]

# %%
addr = pd.DataFrame(pensionDF["본사주소"])
addr = addr["본사주소"].apply(lambda x : x.split()[:2])
addr =	pd.DataFrame(addr.tolist(), columns=('시도', '군구'))
addr.head()
# Out:
#       시도   군구
# 0    경기도  광주시
# 1    경기도  포천시
# 2  서울특별시  동작구
# 3  인천광역시   서구
# 4  서울특별시  용산구

# %%
pensionDF[["시도", "군구", "나머지 주소"]] = pensionDF["본사주소"].str.split(' ', n=2, expand=True)
pensionDF.head()
# Out:
# C:\Users\kdp\AppData\Local\Temp\ipykernel_22220\995769337.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pensionDF[["시도", "군구", "나머지 주소"]] = pensionDF["본사주소"].str.split(' ', n=2, expand=True)
# C:\Users\kdp\AppData\Local\Temp\ipykernel_22220\995769337.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pensionDF[["시도", "군구", "나머지 주소"]] = pensionDF["본사주소"].str.split(' ', n=2, expand=True)
# C:\Users\kdp\AppData\Local\Temp\ipykernel_22220\995769337.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pensionDF[["시도", "군구", "나머지 주소"]] = pensionDF["본사주소"].str.split(' ', n=2, expand=True)
#            사업장명            본사주소  가입자수     당월고지금액     시도   군구 나머지 주소
# 0       우성기전(주)     경기도 광주시 도척면     5     792720    경기도  광주시    도척면
# 1  서능공원묘지운영회(재)     경기도 포천시 내촌면    12    3235900    경기도  포천시    내촌면
# 2       노들새마을금고  서울특별시 동작구 노량진동    14    4794440  서울특별시  동작구   노량진동
# 3       유창성업(주)    인천광역시 서구 오류동    25    5166520  인천광역시   서구    오류동
# 4       희성전자(주)   서울특별시 용산구 한남동   437  184540080  서울특별시  용산구    한남동

# %%
pensionDF = pensionDF.drop("본사주소", axis = True)

# %%
pensionDF["시도"].unique()
# Out:
# array(['경기도', '서울특별시', '인천광역시', '전라북도', '충청남도', '충청북도', '강원도', '부산광역시',
#        '전라남도', '울산광역시', '경상북도', '세종특별자치시', '대구광역시', '경상남도', '제주특별자치도',
#        '대전광역시', '광주광역시', ''], dtype=object)

# %%
pensionDF[pensionDF["시도"] == ""]
# Out:
#                  사업장명  가입자수   당월고지금액 시도 군구 나머지 주소
# 3921        (주)우일씨엔에스    14  4333460
# 4376            (주)성우    18  4754840
# 6987         (주) 이오니아    25  5444320
# 10060        주식회사광백건설     8  2187160
# 16607         주식회사 대웅     3   989000
# ...               ...   ...      ... .. ..    ...
# 307839       은혜교통주식회사     4   765540
# 308163     주식회사건우종합건설    14  4532300
# 312446  주식회사자라다교육부천지점     5   969720
# 312804      행복가정폭력상담소     5   928860
# 314167      시스템안전주식회사    19  5393460
#
# [182 rows x 6 columns]

# %% [markdown]
# ## <hr>SW 기업 DF뽑기

# %%
f2 = "사업자정보_20211031기준.csv"
swDF = pd.read_csv(f2, encoding="cp949")

# %%
swDF
# Out:
#                        회사명     대표이사                        홈페이지  \
# 0                (주)라이드소프트      강태훈     http://www.rydesoft.com
# 1                   (주)코제코      문시환  http://www.pressblog.co.kr
# 2                (주)시코에프에이      김관중       http://www.sico.so.kr
# 3      하니웰에어포트시스템즈게엠베하한국지점  귄테르쉬펜회펠                     http://
# 4                지하정보기술(주)      김창동                     http://
# ...                    ...      ...                         ...
# 49205            주식회사 더코스넷      방상훈                     http://
# 49206             디에이치정보기술      김단현                     http://
# 49207           주식회사 이아이에스      조성철       http://www.eiss.co.kr
# 49208            콘소프트 주식회사      이상국       http://cornsoft.co.kr
# 49209            (주)지우정보통신      조경순                     http://
#
#                                                 본사주소  재무현황연도
# 0              경기도 성남시 수정구 탄리로 57, 성남벤처빌딩 207호 (수진동)    2009
# 1                        서울 서초구 반포대로 90(서초동, 세환빌딩5층)    2011
# 2               서울특별시 금천구 가산디지털2로 114, 3층 302호 (가산동)    2009
# 3                인천광역시 중구 공항동로295번길 124, 신불2단지 (운서동)    2009
# 4          경기도 의왕시 이미로 40, 디동 디 609호 (포일동, 인덕원아이티밸리)    2019
# ...                                              ...     ...
# 49205     서울특별시 금천구 가산디지털2로 46, 309호 (가산동, 에이스태세라타워)    2020
# 49206  제주특별자치도 제주시 매촌2길 71, 103동501호 (도련일동, 아름아이빌8차)    2020
# 49207      대전광역시 유성구 가정북로 156, 8동 207호 (장동, 한국기계연구원)    2020
# 49208          경기도 의정부시 시민로 29, 205호 (의정부동, 제일퍼스트빌3)    2020
# 49209        충청남도 홍성군 홍북읍 충남대로 36, 5층 520호(빌앤더스오피스텔)    2020
#
# [49210 rows x 5 columns]

# %%
swDF.columns
# Out:
# Index(['회사명', '대표이사', '홈페이지', '본사주소', '재무현황연도'], dtype='object')

# %%
swDF = swDF[["회사명", "본사주소"]]
swDF.head()
# Out:
#                    회사명                                       본사주소
# 0            (주)라이드소프트      경기도 성남시 수정구 탄리로 57, 성남벤처빌딩 207호 (수진동)
# 1               (주)코제코                서울 서초구 반포대로 90(서초동, 세환빌딩5층)
# 2            (주)시코에프에이       서울특별시 금천구 가산디지털2로 114, 3층 302호 (가산동)
# 3  하니웰에어포트시스템즈게엠베하한국지점        인천광역시 중구 공항동로295번길 124, 신불2단지 (운서동)
# 4            지하정보기술(주)  경기도 의왕시 이미로 40, 디동 디 609호 (포일동, 인덕원아이티밸리)

# %% [markdown]
# 회사명 -> 사업장명으로 변경

# %%
swDF.columns = ["사업장명", "본사주소"]
swDF.head()
# f.reindex(columns=['http_status', 'user_agent'])
# Out:
#                   사업장명                                       본사주소
# 0            (주)라이드소프트      경기도 성남시 수정구 탄리로 57, 성남벤처빌딩 207호 (수진동)
# 1               (주)코제코                서울 서초구 반포대로 90(서초동, 세환빌딩5층)
# 2            (주)시코에프에이       서울특별시 금천구 가산디지털2로 114, 3층 302호 (가산동)
# 3  하니웰에어포트시스템즈게엠베하한국지점        인천광역시 중구 공항동로295번길 124, 신불2단지 (운서동)
# 4            지하정보기술(주)  경기도 의왕시 이미로 40, 디동 디 609호 (포일동, 인덕원아이티밸리)

# %%
swDF[["시도", "군구", "나머지 주소"]] = swDF["본사주소"].str.split(' ', n=2, expand=True)
swDF.head()
# Out:
# C:\Users\kdp\AppData\Local\Temp\ipykernel_22220\1661869292.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   swDF[["시도", "군구", "나머지 주소"]] = swDF["본사주소"].str.split(' ', n=2, expand=True)
# C:\Users\kdp\AppData\Local\Temp\ipykernel_22220\1661869292.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   swDF[["시도", "군구", "나머지 주소"]] = swDF["본사주소"].str.split(' ', n=2, expand=True)
#                   사업장명                                       본사주소     시도   군구  \
# 0            (주)라이드소프트      경기도 성남시 수정구 탄리로 57, 성남벤처빌딩 207호 (수진동)    경기도  성남시
# 1               (주)코제코                서울 서초구 반포대로 90(서초동, 세환빌딩5층)     서울  서초구
# 2            (주)시코에프에이       서울특별시 금천구 가산디지털2로 114, 3층 302호 (가산동)  서울특별시  금천구
# 3  하니웰에어포트시스템즈게엠베하한국지점        인천광역시 중구 공항동로295번길 124, 신불2단지 (운서동)  인천광역시   중구
# 4            지하정보기술(주)  경기도 의왕시 이미로 40, 디동 디 609호 (포일동, 인덕원아이티밸리)    경기도  의왕시
#
#                               나머지 주소
# 0      수정구 탄리로 57, 성남벤처빌딩 207호 (수진동)
# 1               반포대로 90(서초동, 세환빌딩5층)
# 2         가산디지털2로 114, 3층 302호 (가산동)
# 3         공항동로295번길 124, 신불2단지 (운서동)
# 4  이미로 40, 디동 디 609호 (포일동, 인덕원아이티밸리)

# %%
swDF = swDF.drop("본사주소", axis=True)

# %%
swDF["시도"].unique()
# Out:
# array(['경기도', '서울', '서울특별시', '인천광역시', '대구', '경상북도', '전라북도', '대전광역시',
#        '대구광역시', '충청북도', '부산광역시', '전라남도', '제주특별자치도', '강원도', '충청남도', '경상남도',
#        '광주광역시', '경북', '경기', '인천', '충남', '대전', '울산광역시', '전북', '세종특별자치시',
#        '충북', '제주', '서울시', '광주', '강원', '부산', '울산', '전남', '울산시', '인천시중구',
#        '부산시', '서울특별', '서울특별시시', '제주시', '대구시', '대전시', '충북청주기청원구토성로362번길',
#        '경남', '인천광역시동구', '인천시', '광주시'], dtype=object)

# %%
addr_aliases =	{'서울':'서울특별시', '대구':'대구광역시', "대구시":"대구광역시",'경북':'경상북도',	'인천':'인천광역시',	
'경기':'경기도',	'충남':'충청남도', '대전':'대전광역시', '전북':'전북특별자치도', "전라북도":"전북특별자치도",	
'충북':'충청북도', '제주':'제주특별자치도', "서울시":"서울특별시", "광주":"광주광역시", "강원":"강원특별자치도", "부산":"부산광역시", "울산":"울산광역시", "전남":"전라남도", "울산시":"울산광역시", "인천시중구":"인천광역시",
"부산시":"부산광역시", "서울특별":"서울특별시", "서울특별시시":"서울특별시", "제주시":"제주특별자치도", "경남":"경상남도", "대구":"대구광역시", "대전시":"대전광역시", "충북청주기청원구토성로362번길":"충청북도", "인천광역시동구":"인천광역시",
"인천시":"인천광역시", "광주시":"광주광역시", "강원도":"강원특별자치도"}

# %%
swDF['시도'] = swDF['시도'].apply(lambda	v: addr_aliases.get(v, v))

# %%
swDF["시도"].unique()
# Out:
# array(['경기도', '서울특별시', '인천광역시', '대구광역시', '경상북도', '전북특별자치도', '대전광역시',
#        '충청북도', '부산광역시', '전라남도', '제주특별자치도', '강원특별자치도', '충청남도', '경상남도',
#        '광주광역시', '울산광역시', '세종특별자치시'], dtype=object)

# %% [markdown]
# ## join 사업장명을 기준으로
# - swDF->본사만
# - pensionDF->지사포함

# %%
mergeDF = pd.merge(swDF, pensionDF, on=["사업장명"])
mergeDF.head()
# Out:
#         사업장명   시도_x 군구_x                           나머지 주소_x  가입자수    당월고지금액  \
# 0  (주)시코에프에이  서울특별시  금천구         가산디지털2로 114, 3층 302호 (가산동)    13   4529480
# 1  지하정보기술(주)    경기도  의왕시  이미로 40, 디동 디 609호 (포일동, 인덕원아이티밸리)    14   4220940
# 2      (주)문교  대구광역시  달서구               본동 831 씨티아이디어허브 201호     4    962980
# 3     (주)베스텍    경기도  포천시                        화현면 문암동길 33    34  10957600
# 4     (주)베스텍    경기도  포천시                        화현면 문암동길 33     9   2874140
#
#     시도_y 군구_y 나머지 주소_y
# 0  서울특별시  금천구      가산동
# 1    경기도  의왕시      포일동
# 2   경상남도  김해시      한림면
# 3    경기도  포천시      화현면
# 4   충청남도  아산시      둔포면

# %%
mergeDF['시도_y'] = np.where(mergeDF['시도_y']==" ", mergeDF['시도_y'], mergeDF['시도_x'])
mergeDF["시도_y"].value_counts()
# Out:
# 서울특별시      5645
# 경기도        3321
# 대전광역시       780
# 부산광역시       680
# 전라남도        653
# 경상북도        623
# 강원특별자치도     577
# 대구광역시       534
# 경상남도        524
# 인천광역시       500
# 충청남도        438
# 충청북도        437
# 전북특별자치도     424
# 광주광역시       387
# 울산광역시       206
# 제주특별자치도     190
# 세종특별자치시     144
# Name: 시도_y, dtype: int64

# %%
mergeDF["사업장명"].value_counts() # 대부분이 지사임
# Out:
# 대신네트웍스(주)      126
# 대신네트웍스주식회사      45
# 대한민국고엽제전우회      36
# (주)한성엔지니어링      20
# 주식회사 서진         18
#               ...
# 해솔정보통신 주식회사      1
# 주식회사 안랩          1
# (유)지원통신          1
# 제오스페이스(주)        1
# (주)지우정보통신        1
# Name: 사업장명, Length: 12235, dtype: int64

# %%
mergeDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16063 entries, 0 to 16062
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   사업장명      16063 non-null  object
#  1   시도_x      16063 non-null  object
#  2   군구_x      16063 non-null  object
#  3   나머지 주소_x  16062 non-null  object
#  4   가입자수      16063 non-null  int64
#  5   당월고지금액    16063 non-null  int64
#  6   시도_y      16063 non-null  object
#  7   군구_y      16063 non-null  object
#  8   나머지 주소_y  16063 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 1.2+ MB

# %%
a = ['경기도', '서울특별시', '인천광역시', '대구광역시', '경상북도', '전북특별자치도', '대전광역시',
       '충청북도', '부산광역시', '전라남도', '제주특별자치도', '강원특별자치도', '충청남도', '경상남도',
       '광주광역시', '울산광역시', '세종특별자치시'] # swDF

b = ['충청남도', '서울특별시', '경기도', '인천광역시', '충청북도', '강원특별자치도', '부산광역시',
       '전라남도', '울산광역시', '전북특별자치도', '경상북도', '세종특별자치시', '대구광역시', '경상남도', '',
       '제주특별자치도', '대전광역시', '광주광역시'] # pensionDF

# %%
set(a) - set(b)
# Out:
# set()

# %%
mergeDF2 = mergeDF.drop(["시도_x", "군구_x", "나머지 주소_x"],axis = True)
mergeDF2
# Out:
#                 사업장명  가입자수    당월고지금액   시도_y 군구_y  나머지 주소_y
# 0          (주)시코에프에이    13   4529480  서울특별시  금천구       가산동
# 1          지하정보기술(주)    14   4220940    경기도  의왕시       포일동
# 2              (주)문교     4    962980  대구광역시  김해시       한림면
# 3             (주)베스텍    34  10957600    경기도  포천시       화현면
# 4             (주)베스텍     9   2874140    경기도  아산시       둔포면
# ...              ...   ...       ...    ...  ...       ...
# 16058  주식회사 지에스에프시스템    19   5097220   경상남도  창원시   의창구 두대동
# 16059       유원에스피(주)    15   4788340    경기도  부천시       삼정동
# 16060        커뮤니크(주)    89  22273040  서울특별시  용산구     한강로2가
# 16061       주식회사 다코스    20   3740160  서울특별시  은평구       신사동
# 16062      (주)지우정보통신     4    655920   충청남도  홍성군       홍북읍
#
# [16063 rows x 6 columns]

# %%
mergeDF2.sort_values("당월고지금액")
mergeDF2.columns = ["사업장명", "가입자수", "당월고지금액", "시도", "군구", "나머지 주소"]
mergeDF2.head()
# Out:
#         사업장명  가입자수    당월고지금액     시도   군구 나머지 주소
# 0  (주)시코에프에이    13   4529480  서울특별시  금천구    가산동
# 1  지하정보기술(주)    14   4220940    경기도  의왕시    포일동
# 2      (주)문교     4    962980  대구광역시  김해시    한림면
# 3     (주)베스텍    34  10957600    경기도  포천시    화현면
# 4     (주)베스텍     9   2874140    경기도  아산시    둔포면

# %%
col_list = mergeDF2["시도"].unique()
for col in col_list:
    print(f"================{col}================")
    print(mergeDF2[mergeDF2["시도"]==col].sort_values("당월고지금액", ascending=False).head(3)["사업장명"])
# Out:
# ================서울특별시================
# 5252       엘지전자(주)
# 5789    삼성에스디에스(주)
# 2863      현대모비스(주)
# Name: 사업장명, dtype: object
# ================경기도================
# 4681     삼성전자(주)
# 4558    주식회사 케이티
# 6806     한국농어촌공사
# Name: 사업장명, dtype: object
# ================대구광역시================
# 11079    에스엘 주식회사
# 12444       (주)영일
# 11467       (주)디오
# Name: 사업장명, dtype: object
# ================경상남도================
# 13491    두산중공업(주)
# 6966      현대위아(주)
# 3720      영풍전자(주)
# Name: 사업장명, dtype: object
# ================충청북도================
# 15288        (주)네패스
# 12814     주식회사 씨앤에스
# 7230     충북대학교산학협력단
# Name: 사업장명, dtype: object
# ================대전광역시================
# 8167      한국수자원공사
# 7934    (주)케이티씨에스
# 65      한국전자통신연구원
# Name: 사업장명, dtype: object
# ================강원특별자치도================
# 6321     (주)더존비즈온
# 5658        (주)서흥
# 2148    (주)한국고용정보
# Name: 사업장명, dtype: object
# ================경상북도================
# 4512      (주)포스코건설
# 5061     한국전력기술(주)
# 6401    (주)포스코아이씨티
# Name: 사업장명, dtype: object
# ================전북특별자치도================
# 6410       (주)올포랜드
# 1923     대우전자부품(주)
# 10409    주식회사아이엠아이
# Name: 사업장명, dtype: object
# ================제주특별자치도================
# 6971      (주)넥슨네트웍스
# 7407         (주)피앤피
# 7208    (주)KCTV제주방송
# Name: 사업장명, dtype: object
# ================광주광역시================
# 7890     대신정보통신(주)
# 11812      화천기공(주)
# 15213       한국광기술원
# Name: 사업장명, dtype: object
# ================울산광역시================
# 5948       현대중공업주식회사
# 8705     주식회사 수산이앤에스
# 11156      금양산업개발(주)
# Name: 사업장명, dtype: object
# ================인천광역시================
# 13753    인천공항시설관리 주식회사
# 4563             (주)심텍
# 2428        (주)지에스네트웍스
# Name: 사업장명, dtype: object
# ================전라남도================
# 4802       한전케이디엔(주)
# 5889    (주)하이테크엔지니어링
# 4247        (주)미래씨엔씨
# Name: 사업장명, dtype: object
# ================부산광역시================
# 10446       (주)휴넥트
# 2763       극동건설(주)
# 3415     대양전기공업(주)
# Name: 사업장명, dtype: object
# ================충청남도================
# 9139      하나마이크론(주)
# 14837      한국자동차연구원
# 7637     (주)경동엔지니어링
# Name: 사업장명, dtype: object
# ================세종특별자치시================
# 15803      국토연구원
# 1342     (주)이레테크
# 10191      (주)지이
# Name: 사업장명, dtype: object

# %%
#mergeDF2[mergeDF2["시도"]==col].sort_values("당월고지금액", ascending=False).head(3)["사업장명"]
col_list
# Out:
# array(['서울특별시', '경기도', '대구광역시', '경상남도', '충청북도', '대전광역시', '강원특별자치도',
#        '경상북도', '전북특별자치도', '제주특별자치도', '광주광역시', '울산광역시', '인천광역시', '전라남도',
#        '부산광역시', '충청남도', '세종특별자치시'], dtype=object)

# %% [markdown]
# ## <hr>Group Area

# %%
group_area = mergeDF2.groupby(["시도"]).sum()
group_area.head()
# Out:
# C:\Users\kdp\AppData\Local\Temp\ipykernel_22220\1388286200.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_area = mergeDF2.groupby(["시도"]).sum()
#            가입자수       당월고지금액
# 시도
# 강원특별자치도   12205   3270325580
# 경기도      240508  90857521640
# 경상남도      19920   6762315660
# 경상북도      22218   7590543540
# 광주광역시      7486   1912187940

# %%
group_area["div"] = group_area["당월고지금액"] / group_area["가입자수"]

# %%
group_area = group_area.sort_values("div", ascending=False)
group_area
# Out:
#            가입자수        당월고지금액            div
# 시도
# 울산광역시     16413    6346270460  386661.211235
# 경기도      240508   90857521640  377773.386499
# 경상북도      22218    7590543540  341639.370780
# 경상남도      19920    6762315660  339473.677711
# 서울특별시    402559  133702083620  332130.404785
# 대전광역시     32549    9638478920  296122.121110
# 인천광역시     18807    5486402360  291721.293136
# 충청남도       8904    2502092420  281007.684187
# 전라남도      12920    3550253520  274787.424149
# 부산광역시     14349    3873915560  269978.086278
# 강원특별자치도   12205    3270325580  267949.658337
# 대구광역시      9948    2634790900  264856.342984
# 세종특별자치시    1785     469509060  263030.285714
# 제주특별자치도    3392     889341820  262188.036557
# 충청북도       7316    1885558920  257730.852925
# 광주광역시      7486    1912187940  255435.204382
# 전북특별자치도    6180    1519564700  245884.255663

# %%
col_list = group_area.index.to_list() # 순위대로 
company = []
color = []
for col in col_list:
    print(f"================{col}================")
    print(mergeDF2[mergeDF2["시도"]==col].sort_values("당월고지금액", ascending=False).head(3)["사업장명"])
    sr = mergeDF2[mergeDF2["시도"]==col].sort_values("당월고지금액", ascending=False).head(1)["사업장명"]
    if "광역시" in col:
        color.append("red")
    else:
        color.append("gray")
    company += sr.to_list()
    print(f"company = {company}")
# Out:
# ================울산광역시================
# 5948       현대중공업주식회사
# 8705     주식회사 수산이앤에스
# 11156      금양산업개발(주)
# Name: 사업장명, dtype: object
# company = ['현대중공업주식회사']
# ================경기도================
# 4681     삼성전자(주)
# 4558    주식회사 케이티
# 6806     한국농어촌공사
# Name: 사업장명, dtype: object
# company = ['현대중공업주식회사', '삼성전자(주)']
# ================경상북도================
# 4512      (주)포스코건설
# 5061     한국전력기술(주)
# 6401    (주)포스코아이씨티
# Name: 사업장명, dtype: object
# company = ['현대중공업주식회사', '삼성전자(주)', '(주)포스코건설']
# ================경상남도================
# 13491    두산중공업(주)
# 6966      현대위아(주)
# 3720      영풍전자(주)
# Name: 사업장명, dtype: object
# company = ['현대중공업주식회사', '삼성전자(주)', '(주)포스코건설', '두산중공업(주)']
# ================서울특별시================
# 5252       엘지전자(주)
# 5789    삼성에스디에스(주)
# 2863      현대모비스(주)
# Name: 사업장명, dtype: object
# company = ['현대중공업주식회사', '삼성전자(주)', '(주)포스코건설', '두산중공업(주)', '엘지전자(주)']
# ================대전광역시================
# 8167      한국수자원공사
# 7934    (주)케이티씨에스
# 65      한국전자통신연구원
# Name: 사업장명, dtype: object
# company = ['현대중공업주식회사', '삼성전자(주)', '(주)포스코건설', '두산중공업(주)', '엘지전자(주)', '한국수자원공사']
# ================인천광역시================
# 13753    인천공항시설관리 주식회사
# 4563             (주)심텍
# 2428        (주)지에스네트웍스
# Name: 사업장명, dtype: object
# company = ['현대중공업주식회사', '삼성전자(주)', '(주)포스코건설', '두산중공업(주)', '엘지전자(주)', '한국수자원공사', '인천공항시설관리 주식회사']
# ================충청남도================
# 9139      하나마이크론(주)
# 14837      한국자동차연구원
# 7637     (주)경동엔지니어링
# Name: 사업장명, dtype: object
# company = ['현대중공업주식회사', '삼성전자(주)', '(주)포스코건설', '두산중공업(주)', '엘지전자(주)', '한국수자원공사', '인천공항시설관리 주식회사', '하나마이크론(주)']
# ================전라남도================
# 4802       한전케이디엔(주)
# 5889    (주)하이테크엔지니어링
# 4247        (주)미래씨엔씨
# Name: 사업장명, dtype: object
# company = ['현대중공업주식회사', '삼성전자(주)', '(주)포스코건설', '두산중공업(주)', '엘지전자(주)', '한국수자원공사', '인천공항시설관리 주식회사', '하나마이크론(주)', '한전케이디엔(주)']
# ================부산광역시================
# 10446       (주)휴넥트
# 2763       극동건설(주)
# 3415     대양전기공업(주)
# Name: 사업장명, dtype: object
# company = ['현대중공업주식회사', '삼성전자(주)', '(주)포스코건설', '두산중공업(주)', '엘지전자(주)', '한국수자원공사', '인천공항시설관리 주식회사', '하나마이크론(주)', '한전케이디엔(주)', '(주)휴넥트']
# ================강원특별자치도================
# 6321     (주)더존비즈온
# 5658        (주)서흥
# 2148    (주)한국고용정보
# Name: 사업장명, dtype: object
# company = ['현대중공업주식회사', '삼성전자(주)', '(주)포스코건설', '두산중공업(주)', '엘지전자(주)', '한국수자원공사', '인천공항시설관리 주식회사', '하나마이크론(주)', '한전케이디엔(주)', '(주)휴넥트', '(주)더존비즈온']
# ================대구광역시================
# 11079    에스엘 주식회사
# 12444       (주)영일
# 11467       (주)디오
# Name: 사업장명, dtype: object
# company = ['현대중공업주식회사', '삼성전자(주)', '(주)포스코건설', '두산중공업(주)', '엘지전자(주)', '한국수자원공사', '인천공항시설관리 주식회사', '하나마이크론(주)', '한전케이디엔(주)', '(주)휴넥트', '(주)더존비즈온', '에스엘 주식회사']
# ================세종특별자치시================
# 15803      국토연구원
# 1342     (주)이레테크
# 10191      (주)지이
# Name: 사업장명, dtype: object
# company = ['현대중공업주식회사', '삼성전자(주)', '(주)포스코건설', '두산중공업(주)', '엘지전자(주)', '한국수자원공사', '인천공항시설관리 주식회사', '하나마이크론(주)', '한전케이디엔(주)', '(주)휴넥트', '(주)더존비즈온', '에스엘 주식회사', '국토연구원']
# ================제주특별자치도================
# 6971      (주)넥슨네트웍스
# 7407         (주)피앤피
# 7208    (주)KCTV제주방송
# Name: 사업장명, dtype: object
# company = ['현대중공업주식회사', '삼성전자(주)', '(주)포스코건설', '두산중공업(주)', '엘지전자(주)', '한국수자원공사', '인천공항시설관리 주식회사', '하나마이크론(주)', '한전케이디엔(주)', '(주)휴넥트', '(주)더존비즈온', '에스엘 주식회사', '국토연구원', '(주)넥슨네트웍스']
# ================충청북도================
# 15288        (주)네패스
# 12814     주식회사 씨앤에스
# 7230     충북대학교산학협력단
# Name: 사업장명, dtype: object
# company = ['현대중공업주식회사', '삼성전자(주)', '(주)포스코건설', '두산중공업(주)', '엘지전자(주)', '한국수자원공사', '인천공항시설관리 주식회사', '하나마이크론(주)', '한전케이디엔(주)', '(주)휴넥트', '(주)더존비즈온', '에스엘 주식회사', '국토연구원', '(주)넥슨네트웍스', '(주)네패스']
# ================광주광역시================
# 7890     대신정보통신(주)
# 11812      화천기공(주)
# 15213       한국광기술원
# Name: 사업장명, dtype: object
# company = ['현대중공업주식회사', '삼성전자(주)', '(주)포스코건설', '두산중공업(주)', '엘지전자(주)', '한국수자원공사', '인천공항시설관리 주식회사', '하나마이크론(주)', '한전케이디엔(주)', '(주)휴넥트', '(주)더존비즈온', '에스엘 주식회사', '국토연구원', '(주)넥슨네트웍스', '(주)네패스', '대신정보통신(주)']
# ================전북특별자치도================
# 6410       (주)올포랜드
# 1923     대우전자부품(주)
# 10409    주식회사아이엠아이
# Name: 사업장명, dtype: object
# company = ['현대중공업주식회사', '삼성전자(주)', '(주)포스코건설', '두산중공업(주)', '엘지전자(주)', '한국수자원공사', '인천공항시설관리 주식회사', '하나마이크론(주)', '한전케이디엔(주)', '(주)휴넥트', '(주)더존비즈온', '에스엘 주식회사', '국토연구원', '(주)넥슨네트웍스', '(주)네패스', '대신정보통신(주)', '(주)올포랜드']

# %%
avg = group_area["div"].mean()
plt.figure(figsize=(20, 10))

x = group_area.index.to_list()
y = group_area["div"].to_list()

plt.plot(x, [avg]*len(x), "k--")
bar = plt.bar(x, y, color = color)


plt.xticks(rotation=70)
plt.ylim(220000, 450000)
plt.rc('xtick', labelsize=15)
plt.rc('ytick', labelsize=15)

idx = 0

plt.title("2021년 기준 SW 기업 기준", fontsize = "30")
# 숫자 넣는 부분
for rect in bar:
    height = rect.get_height()
    if idx < 9:
        plt.text(rect.get_x() + rect.get_width()/2.0, height, company[idx], ha='center', va='top', size = 15, rotation=90)
    else:
        plt.text(rect.get_x() + rect.get_width()/2.0, height, company[idx], ha='center', va='bottom', size = 15, rotation=90)
    idx += 1

plt.text(rect.get_x() + rect.get_width()/2.0, avg, f"평균:{round(avg)}", ha='center', va='bottom', size = 15)

plt.show()

# %%
company
# Out:
# ['삼성전자(주)',
#  '현대중공업주식회사',
#  '(주)포스코건설',
#  '엘지전자(주)',
#  '5',
#  '6',
#  '7',
#  '8',
#  '9',
#  '10',
#  '11',
#  '12',
#  '(주)넥슨네트웍스',
#  '14',
#  '15',
#  '16',
#  '17']

# %%
plt.figure(figsize=(20, 10))
x = group_area.index.to_list()
y = group_area["div"].to_list()
bar = plt.bar(x, y, color = 'pink')
plt.xticks(rotation=70)
# plt.ylim(280000, 350000)
plt.rc('xtick', labelsize=20)

company = ["삼성전자(주)", "현대중공업주식회사", "(주)포스코건설", "엘지전자(주)", "5", "6", "7", "8", "9", "10", "11", "12", "(주)넥슨네트웍스", "14", "15", "16", "17"]
idx = 0
# 숫자 넣는 부분
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, company[idx], ha='center', va='bottom', size = 12)
    idx += 1
