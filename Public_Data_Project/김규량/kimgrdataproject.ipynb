# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import platform
import koreanize_matplotlib

# %%
data2023 = '국민연금공단_국민연금 가입 사업장 내역_20240119.csv'
data2019 = '국민연금 가입 사업장 내역 2019년 12월.csv'
data2015 = '국민연금 가입 사업장 내역 2015년 12월.csv'

# %%
DF2023=pd.read_csv(data2023)
DF2023
# Out:
#                                                      사업장명        사업장지번상세주소  \
# 0                                               (주)니프코코리아     충청남도 아산시 둔포면
# 1                                                 신일기업(주)   서울특별시 중구 충무로2가
# 2                                                디에스디엘(주)  서울특별시 중구 남대문로4가
# 3                                                  (주)헤럴드    서울특별시 용산구 후암동
# 4                                                 연합뉴스(주)    서울특별시 종로구 수송동
# ...                                                   ...              ...
# 536597             유한회사우전-(일용)2023년 상습결빙구간 자동염수분사장치 설치 공사    광주광역시 광산구 우산동
# 536598  우주종합건설（주）/일용/당진 현대제철 코크스 CDQ 신설 토건공사(21) 중 건축공사(3     충청남도 당진시 송산면
# 536599                 (주)제이원기술/일용/아미동 오피스텔 신축공사 중 기계설비공사   부산광역시 서구 아미동2가
# 536600   유니넷텍(주)-(일용)2023년 구리수택동 수택지역주택조합 재건축 수탁 선로공사(총액)      경기도 구리시 수택동
# 536601  주식회사성보기전-일용-9Block TL장 Rigid 제품 전용 출하 설비 설치 공사...     울산광역시 남구 고사동
#
#                      사업장업종코드명  가입자수     당월고지금액  신규취득자수  상실가입자수
# ...

# %%
DF2019=pd.read_csv(data2019)
DF2019
# Out:
#                                                      사업장명           사업장지번상세주소  \
# 0                                                   (유)삼송       서울특별시 서초구 양재동
# 1                                                   (주)장성     경기도 성남시 분당구 야탑동
# 2                                        특수법인 총포 화약안전기술협회       서울특별시 마포구 용강동
# 3                                                서울명지초등학교      서울특별시 서대문구 홍은동
# 4                                               삼양건설산업(주)       서울특별시 서초구 양재동
# ...                                                   ...                 ...
# 509113        주식회사성보건설/(일용)화북2동4999-5번지다가구주택신축공사중철근콘크리트공사     제주특별자치도 제주시 도남동
# 509114                    (주)태성기술개발/일용/담양군 신계정수장 침전지 개선사업        전라남도 담양군 월산면
# 509115                   (주)유상전설-(상용)영등포여고 학생공간 재구조화 전기공사      서울특별시 영등포구 신길동
# 509116  성마기업　주식회사-(일용)LGE창원1공장 선진화 프로젝트(통합생산동 기계설비공사 2공구)  경상남도 창원시  성산구 가음정동
# 509117      연합건설산업（주）-(상용)국도36호선 공주 우성 신풍리 지내 현광방지시설 정비공사        충청남도 공주시 우성면
#
# ...

# %%
DF2015=pd.read_csv(data2015)
DF2015
# Out:
#                                   사업장명        사업장지번상세주소  \
# 0                            대신정보통신(주)    서울특별시 금천구 가산동
# 1                           한성인터내쇼날(주)     인천광역시 서구 가좌동
# 2                              세종실업(주)    서울특별시 강남구 일원동
# 3                                (주)경농    서울특별시 서초구 서초동
# 4                                윔텍(주)  경기도 안양시 만안구 안양동
# ...                                ...              ...
# 427299   주)거명전력/대구제일고등학교 조리장개조 및기타전기공사     대구광역시 서구 비산동
# 427300  성민종합건설(주)/일용/신흑동2305-3숙박시설신축공사     충청남도 보령시 신흑동
# 427301             대아티아이주식회사 성남 여주(일용)      경기도 이천시 부발읍
# 427302     시재건설（주）-(일용)미8군 사령부 건설공사 포장      경기도 평택시 팽성읍
# 427303       (주)디에이치전설-일용-서산대산지구한성신축공사     충청남도 서산시 대산읍
#
#                       사업장업종코드명  가입자수     당월고지금액  신규취득자수  상실가입자수
# 0            응용 소프트웨어 개발 및 공급업   351  100787140       7      14
# 1                    상품 종합 도매업     6    1349980       0       0
# 2                 시설물 유지관리 공사업     4     833100       0       0
# ...

# %%
DF2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536602 entries, 0 to 536601
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   사업장명       536602 non-null  object
#  1   사업장지번상세주소  536602 non-null  object
#  2   사업장업종코드명   527720 non-null  object
#  3   가입자수       536602 non-null  int64
#  4   당월고지금액     536602 non-null  int64
#  5   신규취득자수     536602 non-null  int64
#  6   상실가입자수     536602 non-null  int64
# dtypes: int64(4), object(3)
# memory usage: 28.7+ MB

# %%
DF2023['사업장업종코드명'] = DF2023['사업장업종코드명'].astype('category')
DF2023['사업장업종코드명']
# Out:
# 0             포장용 플라스틱 성형용기 제조업
# 1                           NaN
# 2          비주거용 건물 임대업(점포  자기땅)
# 3               잡지 및 정기 간행물 발행업
# 4               잡지 및 정기 간행물 발행업
#                   ...
# 536597            배관 및 냉ㆍ난방 공사업
# 536598    사무ㆍ상업용 및 공공기관용 건물 건설업
# 536599                 소방시설 공사업
# 536600            기타 엔지니어링 서비스업
# 536601                일반 전기 공사업
# Name: 사업장업종코드명, Length: 536602, dtype: category
# Categories (1214, object): ['1차 금속제품 도매업', '1차 유리제품  유리섬유 및 광학용 유리 제조업', 'BIZ_NO미존재사업장', 'SNS마켓', ..., '화훼작물 재배업', '환경 관련 엔지니어링 서비스업', '환경설비 건설업', '휴양 콘도 운영업']

# %%
DF2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536602 entries, 0 to 536601
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   사업장명       536602 non-null  object
#  1   사업장지번상세주소  536602 non-null  object
#  2   사업장업종코드명   527720 non-null  category
#  3   가입자수       536602 non-null  int64
#  4   당월고지금액     536602 non-null  int64
#  5   신규취득자수     536602 non-null  int64
#  6   상실가입자수     536602 non-null  int64
# dtypes: category(1), int64(4), object(2)
# memory usage: 25.6+ MB

# %%
DF2023.nunique()
# Out:
# 사업장명         500012
# 사업장지번상세주소      4944
# 사업장업종코드명       1214
# 가입자수           1549
# 당월고지금액       213531
# 신규취득자수          215
# 상실가입자수          270
# dtype: int64

# %%
DF2023['사업장업종코드명'].value_counts()
# Out:
# 사업장업종코드명
# BIZ_NO미존재사업장            71080
# 배관 및 냉ㆍ난방 공사업           16765
# 응용 소프트웨어 개발 및 공급업       14374
# 유리 및 창호 공사업             10710
# 비주거용 건물 임대업(점포  자기땅)    10273
#                         ...
# 다단계판매원의후원수당                 1
# 노점 및 유사 이동 소매업              1
# 사적지 관리 운영업                  1
# 항구 및 기타 해상 터미널 운영업          1
# 재생 섬유 제조업                   1
# Name: count, Length: 1214, dtype: int64

# %%
DF2023.sort_values('당월고지금액', ascending=False).head()
# Out:
#                  사업장명        사업장지번상세주소                 사업장업종코드명    가입자수  \
# 4286          삼성전자(주)  경기도 수원시 영통구 매탄동       비디오 및 기타 영상 기기 제조업  120877
# 3244         현대자동차(주)    서울특별시 서초구 양재동  화물 자동차 및 특수 목적용 자동차 제조업   68427
# 13145         엘지전자(주)  서울특별시 영등포구 여의도동            주방용 전기 기기 제조업   35609
# 134977  에스케이하이닉스 주식회사      경기도 이천시 부발읍                  컴퓨터 제조업   31145
# 150647     엘지디스플레이(주)  서울특별시 영등포구 여의도동            기타 반도체 소자 제조업   27978
#
#              당월고지금액  신규취득자수  상실가입자수
# 4286    63041891780     390     670
# 3244    34364239440     367     512
# 13145   18101199080     141     157
# 134977  16237739840     100     173
# 150647  14141978700      50     242

# %%
DF2023['1인당국민연금납부액'] = round(DF2023['당월고지금액']/DF2023['가입자수'])
DF2019['1인당국민연금납부액'] = round(DF2019['당월고지금액']/DF2019['가입자수'])
DF2015['1인당국민연금납부액'] = round(DF2015['당월고지금액']/DF2015['가입자수'])

# %%
DF2023['연금납부연도'] = '2023-12-01' 
DF2019['연금납부연도'] = '2019-11-01'
DF2015['연금납부연도'] = '2015-11-01'

# %%
# IT/소프트웨어 산업의 동향과 경쟁력 요소  그 중에서 세번째로 많은 응용 소프트웨어 개발 및 공급업
DF2023.head(20).sort_values(by='1인당국민연금납부액', ascending=False)
# Out:
#            사업장명        사업장지번상세주소                사업장업종코드명  가입자수      당월고지금액  \
# 0     (주)니프코코리아     충청남도 아산시 둔포면       포장용 플라스틱 성형용기 제조업   586   301703340
# 11    한국투자증권(주)  서울특별시 영등포구 여의도동       그 외 기타 금융 지원 서비스업  2844  1435303880
# 6   몬산토코리아 유한회사  서울특별시 영등포구 여의도동                     NaN    22    10963760
# 4       연합뉴스(주)    서울특별시 종로구 수송동         잡지 및 정기 간행물 발행업   825   410437380
# 19      서울상공회의소  서울특별시 중구 남대문로4가    비주거용 건물 임대업(점포  자기땅)   280   133382820
# 12      한국수출입은행  서울특별시 영등포구 여의도동       그 외 기타 금융 지원 서비스업  1229   574058480
# 13     (주)상상인증권  서울특별시 영등포구 여의도동                  증권 중개업   263   117103280
# 15     (주)동방아그로    서울특별시 관악구 남현동  화학 살균ㆍ살충제 및 농업용 약제 제조업   145    60581860
# 3        (주)헤럴드    서울특별시 용산구 후암동         잡지 및 정기 간행물 발행업   322   130867200
# 14       유니온(주)     서울특별시 중구 소공동                 시멘트 제조업    53    21040560
# 5       협성해운(주)   서울특별시 중구 을지로1가       내륙 수상 여객 및 화물 운송업    35    13626240
# ...

# %%
DF2023[DF2023['사업장업종코드명'] == '응용 소프트웨어 개발 및 공급업'].sort_values('당월고지금액', ascending=False).head()
# Out:
#              사업장명        사업장지번상세주소           사업장업종코드명   가입자수      당월고지금액  \
# 3341   삼성에스디에스(주)    서울특별시 송파구 신천동  응용 소프트웨어 개발 및 공급업  11607  6112532620
# 3006    (주)엘지씨엔에스    서울특별시 강서구 마곡동  응용 소프트웨어 개발 및 공급업   6765  3433785720
# 8597   SK쉴더스 주식회사  경기도 성남시 분당구 삼평동  응용 소프트웨어 개발 및 공급업   6927  2535606500
# 9294    현대오토에버(주)    서울특별시 강남구 대치동  응용 소프트웨어 개발 및 공급업   4871  2504414420
# 53721    엔씨소프트(주)    서울특별시 강남구 삼성동  응용 소프트웨어 개발 및 공급업   5039  2479423920
#
#        신규취득자수  상실가입자수  1인당국민연금납부액      연금납부연도
# 3341       21      68    526625.0  2023-12-01
# 3006       29      47    507581.0  2023-12-01
# 8597       63     110    366047.0  2023-12-01
# 9294       45       7    514148.0  2023-12-01
# 53721      56      51    492047.0  2023-12-01

# %%
DF2019.head(20).sort_values(by='1인당국민연금납부액', ascending=False)
# Out:
#                 사업장명        사업장지번상세주소               사업장업종코드명  가입자수  \
# 15           KB증권(주)  서울특별시 영등포구 여의도동                 증권 중개업  2828
# 10          한국후지쯔(주)   서울특별시 종로구 종로1가      응용 소프트웨어 개발 및 공급업   185
# 9          한국아이비엠(주)  서울특별시 영등포구 여의도동  컴퓨터 및 주변장치  소프트웨어 도매업  1390
# 18            (재)CBS     서울특별시 양천구 목동                라디오 방송업   345
# 11            한국관광공사      강원도 원주시 반곡동   비주거용 건물 임대업(점포  자기땅)   705
# 19           보령제약(주)    서울특별시 종로구 원남동             완제 의약품 제조업  1289
# 5          (주)한국경제신문     서울특별시 중구 중림동        잡지 및 정기 간행물 발행업   530
# 2   특수법인 총포 화약안전기술협회    서울특별시 마포구 용강동     기타 기술 시험  검사 및 분석업    20
# 17           보광교통(주)    서울특별시 은평구 수색동               시내버스 운송업   122
# 0              (유)삼송    서울특별시 서초구 양재동                    NaN   181
# 4          삼양건설산업(주)    서울특별시 서초구 양재동                아파트 건설업    79
# 6        (주) 매일경제신문사    서울특별시 중구 필동1가                스크린 인쇄업   770
# 1              (주)장성  경기도 성남시 분당구 야탑동  그 외 기타 분류 안된 섬유제품 제조업     4
# ...

# %%
DF2019[DF2019['사업장업종코드명'] == '응용 소프트웨어 개발 및 공급업'].sort_values('당월고지금액', ascending=False).head()
# Out:
#               사업장명        사업장지번상세주소           사업장업종코드명   가입자수      당월고지금액  \
# 382412  삼성에스디에스(주)    서울특별시 송파구 신천동  응용 소프트웨어 개발 및 공급업  12621  5466979660
# 2629     (주)엘지씨엔에스    서울특별시 강서구 마곡동  응용 소프트웨어 개발 및 공급업   6145  2599955800
# 48321     엔씨소프트(주)    서울특별시 강남구 삼성동  응용 소프트웨어 개발 및 공급업   3751  1498675640
# 292583   롯데정보통신(주)    서울특별시 금천구 가산동  응용 소프트웨어 개발 및 공급업   2731  1009880280
# 52335     (주)넥슨코리아  경기도 성남시 분당구 삼평동  응용 소프트웨어 개발 및 공급업   2557   999031340
#
#         신규취득자수  상실가입자수  1인당국민연금납부액      연금납부연도
# 382412      31      45    433165.0  2019-11-01
# 2629        28      33    423101.0  2019-11-01
# 48321       40      40    399540.0  2019-11-01
# 292583      29      31    369784.0  2019-11-01
# 52335       31      29    390704.0  2019-11-01

# %%
DF2015.head(20).sort_values(by='1인당국민연금납부액', ascending=False)
# Out:
#              사업장명        사업장지번상세주소                사업장업종코드명  가입자수     당월고지금액  \
# 16        한양증권(주)  서울특별시 영등포구 여의도동                  증권 중개업   257   84123600
# 3           (주)경농    서울특별시 서초구 서초동  화학 살균ㆍ살충제 및 농업용 약제 제조업   304   94230320
# 18  서중인터내셔날코리아(주)      경기도 이천시 마장면         그 외 기타 건축자재 도매업    17    5219760
# 9        평화당인쇄(주)    서울특별시 종로구 견지동                 스크린 인쇄업    56   17120280
# 0       대신정보통신(주)    서울특별시 금천구 가산동       응용 소프트웨어 개발 및 공급업   351  100787140
# 17    (주)SBI 저축은행     서울특별시 중구 수하동                    신용조합   434  122849000
# 6           (주)한창  서울특별시 영등포구 여의도동  전기용 기계ㆍ장비 및 관련 기자재 도매업    18    4974980
# 7         옥천산업(주)    서울특별시 송파구 가락동      복합비료 및 기타 화학비료 제조업    10    2504180
# 19   에스케이에스페인트(주)    전라북도 군산시 오식도동       일반용 도료 및 관련제품 제조업     9    2175820
# 8         청화산업(주)     서울특별시 중구 쌍림동           기타 토목 시설물 건설업    23    5503900
# 12         서한사(주)   서울특별시 중구 장충동2가                     호텔업   239   56003580
# ...

# %%
DF2015[DF2015['사업장업종코드명'] == '응용 소프트웨어 개발 및 공급업'].sort_values('당월고지금액', ascending=False).head()
# Out:
#              사업장명        사업장지번상세주소           사업장업종코드명   가입자수      당월고지금액  \
# 4071   삼성에스디에스(주)    서울특별시 송파구 신천동  응용 소프트웨어 개발 및 공급업  14058  5235993360
# 4015     (주)엘지씨에스    서울특별시 강서구 마곡동  응용 소프트웨어 개발 및 공급업   6480  2352453480
# 77088    엔씨소프트(주)    서울특별시 강남구 삼성동  응용 소프트웨어 개발 및 공급업   2305   772309720
# 12199   현대오토에버(주)    서울특별시 강남구 대치동  응용 소프트웨어 개발 및 공급업   1725   645409060
# 83525    (주)넥슨코리아  경기도 성남시 분당구 삼평동  응용 소프트웨어 개발 및 공급업   1915   622477920
#
#        신규취득자수  상실가입자수  1인당국민연금납부액      연금납부연도
# 4071       15     234    372456.0  2015-11-01
# 4015       19      60    363033.0  2015-11-01
# 77088      35      35    335058.0  2015-11-01
# 12199       3       5    374150.0  2015-11-01
# 83525      45      25    325054.0  2015-11-01

# %%
DF2023[DF2023['사업장업종코드명'] == '데이터베이스 및 온라인 정보 제공업'].sort_values('당월고지금액', ascending=False).head()
# Out:
#                 사업장명        사업장지번상세주소             사업장업종코드명  가입자수      당월고지금액  \
# 105234     (주)케이티씨에스     대전광역시 서구 괴정동  데이터베이스 및 온라인 정보 제공업  9147  2184533740
# 6532        네이버 주식회사  경기도 성남시 분당구 정자동  데이터베이스 및 온라인 정보 제공업  4261  2169299420
# 53398       주식회사 카카오  제주특별자치도 제주시 영평동  데이터베이스 및 온라인 정보 제공업  3824  1847162460
# 6656        주식회사 메타엠    서울특별시 강남구 논현동  데이터베이스 및 온라인 정보 제공업  6971  1380315240
# 130259  네이버클라우드 주식회사  경기도 성남시 분당구 백현동  데이터베이스 및 온라인 정보 제공업  1948   966947060
#
#         신규취득자수  상실가입자수  1인당국민연금납부액      연금납부연도
# 105234     289    1115    238825.0  2023-12-01
# 6532        35      52    509106.0  2023-12-01
# 53398       23      48    483045.0  2023-12-01
# 6656       500     563    198008.0  2023-12-01
# 130259      46      67    496379.0  2023-12-01

# %%
DF2019[DF2019['사업장업종코드명'] == '데이터베이스 및 온라인 정보 제공업'].sort_values('당월고지금액', ascending=False).head()
# Out:
#               사업장명        사업장지번상세주소             사업장업종코드명  가입자수      당월고지금액  \
# 94040    (주)케이티씨에스     대전광역시 서구 괴정동  데이터베이스 및 온라인 정보 제공업  8461  1769299000
# 383318    네이버 주식회사  경기도 성남시 분당구 정자동  데이터베이스 및 온라인 정보 제공업  3416  1410721320
# 5585    (주)메타넷엠플랫폼   서울특별시 중구 충무로2가  데이터베이스 및 온라인 정보 제공업  7150  1215809120
# 48212     주식회사 카카오  제주특별자치도 제주시 영평동  데이터베이스 및 온라인 정보 제공업  2813  1071537120
# 5361     카페24 주식회사   서울특별시 동작구 신대방동  데이터베이스 및 온라인 정보 제공업  1104   365324540
#
#         신규취득자수  상실가입자수  1인당국민연금납부액      연금납부연도
# 94040      235     293    209112.0  2019-11-01
# 383318      52      57    412975.0  2019-11-01
# 5585       631     499    170043.0  2019-11-01
# 48212       58     302    380923.0  2019-11-01
# 5361        11      25    330910.0  2019-11-01

# %%
DF2015[DF2015['사업장업종코드명'] == '데이터베이스 및 온라인 정보 제공업'].sort_values('당월고지금액', ascending=False).head()
# Out:
#              사업장명        사업장지번상세주소             사업장업종코드명   가입자수      당월고지금액  \
# 149624  (주)케이티씨에스     대전광역시 서구 괴정동  데이터베이스 및 온라인 정보 제공업  10142  1637542640
# 77065    주식회사 카카오  제주특별자치도 제주시 영평동  데이터베이스 및 온라인 정보 제공업   2353   825921260
# 8351     네이버 주식회사  경기도 성남시 분당구 정자동  데이터베이스 및 온라인 정보 제공업   2235   799930020
# 8511    (주)메타넷엠씨씨   서울특별시 중구 충무로2가  데이터베이스 및 온라인 정보 제공업   5537   730578460
# 238455    주식회사 티몬    서울특별시 강남구 대치동  데이터베이스 및 온라인 정보 제공업   1080   282179100
#
#         신규취득자수  상실가입자수  1인당국민연금납부액      연금납부연도
# 149624     418     417    161462.0  2015-11-01
# 77065       46      54    351008.0  2015-11-01
# 8351        47      34    357911.0  2015-11-01
# 8511       475     474    131945.0  2015-11-01
# 238455      41      35    261277.0  2015-11-01

# %%
# '삼성에스디에스', '엘지씨에스', '엔씨소프트'
# x축: 연도  y축: 1인당 납부액

x15 = [1,3,5]
data15 = [372456, 363033, 335058]
plt.bar(x15, data15, color='b', width=0.5)

x19 = [1+0.5, 3+0.5, 5+0.5]
data19 = [433165, 423101, 399540]
plt.bar(x19, data19, color='r', width=0.5)

x23 = [1+1, 3+1, 5+1]
data23 = [526625, 507581, 492047]
plt.bar(x23, data23, color='g', width=0.5)

ticklabel = ['2015', '2019', '2023']
plt.xticks(x19, ticklabel)
plt.xlabel('년도(년)')
plt.ylabel('1인당국민연금납부액(원)')

plt.title('소프트웨어 빅테크 성장 추이')
plt.legend(['삼성SDS', 'LG CNS', 'NC 소프트'])
plt.show()

# %%
# '케이티씨에스', '카카오', '네이버'
# x축: 납부연도  y축: 1인당 납부액
x15 = [1,3,5]
datakt = [161462, 209112, 238825]
plt.bar(x15, data15, color='black', width=0.5)

x19 = [1+0.5, 3+0.5, 5+0.5]
datakaka = [351008, 380923, 483045]
plt.bar(x19, data19, color='yellow', width=0.5)

x23 = [1+1, 3+1, 5+1]
datanav = [357911, 412975, 509106]
plt.bar(x23, data23, color='lightgreen', width=0.5)

ticklabel = ['2015', '2019', '2023']
plt.xticks(x19, ticklabel)
plt.xlabel('년도(년)')
plt.ylabel('1인당국민연금납부액(원)')

plt.title('데이터베이스 빅테크 성장 추이')
plt.legend(['케이티씨에스', '카카오', '네이버'])
plt.show()

# %%
# '삼성에스디에스', '엘지씨에스', '엔씨소프트'
# x축: 연도  y축: 가입자수
x = [2015, 2019, 2023]
ysam = [14058, 12621, 11607]
ylg = [6480, 6145, 6765]
ync = [2305, 3751, 5039]

plt.title('소프트웨어 빅테크 성장 추이')
plt.plot(x, ysam)
plt.plot(x, ylg)
plt.plot(x, ync)

plt.xlabel('년도(년)')
plt.ylabel('가입자수(명)')
ticklabel = ['2015', '2019', '2023']

plt.legend(('삼성SDS', 'LG CNS', 'NC 소프트'), loc='center right')
plt.show()

# %%
# '케이티씨에스', '네이버', '카카오'
# x축:연도  y축: 가입자수
x = [2015, 2019, 2023]
ykt = [10142, 8461, 9147]
ynav = [2235, 3416, 4261]
ykaka = [2353, 2813, 3824]

plt.title('데이터베이스 빅테크 성장 추이')
plt.plot(x, ykt, color='black')
plt.plot(x, ynav, color='lightgreen')
plt.plot(x, ykaka, color='yellow')
plt.xlabel('년도(년)')
plt.ylabel('가입자수(명)')

plt.legend(('KT CS', '네이버', '카카오'))
plt.show()

# %%
# 정창수 교수님 피드백: 그래프에 마크 표시했으면 좋았을것
# -- 개인적 생각: 교수님이 뭔가 더 할말 있었을 거 같았는데 길어질거 같아 생략한거 같다
#                팀원들 중에서 제일 부족했다고 생각함, 소주제랑 흐름을 파악하지 못해 코드 짜는데 애먹었다.
