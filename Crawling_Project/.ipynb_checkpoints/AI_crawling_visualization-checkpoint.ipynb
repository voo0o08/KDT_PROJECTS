# %%
import pandas as pd
import numpy as np
import koreanize_matplotlib
import matplotlib.pyplot as plt
import pymysql

from bs4 import BeautifulSoup
import requests
from konlpy.tag import Okt
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import time
import platform
import numpy as np
from PIL import Image

# %%
def pie_graph(ratio, labels):
    colors = ['silver', 'gold', 'whitesmoke', 'lightgray']
    plt.pie(ratio, labels=labels, autopct='%.1f%%', colors=colors)
    plt.show()

# %%
df = pd.read_csv("temp_work_net_AI.csv")
AI_df = df.drop('Unnamed: 0', axis=1)
AI_df
# Out:
#                 모집직종                                               직무내용  \
# 0              게임개발자                                                  -
# 1              C·C++  [담당업무] • 컴퓨터 비전 및 AI 분야 논문 조사 및 요약 • DCNN 기반 영...
# 2                  -  AI Technical Senior/AI 분석,모델링,AI서비스기획,설계,클라우드 ...
# 3    그 외 프로그래밍언어 전문가  ###긴급) AI/ML Engineer(추천 서비스) -업계 최고 대기업 -최우대#...
# 4         C/C++,Java  [AI플랫폼팀 소개] * AI플랫폼팀은 자사 솔루션을 제품화하는데 있어서의 연구개발...
# ..               ...                                                ...
# 195                -                     바이오/제약/식품, 빅데이터/AI, DBA/데이터베이스
# 196                -                      기획/전략/경영, 네트워크/서버/보안, 빅데이터/AI
# 197                -  기획/전략/경영, 바이오/제약/식품, 빅데이터/AI, 사무/총무/법무, 생산/제조/...
# 198     웹기획,서비스기획·운영  [주요업무] • AI 서비스의 S/W 개발과 관련된 프로젝트 기획 및 수행관리 • ...
# 199                -  ㆍ 정형/비정형 문서의 인식 모델 개발 ㆍ AI 엔진 성능 향상을 위한 딥러닝 모델...
#
#                 경력조건      학력 전공 자격면허  \
# 0      경력 (최소 5년 이상)    학력무관  -    -
# 1      신입, 경력 (연수무관)      석사  -    -
# 2      경력 (최소 1년 이상)    학력무관  -    -
# 3    경력 (최소 24개월 이상)    학력무관  -    -
# 4      신입, 경력 (연수무관)      석사  -    -
# ..               ...     ... ..  ...
# 195               무관      석사  -    -
# 196               무관    학력무관  -    -
# 197               무관  대졸(4년)  -    -
# 198    경력 (최소 3년 이상)  대졸(4년)  -    -
# 199    경력 (최소 5년 이상)    학력무관  -    -
#
#                                                   우대조건
# 0                                                    -
# 1                                                    -
# 2                                                    -
# 3                                                    -
# 4    - 최신 기술 트렌드에 관심이 많은 분\n- MSA(Micro Service Arc...
# ..                                                 ...
# 195                                                  -
# 196                                                  -
# 197                                                  -
# 198                                                  -
# 199                                                  -
#
# [200 rows x 7 columns]

# %%
AI_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   모집직종    200 non-null    object
#  1   직무내용    200 non-null    object
#  2   경력조건    200 non-null    category
#  3   학력      200 non-null    category
#  4   전공      200 non-null    object
#  5   자격면허    200 non-null    object
#  6   우대조건    200 non-null    object
# dtypes: category(2), object(5)
# memory usage: 9.4+ KB

# %%
AI_df = AI_df.astype({'경력조건':'category', '학력':'category'})

# %% [markdown]
# ## 규티빠띠 cloud 그리기

# %%
title_list = list(AI_df["직무내용"])

# %%
def make_wordcloud(title_list, stopwords, word_count):  # 딕셔너리로 만듦
    okt = Okt()
    sentences_tag = []
    # 형태소 분석하여 리스트에 넣기
    for sentence in title_list:
        morph = okt.pos(sentence)
        sentences_tag.append(morph)
        print(morph)
        print('-' * 80)
    noun_adj_list = []
    # 명사와 형용사만 구분하여 리스트에 추가
    for sentence1 in sentences_tag:
        for word, tag in sentence1:
            if tag in ['Noun', 'Adjective']:
                noun_adj_list.append(word)
    # 형태소별 count
    counts = Counter(noun_adj_list)
    tags = counts.most_common(word_count)
    print('-' * 80)
    print(tags)
    tag_dict = dict(tags)
    # 검색어 제외 방법 2: dict에서 해당 검색어 제거
    for stopword in stopwords:
        if stopword in tag_dict:
            tag_dict.pop(stopword)
    print(tag_dict)
    if platform.system() == 'Windows':
        path = r'c:\Windows\Fonts\malgun.ttf'
    elif platform.system() == 'Darwin':  # Mac OS
        path = r'/System/Library/Fonts/AppleGothic'
    else:
        path = r'/usr/share/fonts/truetype/name/NanumMyeongjo.ttf'
    img_mask = np.array(Image.open('cloud.png'))
    wordcloud = WordCloud(font_path=path, width=800, height=600,
                          background_color="white", max_font_size=200,
                          repeat=True,
                          colormap='inferno', mask=img_mask)
    cloud = wordcloud.generate_from_frequencies(tag_dict)
    plt.figure(figsize=(10, 8))
    plt.axis('off')
    plt.imshow(cloud)
    plt.show()


if __name__ == '__main__':
    #search_word = "ChatGPT"  # 검색어 지정
    #title_list = []
    stopwords = ['데이터', "빅데이터", "및", "이상", "등", "관련"]  # wordcloud에서 제외할 단어
    # 1~200번게시글 까지 크롤링
    #get_titles(1, 200, search_word, title_list)
    # 단어 50개까지 wordcloud로 출력
    make_wordcloud(title_list, stopwords, 50)
# Out:
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('[', 'Punctuation'), ('담당', 'Noun'), ('업무', 'Noun'), (']', 'Punctuation'), ('•', 'Foreign'), ('컴퓨터', 'Noun'), ('비전', 'Verb'), ('및', 'Noun'), ('AI', 'Alpha'), ('분야', 'Noun'), ('논문', 'Noun'), ('조사', 'Noun'), ('및', 'Noun'), ('요약', 'Noun'), ('•', 'Foreign'), ('DCNN', 'Alpha'), ('기반', 'Noun'), ('영', 'Modifier'), ('상처리', 'Noun'), ('AI', 'Alpha'), ('엔진', 'Noun'), ('개발', 'Noun'), ('혹은', 'Adverb'), ('RNN', 'Alpha'), ('기반', 'Noun'), ('신호처리', 'Noun'), ('AI', 'Alpha'), ('엔진', 'Noun'), ('개발', 'Noun'), ('•', 'Foreign'), ('AI', 'Alpha'), ('학습', 'Noun'), ('데이터', 'Noun'), ('관련', 'Noun'), ('유틸리티', 'Noun'), ('스크립트', 'Noun'), ('및', 'Noun'), ('툴', 'Noun'), ('개발', 'Noun'), ('[', 'Punctuation'), ('자격', 'Noun'), ('요건', 'Noun'), (']', 'Punctuation'), ('•', 'Foreign'), ('학력', 'Noun'), (':', 'Punctuation'), ('석사', 'Noun'), ('이상', 'Noun'), ('•', 'Foreign'), ('전공', 'Noun'), (':', 'Punctuation'), ('이공', 'Noun'), ('계', 'Suffix'), ('(', 'Punctuation'), ('자연', 'Noun'), ('계열', 'Noun'), (',', 'Punctuation'), ('공학', 'Noun'), ('계열', 'Noun'), (')', 'Punctuation'), ('[', 'Punctuation'), ('필수', 'Noun'), ('요건', 'Noun'), ('및', 'Noun'), ('우대', 'Noun'), ('사항', 'Noun'), (']', 'Punctuation'), ('[', 'Punctuation'), ('필수', 'Noun'), ('요건', 'Noun'), (']', 'Punctuation'), ('A', 'Alpha'), ('항목', 'Noun'), ('A', 'Alpha'), ('-', 'Punctuation'), ('1', 'Number'), (')', 'Punctuation'), ('이공', 'Noun'), ('계', 'Suffix'), ('분야', 'Noun'), ('에서', 'Josa'), ('석사', 'Noun'), ('졸업', 'Noun'), ('이상', 'Noun'), ('A', 'Alpha'), ('-', 'Punctuation'), ('2', 'Number'), (')', 'Punctuation'), ('C', 'Alpha'), ('/', 'Punctuation'), ('C', 'Alpha'), ('++', 'Punctuation'), ('혹은', 'Adverb'), ('Python', 'Alpha'), ('언어', 'Noun'), ('에', 'Josa'), ('능숙한', 'Adjective'), ('사람', 'Noun'), ('[', 'Punctuation'), ('우대', 'Noun'), ('사항', 'Noun'), (']', 'Punctuation'), ('B', 'Alpha'), ('항목', 'Noun'), ('B', 'Alpha'), ('-', 'Punctuation'), ('1', 'Number'), (')', 'Punctuation'), ('컴퓨터', 'Noun'), ('비전', 'Verb'), ('혹은', 'Adverb'), ('AI', 'Alpha'), ('관련', 'Noun'), ('학회', 'Noun'), ('에', 'Josa'), ('제', 'Noun'), ('1', 'Number'), ('저자', 'Noun'), ('로', 'Josa'), ('논문', 'Noun'), ('게재', 'Noun'), ('B', 'Alpha'), ('-', 'Punctuation'), ('2', 'Number'), (')', 'Punctuation'), ('영어', 'Noun'), ('논문', 'Noun'), ('및', 'Noun'), ('기술', 'Noun'), ('자료', 'Noun'), ('를', 'Josa'), ('읽고', 'Verb'), ('분석', 'Noun'), ('할', 'Verb'), ('수', 'Noun'), ('있는', 'Adjective'), ('외국어', 'Noun'), ('문해', 'Noun'), ('력', 'Suffix'), ('을', 'Josa'), ('보유', 'Noun'), ('한', 'Josa'), ('사람', 'Noun'), ('B', 'Alpha'), ('-', 'Punctuation'), ('3', 'Number'), (')', 'Punctuation'), ('Git', 'Alpha'), ('사용', 'Noun'), ('에', 'Josa'), ('능숙한', 'Adjective'), ('사람', 'Noun'), ('B', 'Alpha'), ('-', 'Punctuation'), ('4', 'Number'), (')', 'Punctuation'), ('OpenCV', 'Alpha'), ('사용', 'Noun'), ('에', 'Josa'), ('능숙한', 'Adjective'), ('사람', 'Noun'), ('B', 'Alpha'), ('-', 'Punctuation'), ('5', 'Number'), (')', 'Punctuation'), ('CUDA', 'Alpha'), ('사용', 'Noun'), ('에', 'Josa'), ('능숙한', 'Adjective'), ('사람', 'Noun'), ('B', 'Alpha'), ('-', 'Punctuation'), ('6', 'Number'), (')', 'Punctuation'), ('OOP', 'Alpha'), ('개념', 'Noun'), ('에', 'Josa'), ('익숙한', 'Adjective'), ('사람', 'Noun'), ('B', 'Alpha'), ('-', 'Punctuation'), ('7', 'Number'), (')', 'Punctuation'), ('CI', 'Alpha'), ('/', 'Punctuation'), ('CD', 'Alpha'), ('를', 'Noun'), ('구축', 'Noun'), ('한', 'Josa'), ('경험', 'Noun'), ('이', 'Josa'), ('있는', 'Adjective'), ('사람', 'Noun'), ('B', 'Alpha'), ('-', 'Punctuation'), ('8', 'Number'), (')', 'Punctuation'), ('Rasberry', 'Alpha'), ('Pi', 'Alpha'), (',', 'Punctuation'), ('NVIDIA', 'Alpha'), ('Jetson', 'Alpha'), ('보드', 'Noun'), ('등', 'Noun'), ('을', 'Josa'), ('사용', 'Noun'), ('해본', 'Verb'), ('경험', 'Noun'), ('이', 'Josa'), ('있는', 'Adjective'), ('사람', 'Noun'), ('B', 'Alpha'), ('-', 'Punctuation'), ('9', 'Number'), (')', 'Punctuation'), ('기계', 'Noun'), ('적', 'Suffix'), ('매커니즘', 'Noun'), ('이', 'Josa'), ('포함', 'Noun'), ('된', 'Verb'), ('장치', 'Noun'), ('를', 'Josa'), ('만들어', 'Verb'), ('본', 'Verb'), ('경험', 'Noun'), ('이', 'Josa'), ('있는', 'A ...
# --------------------------------------------------------------------------------
# [('AI', 'Alpha'), ('Technical', 'Alpha'), ('Senior', 'Alpha'), ('/', 'Punctuation'), ('AI', 'Alpha'), ('분석', 'Noun'), (',', 'Punctuation'), ('모델링', 'Noun'), (',', 'Punctuation'), ('AI', 'Alpha'), ('서비스', 'Noun'), ('기획', 'Noun'), (',', 'Punctuation'), ('설계', 'Noun'), (',', 'Punctuation'), ('클라우드', 'Noun'), ('사업', 'Noun'), ('기획', 'Noun'), ('컨설턴트', 'Noun'), ('과', 'Noun'), ('차장', 'Noun'), ('급', 'Suffix'), ('7', 'Number'), ('명', 'Noun')]
# --------------------------------------------------------------------------------
# [('#', 'Foreign'), ('##긴급', 'Hashtag'), (')', 'Punctuation'), ('AI', 'Alpha'), ('/', 'Punctuation'), ('ML', 'Alpha'), ('Engineer', 'Alpha'), ('(', 'Punctuation'), ('추천', 'Noun'), ('서비스', 'Noun'), (')', 'Punctuation'), ('-', 'Punctuation'), ('업계', 'Noun'), ('최고', 'Noun'), ('대기업', 'Noun'), ('-', 'Punctuation'), ('최우', 'Noun'), ('대', 'Suffix'), ('###-', 'Punctuation'), ('업계', 'Noun'), ('1~2', 'Number'), ('위', 'Noun'), ('에', 'Josa'), ('소비재', 'Noun'), ('대기업', 'Noun'), ('-', 'Punctuation'), ('근무', 'Noun'), ('분위기', 'Noun'), ('Good', 'Alpha'), (',', 'Punctuation'), ('복리', 'Noun'), ('후생', 'Noun'), ('이나', 'Josa'), ('연차', 'Noun'), ('제도', 'Noun'), ('잘', 'Verb'), ('되어있음', 'Verb'), ('.-', 'Punctuation'), ('만족도', 'Noun'), ('후기', 'Noun'), ('높은', 'Adjective'), ('회사', 'Noun'), ('임', 'Noun'), ('.', 'Punctuation'), ('▶', 'Foreign'), ('포지션', 'Noun'), (':', 'Punctuation'), ('AI', 'Alpha'), ('/', 'Punctuation'), ('ML', 'Alpha'), ('Engineer', 'Alpha'), ('(', 'Punctuation'), ('추천', 'Noun'), ('서비스', 'Noun'), (')', 'Punctuation'), ('▶', 'Foreign'), ('업무', 'Noun'), ('내용', 'Noun'), ('-', 'Punctuation'), ('Generative', 'Alpha'), ('AI', 'Alpha'), ('등', 'Noun'), ('AI', 'Alpha'), ('/', 'Punctuation'), ('ML', 'Alpha'), ('기술', 'Noun'), ('을', 'Josa'), ('활용', 'Noun'), ('하여', 'Verb'), ('다양한', 'Adjective'), ('서비스', 'Noun'), ('를', 'Josa'), ('개발', 'Noun'), ('합니다', 'Verb'), ('.-', 'Punctuation'), ('사용자', 'Noun'), ('의', 'Josa'), ('선호', 'Noun'), ('도를', 'Verb'), ('기반', 'Noun'), ('으로', 'Josa'), ('상품', 'Noun'), (',', 'Punctuation'), ('콘텐츠', 'Noun'), ('등', 'Noun'), ('을', 'Josa'), ('추천', 'Noun'), ('하', 'Suffix'), ('는', 'Josa'), ('AI', 'Alpha'), ('기술', 'Noun'), ('을', 'Josa'), ('개발', 'Noun'), ('합니다', 'Verb'), ('.-', 'Punctuation'), ('데이터', 'Noun'), ('분석', 'Noun'), (',', 'Punctuation'), ('모델', 'Noun'), ('개발', 'Noun'), ('및', 'Noun'), ('평가', 'Noun'), ('합니다', 'Verb'), ('.-', 'Punctuation'), ('ML', 'Alpha'), ('파이프라인', 'Noun'), ('구축', 'Noun'), ('하고', 'Josa'), ('운영', 'Noun'), ('합니다', 'Verb'), ('.-', 'Punctuation'), ('뷰티', 'Noun'), ('도메인', 'Noun'), ('에', 'Josa'), ('특화된', 'Noun'), ('AI', 'Alpha'), ('/', 'Punctuation'), ('ML', 'Alpha'), ('/', 'Punctuation'), ('DL', 'Alpha'), ('모델', 'Noun'), ('을', 'Josa'), ('최적화', 'Noun'), ('하고', 'Josa'), ('고도', 'Noun'), ('화합니다', 'Adjective'), ('.', 'Punctuation'), ('▶', 'Foreign'), ('자격', 'Noun'), ('요건', 'Noun'), ('-', 'Punctuation'), ('경력', 'Noun'), (':', 'Punctuation'), ('AI', 'Alpha'), ('/', 'Punctuation'), ('ML', 'Alpha'), ('관련', 'Noun'), ('된', 'Verb'), ('경험', 'Noun'), ('이', 'Josa'), ('2년', 'Number'), ('이상', 'Noun'), ('있으신', 'Adjective'), ('분', 'Noun'), ('-', 'Punctuation'), ('학위', 'Noun'), (':', 'Punctuation'), ('학사', 'Noun'), ('이상', 'Noun'), ('(', 'Punctuation'), ('컴퓨터', 'Noun'), ('공학', 'Noun'), (',', 'Punctuation'), ('수학', 'Noun'), (',', 'Punctuation'), ('통계', 'Noun'), ('등', 'Noun'), ('관련', 'Noun'), ('전공', 'Noun'), ('하신', 'Verb'), ('분', 'Noun'), (')-', 'Punctuation'), ('Python', 'Alpha'), (',', 'Punctuation'), ('TensorFlow', 'Alpha'), (',', 'Punctuation'), ('PyTorch', 'Alpha'), (',', 'Punctuation'), ('scikit', 'Alpha'), ('-', 'Punctuation'), ('learn', 'Alpha'), ('등', 'Noun'), ('AI', 'Alpha'), ('/', 'Punctuation'), ('ML', 'Alpha'), ('관련', 'Noun'), ('된', 'Verb'), ('프로그래밍', 'Noun'), ('언어', 'Noun'), ('및', 'Noun'), ('라이브러리', 'Noun'), ('에', 'Josa'), ('능숙하신', 'Adjective'), ('분', 'Noun'), ('을', 'Josa'), ('찾습니다', 'Verb'), ('.-', 'Punctuation'), ('데이터', 'Noun'), ('분석', 'Noun'), (',', 'Punctuation'), ('머신', 'Noun'), ('러닝', 'Noun'), ('에', 'Josa'), ('대한', 'Noun'), ('기본', 'Noun'), ('적', 'Suffix'), ('인', 'Josa'), ('지식', 'Noun'), ('을', 'Josa'), ('갖추시고', 'Verb'), ('관련', 'Noun'), ('실무', 'Noun'), ('경험', 'Noun'), ('이', 'Josa'), ('있으신', 'Adjective'), ('분', 'Noun'), ('을', 'Josa'), ('찾습니다', 'Verb'), ('.-', 'Punctuation'), ('AWS', 'Alpha'), ('등', 'Noun'), ('클라우드', 'Noun'), ('환경', 'Noun'), ('에서', 'Josa'), ('AI', 'Alpha'), ('/', 'Punctuation'), ('ML', 'Alpha'), ('서비스', 'Noun'), ('를', 'Josa'), ('실제', 'Noun'), ('개발', 'Noun'), ('하시거나', 'Verb'), ('MLOps', 'Alpha'), ('실무', 'No ...
# --------------------------------------------------------------------------------
# [('[', 'Punctuation'), ('AI', 'Alpha'), ('플랫폼', 'Noun'), ('팀', 'Noun'), ('소개', 'Noun'), (']', 'Punctuation'), ('*', 'Punctuation'), ('AI', 'Alpha'), ('플랫폼', 'Noun'), ('팀', 'Noun'), ('은', 'Josa'), ('자사', 'Noun'), ('솔루션', 'Noun'), ('을', 'Josa'), ('제품', 'Noun'), ('화하는데', 'Adjective'), ('있', 'Adjective'), ('어서', 'Noun'), ('의', 'Josa'), ('연구개발', 'Noun'), ('과', 'Josa'), ('운영', 'Noun'), ('을', 'Josa'), ('수행', 'Noun'), ('하며', 'Verb'), (',', 'Punctuation'), ('와이즈넛', 'Noun'), ('의', 'Josa'), ('인공', 'Noun'), ('지능', 'Noun'), ('SW', 'Alpha'), ('를', 'Noun'), ('고객', 'Noun'), ('에게', 'Josa'), ('제공', 'Noun'), ('하기', 'Verb'), ('위', 'Noun'), ('한', 'Josa'), ('플랫폼', 'Noun'), ('기술', 'Noun'), ('을', 'Josa'), ('연구', 'Noun'), ('하고', 'Josa'), ('개발', 'Noun'), ('합니다', 'Verb'), ('.', 'Punctuation'), ('또한', 'Noun'), (',', 'Punctuation'), ('와이즈넛', 'Noun'), ('솔루션', 'Noun'), ('개발', 'Noun'), ('/', 'Punctuation'), ('운영', 'Noun'), ('을', 'Josa'), ('위', 'Noun'), ('한', 'Josa'), ('AI', 'Alpha'), ('플랫폼', 'Noun'), ('을', 'Josa'), ('설계', 'Noun'), ('하고', 'Josa'), (',', 'Punctuation'), ('플랫폼', 'Noun'), ('환경', 'Noun'), ('에서', 'Josa'), ('다양한', 'Adjective'), ('와이즈넛', 'Noun'), ('인공', 'Noun'), ('지능', 'Noun'), ('솔루션', 'Noun'), ('을', 'Josa'), ('연결하는', 'Adjective'), ('공통', 'Noun'), ('서비스', 'Noun'), ('를', 'Josa'), ('개발', 'Noun'), ('합니다', 'Verb'), ('.', 'Punctuation'), ('[', 'Punctuation'), ('담당', 'Noun'), ('업무', 'Noun'), (']', 'Punctuation'), ('-', 'Punctuation'), ('MSA', 'Alpha'), ('(', 'Punctuation'), ('Micro', 'Alpha'), ('service', 'Alpha'), ('Architecture', 'Alpha'), (')', 'Punctuation'), ('기반', 'Noun'), ('의', 'Josa'), ('제품', 'Noun'), ('개발', 'Noun'), ('/', 'Punctuation'), ('운영', 'Noun'), ('플랫폼', 'Noun'), ('설계', 'Noun'), ('-', 'Punctuation'), ('AI', 'Alpha'), ('플랫폼', 'Noun'), ('환경', 'Noun'), ('에서', 'Josa'), ('개발', 'Noun'), ('을', 'Josa'), ('위', 'Noun'), ('한', 'Josa'), ('다양한', 'Adjective'), ('기술', 'Noun'), ('검증', 'Noun'), ('및', 'Noun'), ('내부', 'Noun'), ('기술', 'Noun'), ('표준', 'Noun'), ('수립', 'Noun'), ('-', 'Punctuation'), ('AI', 'Alpha'), ('플랫폼', 'Noun'), ('대상', 'Noun'), ('의', 'Josa'), ('개발', 'Noun'), ('및', 'Noun'), ('배포', 'Noun'), ('(', 'Punctuation'), ('CI', 'Alpha'), ('/', 'Punctuation'), ('CD', 'Alpha'), (')', 'Punctuation'), ('기술', 'Noun'), ('연구', 'Noun'), ('-', 'Punctuation'), ('인증', 'Noun'), (',', 'Punctuation'), ('로깅', 'Noun'), (',', 'Punctuation'), ('분석', 'Noun'), ('/', 'Punctuation'), ('시각', 'Noun'), ('화', 'Suffix'), (',', 'Punctuation'), ('모니터링', 'Noun'), ('등', 'Noun'), ('플랫폼', 'Noun'), ('공통', 'Noun'), ('서비스', 'Noun'), ('개발', 'Noun'), ('-', 'Punctuation'), ('Cloud', 'Alpha'), ('Native', 'Alpha'), ('기반', 'Noun'), ('의', 'Josa'), ('내부', 'Noun'), ('개발', 'Noun'), ('/', 'Punctuation'), ('테스트', 'Noun'), ('인프라', 'Noun'), ('관리', 'Noun'), ('/', 'Punctuation'), ('운영', 'Noun'), ('(', 'Punctuation'), ('DevOps', 'Alpha'), (')', 'Punctuation'), ('-', 'Punctuation'), ('인공', 'Noun'), ('지능', 'Noun'), ('관련', 'Noun'), ('R', 'Alpha'), ('&', 'Punctuation'), ('D', 'Alpha'), ('연구', 'Noun'), ('과제', 'Noun'), ('수행', 'Noun')]
# --------------------------------------------------------------------------------
# [('오토', 'Noun'), ('시맨틱스', 'Noun'), ('는', 'Josa'), ('산업', 'Noun'), ('용', 'Noun'), ('AI', 'Alpha'), ('전', 'Modifier'), ('문', 'Modifier'), ('회사', 'Noun'), ('로', 'Josa'), ('건물', 'Noun'), ('분야', 'Noun'), ('EMS', 'Alpha'), ('(', 'Punctuation'), ('Energy', 'Alpha'), ('Management', 'Alpha'), ('System', 'Alpha'), (')', 'Punctuation'), ('와', 'Verb'), ('AI', 'Alpha'), ('기반', 'Noun'), ('관제', 'Noun'), ('센터', 'Noun'), ('를', 'Josa'), ('주력', 'Noun'), ('사업', 'Noun'), ('화', 'Suffix'), ('하고', 'Josa'), ('있습니다', 'Adjective'), ('.', 'Punctuation'), ('저희', 'Noun'), ('는', 'Josa'), ('건물', 'Noun'), ('의', 'Josa'), ('설비', 'Noun'), ('를', 'Josa'), ('AI', 'Alpha'), ('기반', 'Noun'), ('으로', 'Josa'), ('제어', 'Noun'), ('하여', 'Verb'), ('건물', 'Noun'), ('의', 'Josa'), ('에너지', 'Noun'), ('를', 'Josa'), ('절감', 'Noun'), ('하고', 'Josa'), (',', 'Punctuation'), ('쾌적', 'Noun'), ('도를', 'Verb'), ('높이', 'Noun'), ('고', 'Josa'), (',', 'Punctuation'), ('안전성', 'Noun'), ('을', 'Josa'), ('증가', 'Noun'), ('시키려고', 'Verb'), ('합니다', 'Verb'), ('.', 'Punctuation'), ('백화점', 'Noun'), (',', 'Punctuation'), ('쇼핑몰', 'Noun'), (',', 'Punctuation'), ('전시장', 'Noun'), (',', 'Punctuation'), ('대형', 'Noun'), ('오피스', 'Noun'), (',', 'Punctuation'), ('연구소', 'Noun'), (',', 'Punctuation'), ('점포', 'Noun'), ('등', 'Noun'), ('다양한', 'Adjective'), ('건물', 'Noun'), ('에서', 'Josa'), ('실증', 'Noun'), ('하였으며', 'Verb'), (',', 'Punctuation'), ('계속', 'Noun'), ('해서', 'Verb'), ('서비스', 'Noun'), ('하는', 'Verb'), ('건물', 'Noun'), ('의', 'Josa'), ('수', 'Noun'), ('를', 'Josa'), ('늘려가고', 'Verb'), ('있습니다', 'Adjective'), ('.', 'Punctuation'), ('회사', 'Noun'), ('는', 'Josa'), ('성수역', 'Noun'), ('에', 'Josa'), ('위치', 'Noun'), ('하고', 'Josa'), ('있으며', 'Adjective'), ('20', 'Number'), ('대와', 'Verb'), ('30', 'Number'), ('대로', 'Noun'), ('구성', 'Noun'), ('되어', 'Verb'), ('있으며', 'Adjective'), (',', 'Punctuation'), ('이', 'Noun'), ('분야', 'Noun'), ('국내', 'Noun'), ('최고', 'Noun'), ('의', 'Josa'), ('기술', 'Noun'), ('회사', 'Noun'), ('입니다', 'Adjective'), ('.', 'Punctuation'), ('연구자', 'Noun'), ('는', 'Josa'), ('크게', 'Noun'), ('아래', 'Noun'), ('와', 'Josa'), ('같은', 'Adjective'), ('분야', 'Noun'), ('의', 'Josa'), ('업무', 'Noun'), ('에서', 'Josa'), ('일', 'Noun'), ('하게', 'Verb'), ('됩니다', 'Verb'), ('.', 'Punctuation'), ('1', 'Number'), (')', 'Punctuation'), ('AI', 'Alpha'), ('분야', 'Noun'), ('-', 'Punctuation'), ('설비', 'Noun'), ('모델링', 'Noun'), (',', 'Punctuation'), ('제어', 'Noun'), ('등', 'Noun'), ('2', 'Number'), (')', 'Punctuation'), ('소프트웨어', 'Noun'), ('분야', 'Noun'), ('-', 'Punctuation'), ('플랫폼', 'Noun'), ('소프트웨어', 'Noun'), ('개발', 'Noun'), (',', 'Punctuation'), ('chat', 'Alpha'), ('GPT', 'Alpha'), ('연동', 'Noun'), ('등', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation'), ('AI', 'Alpha'), ('/', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('클라우드', 'Noun'), ('인프라', 'Noun'), ('클러스터', 'Noun'), ('구성', 'Noun'), ('및', 'Noun'), ('운영', 'Noun'), ('-', 'Punctuation'), ('AI', 'Alpha'), ('/', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('클라우드', 'Noun'), ('아키텍처', 'Noun'), ('설계', 'Noun'), ('및', 'Noun'), ('구축', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation'), ('AI', 'Alpha'), ('/', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('클라우드', 'Noun'), ('관련', 'Noun'), ('비즈니스', 'Noun'), ('모델', 'Noun'), ('발굴', 'Noun'), ('-', 'Punctuation'), ('AI', 'Alpha'), ('/', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('클라우드', 'Noun'), ('과제', 'Noun'), ('관리', 'Noun'), ('및', 'Noun'), ('팀', 'Noun'), ('운영', 'Noun')]
# --------------------------------------------------------------------------------
# [('안녕하세요', 'Adjective'), (',', 'Punctuation'), ('AI', 'Alpha'), ('인프라', 'Noun'), ('소프트웨어', 'Noun'), ('를', 'Josa'), ('개발', 'Noun'), ('하고', 'Josa'), ('있는', 'Adjective'), ('주식회사', 'Noun'), ('MOREH', 'Alpha'), ('입니다', 'Adjective'), ('.', 'Punctuation'), ('모레', 'Noun'), ('는', 'Josa'), ('강남역', 'Noun'), ('에', 'Josa'), ('위치', 'Noun'), ('하고', 'Josa'), ('있으며', 'Adjective'), ('현재', 'Noun'), ('구성원', 'Noun'), ('은', 'Josa'), ('약', 'Noun'), ('75', 'Number'), ('명', 'Noun'), ('입니다', 'Adjective'), ('.', 'Punctuation'), ('대부분', 'Noun'), ('개발', 'Noun'), ('조직', 'Noun'), ('으로', 'Josa'), ('구성', 'Noun'), ('되어', 'Verb'), ('있으며', 'Adjective'), ('AI', 'Alpha'), ('분야', 'Noun'), ('의', 'Josa'), ('뛰어난', 'Adjective'), ('동료', 'Noun'), ('들', 'Suffix'), ('과', 'Josa'), ('함께', 'Adverb'), ('일', 'Noun'), ('하고', 'Josa'), ('있습니다', 'Adjective'), ('.', 'Punctuation'), ('모레', 'Noun'), ('에서', 'Josa'), ('상반기', 'Noun'), ('경력', 'Noun'), ('&', 'Punctuation'), ('전', 'Modifier'), ('문', 'Modifier'), ('연', 'Modifier'), ('구', 'Modifier'), ('요원', 'Noun'), ('채용', 'Noun'), ('을', 'Josa'), ('진행', 'Noun'), ('하고', 'Josa'), ('있으니', 'Adjective'), ('많은', 'Adjective'), ('관심', 'Noun'), ('바랍니다', 'Verb'), ('.', 'Punctuation'), ('-', 'Punctuation'), ('Backend', 'Alpha'), ('엔지니어', 'Noun'), ('-', 'Punctuation'), ('Compiler', 'Alpha'), ('엔지니어', 'Noun'), ('-', 'Punctuation'), ('GPU', 'Alpha'), ('소프트웨어', 'Noun'), ('엔지니어', 'Noun'), ('-', 'Punctuation'), ('Sys', 'Alpha'), ('Ops', 'Alpha'), ('엔지니어', 'Noun'), ('-', 'Punctuation'), ('System', 'Alpha'), ('소프트웨어', 'Noun'), ('엔지니어', 'Noun'), ('Moreh', 'Alpha'), ('에', 'Josa'), ('대한', 'Noun'), ('소개', 'Noun'), ('와', 'Josa'), ('지', 'Modifier'), ('원', 'Modifier'), ('방법', 'Noun'), ('은', 'Josa'), ('노션', 'Noun'), ('채용', 'Noun'), ('사이트', 'Noun'), ('를', 'Josa'), ('통해', 'Noun'), ('확인', 'Noun'), ('해주세요', 'Verb'), ('.', 'Punctuation'), ('(https://www.notion.so/moreh/Moreh-Careers-04b1430ade34474495ed5ed9475108a9', 'URL'), (')', 'Punctuation'), ('지원', 'Noun'), ('과', 'Josa'), ('관련', 'Noun'), ('하여', 'Verb'), ('문의사항', 'Noun'), ('이', 'Josa'), ('있는', 'Adjective'), ('경우', 'Noun'), (',', 'Punctuation'), ('노션', 'Noun'), ('채용', 'Noun'), ('페이지', 'Noun'), ('를', 'Josa'), ('통해', 'Noun'), ('연락', 'Noun'), ('주세요', 'Verb'), (':)', 'Punctuation'), ('감사합니다', 'Verb'), ('.', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('[', 'Punctuation'), ('주요', 'Modifier'), ('업무', 'Noun'), (']', 'Punctuation'), ('-', 'Punctuation'), ('해상', 'Noun'), ('선박', 'Noun'), ('빅데이터', 'Noun'), ('분석', 'Noun'), ('및', 'Noun'), ('AI', 'Alpha'), ('모델', 'Noun'), ('개발', 'Noun'), ('-', 'Punctuation'), ('Pattern', 'Alpha'), ('Recognition', 'Alpha'), (',', 'Punctuation'), ('Classification', 'Alpha'), (',', 'Punctuation'), ('Prediction', 'Alpha'), ('[', 'Punctuation'), ('자격', 'Noun'), ('요건', 'Noun'), (']', 'Punctuation'), ('-', 'Punctuation'), ('Machine', 'Alpha'), ('Learning', 'Alpha'), ('기반', 'Noun'), ('풍부한', 'Adjective'), ('지식', 'Noun'), ('-', 'Punctuation'), ('Deep', 'Alpha'), ('Learning', 'Alpha'), ('framework', 'Alpha'), ('(', 'Punctuation'), ('Tensorflow', 'Alpha'), (',', 'Punctuation'), ('Keras', 'Alpha'), (',', 'Punctuation'), ('PyTorch', 'Alpha'), (',', 'Punctuation'), ('Python', 'Alpha'), ('등', 'Noun'), (')', 'Punctuation'), ('기반', 'Noun'), ('개발', 'Noun'), ('경험', 'Noun'), ('-', 'Punctuation'), ('Pattern', 'Alpha'), ('Recognition', 'Alpha'), (',', 'Punctuation'), ('Classification', 'Alpha'), (',', 'Punctuation'), ('Prediction', 'Alpha'), ('AI', 'Alpha'), ('모델', 'Noun'), ('개발', 'Noun'), ('경험', 'Noun'), ('-', 'Punctuation'), ('빅데이터', 'Noun'), ('분석', 'Noun'), ('및', 'Noun'), ('AI', 'Alpha'), ('관련', 'Noun'), ('경력', 'Noun'), ('5년', 'Number'), ('이상인', 'Noun'), ('분', 'Noun'), ('[', 'Punctuation'), ('우대', 'Noun'), ('사항', 'Noun'), (']', 'Punctuation'), ('-', 'Punctuation'), ('NIPS', 'Alpha'), (',', 'Punctuation'), ('ICML', 'Alpha'), (',', 'Punctuation'), ('CVPR', 'Alpha'), ('등', 'Noun'), ('최고', 'Noun'), ('수준', 'Noun'), ('국제', 'Noun'), ('학회', 'Noun'), ('논문', 'Noun'), ('게재', 'Noun'), ('경험', 'Noun'), ('-', 'Punctuation'), ('박사', 'Noun'), ('학위', 'Noun'), ('또는', 'Adverb'), ('선진', 'Noun'), ('기업', 'Noun'), ('/', 'Punctuation'), ('연구기관', 'Noun'), ('에서의', 'Josa'), ('연구', 'Noun'), ('개발', 'Noun'), ('경험', 'Noun'), ('-', 'Punctuation'), ('최적화', 'Noun'), (',', 'Punctuation'), ('경량', 'Noun'), ('화', 'Suffix'), ('등', 'Noun'), ('성능', 'Noun'), ('개선', 'Noun'), ('을', 'Josa'), ('위', 'Noun'), ('한', 'Josa'), ('모델링', 'Noun'), ('경험', 'Noun'), ('[', 'Punctuation'), ('직급', 'Noun'), (']', 'Punctuation'), ('과장', 'Noun'), ('~', 'Punctuation'), ('부장', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('그래픽디자인', 'Noun'), ('/', 'Punctuation'), ('CG', 'Alpha'), (',', 'Punctuation'), ('동영상', 'Noun'), ('제작', 'Noun'), ('/', 'Punctuation'), ('편집', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('응용프로그램', 'Noun'), ('개발', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('경력', 'Noun'), ('-', 'Punctuation'), ('AI', 'Alpha'), ('/', 'Punctuation'), ('빅데이터', 'Noun'), ('-', 'Punctuation'), ('컨설팅', 'Noun'), ('-', 'Punctuation'), ('서울', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('전기', 'Noun'), ('/', 'Punctuation'), ('전자', 'Noun'), ('/', 'Punctuation'), ('제어', 'Noun'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('응용프로그램', 'Noun'), ('개발', 'Noun'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation'), ('생', 'Noun'), ('성형', 'Noun'), ('AI', 'Alpha'), ('연구개발', 'Noun'), ('-', 'Punctuation'), ('솔루션', 'Noun'), ('적용', 'Noun'), ('연구개발', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('마케팅', 'Noun'), ('/', 'Punctuation'), ('PR', 'Alpha'), ('/', 'Punctuation'), ('분석', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('게임', 'Noun'), (',', 'Punctuation'), ('그래픽디자인', 'Noun'), ('/', 'Punctuation'), ('CG', 'Alpha'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('ㆍ', 'Foreign'), ('코딩', 'Noun'), ('관련', 'Noun'), ('교육', 'Noun'), ('컨텐츠', 'Noun'), ('기획', 'Noun'), (',', 'Punctuation'), ('개발', 'Noun'), ('ㆍ', 'Foreign'), ('학교', 'Noun'), (',', 'Punctuation'), ('기관', 'Noun'), ('파견', 'Noun'), ('AI', 'Alpha'), ('관련', 'Noun'), ('수업', 'Noun'), ('진행', 'Noun')]
# --------------------------------------------------------------------------------
# [('지원', 'Noun'), ('자격', 'Noun'), ('·', 'Punctuation'), ('학력', 'Noun'), (':', 'Punctuation'), ('학력', 'Noun'), ('무관', 'Noun'), ('·', 'Punctuation'), ('경력', 'Noun'), (':', 'Punctuation'), ('신입', 'Noun'), ('담당', 'Noun'), ('업무', 'Noun'), ('·', 'Punctuation'), ('정부', 'Noun'), ('사업', 'Noun'), ('관리', 'Noun'), ('및', 'Noun'), ('기획', 'Noun'), ('·', 'Punctuation'), ('고객', 'Noun'), ('분석', 'Noun'), ('및', 'Noun'), ('Needs', 'Alpha'), ('도출', 'Noun'), ('·', 'Punctuation'), ('자사', 'Noun'), ('서비스', 'Noun'), ('및', 'Noun'), ('솔루션', 'Noun'), ('기획', 'Noun'), ('&', 'Punctuation'), ('운영', 'Noun'), ('전략', 'Noun'), ('수립', 'Noun'), ('·', 'Punctuation'), ('다양한', 'Adjective'), ('관계자', 'Noun'), ('와의', 'Josa'), ('협업', 'Noun'), ('수행', 'Noun'), ('우대', 'Noun'), ('사항', 'Noun'), ('ㆍ', 'Foreign'), ('정부', 'Noun'), ('지원', 'Noun'), ('사업', 'Noun'), ('수행', 'Noun'), ('이력', 'Noun'), ('등', 'Noun'), ('유관', 'Noun'), ('업무', 'Noun'), ('경력', 'Noun'), ('자', 'Suffix'), ('ㆍ', 'Foreign'), ('스마트', 'Noun'), ('팩토리', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), ('에', 'Josa'), ('대한', 'Noun'), ('이해', 'Noun'), ('와', 'Josa'), ('경험', 'Noun'), ('ㆍ', 'Foreign'), ('공학', 'Noun'), ('계열', 'Noun'), ('ㆍ', 'Foreign'), ('문서', 'Noun'), ('작성', 'Noun'), ('우수', 'Noun'), ('자', 'Suffix'), (',', 'Punctuation'), ('컴퓨터', 'Noun'), ('활용', 'Noun'), ('능력', 'Noun'), ('우수', 'Noun'), (',', 'Punctuation'), ('PPT', 'Alpha'), ('능력', 'Noun'), ('우수', 'Noun'), ('자', 'Suffix'), (',', 'Punctuation'), ('엑셀', 'Noun'), ('고급', 'Noun'), ('능력자', 'Noun')]
# --------------------------------------------------------------------------------
# [('우리', 'Noun'), ('직업', 'Noun'), ('학교', 'Noun'), ('에서', 'Josa'), ('유능한', 'Adjective'), ('강사', 'Noun'), ('님', 'Suffix'), ('을', 'Josa'), ('모집', 'Noun'), ('합니다', 'Verb'), ('.', 'Punctuation'), ('자격', 'Noun'), ('조건', 'Noun'), (':', 'Punctuation'), ('AI', 'Alpha'), ('관련', 'Noun'), ('또는', 'Adverb'), ('정보', 'Noun'), ('관련', 'Noun'), ('직종', 'Noun'), ('우대', 'Noun'), (':', 'Punctuation'), ('강의', 'Noun'), ('경력', 'Noun'), ('1년', 'Number'), ('이상', 'Foreign'), ('급여', 'Noun'), (':', 'Punctuation'), ('강의', 'Noun'), ('는', 'Josa'), ('1일', 'Number'), ('최대', 'Noun'), ('5시간', 'Number'), ('가능', 'Noun'), ('시간', 'Noun'), ('당', 'Suffix'), ('경력', 'Noun'), ('사항', 'Noun'), ('에', 'Josa'), ('따라', 'Verb'), ('협의', 'Noun'), ('근무시간', 'Noun'), (':', 'Punctuation'), ('주', 'Noun'), ('5일', 'Number'), ('시간', 'Noun'), ('은', 'Josa'), ('협의', 'Noun'), ('가능', 'Noun'), ('(', 'Punctuation'), ('현재', 'Noun'), ('요일', 'Noun'), ('등록', 'Noun'), ('제로', 'Noun'), ('시간표', 'Noun'), ('편성', 'Noun'), (')', 'Punctuation'), ('(', 'Punctuation'), ('상시', 'Noun'), ('근무', 'Noun'), (')', 'Punctuation'), ('8시간', 'Number'), ('강의', 'Noun'), ('내용', 'Noun'), (':', 'Punctuation'), ('쳇', 'Exclamation'), ('GTP', 'Alpha'), ('활용', 'Noun'), ('하여', 'Verb'), ('스', 'Noun'), ('테이블', 'Noun'), ('디', 'Noun'), ('퓨전', 'Noun'), (',', 'Punctuation'), ('DALL', 'Alpha'), ('·', 'Punctuation'), ('E', 'Alpha'), ('2', 'Number'), ('이미지', 'Noun'), ('만드는', 'Verb'), ('방법', 'Noun'), ('면접', 'Noun'), ('시', 'Noun'), (':', 'Punctuation'), ('이력서', 'Noun'), (',', 'Punctuation'), ('경력', 'Noun'), ('증명서', 'Noun'), (',', 'Punctuation'), ('자격증', 'Noun'), ('사본', 'Noun'), (',', 'Punctuation'), ('졸업', 'Noun'), ('증명서', 'Noun'), ('(', 'Punctuation'), ('관련', 'Noun'), ('자격증', 'Noun'), ('서류', 'Noun'), ('만', 'Josa'), ('제출', 'Noun'), (')', 'Punctuation'), ('(', 'Punctuation'), ('사진', 'Noun'), ('X', 'Alpha'), (')', 'Punctuation'), ('이메일', 'Noun'), ('접수', 'Noun'), (':', 'Punctuation'), ('hongsi888@naver.com', 'Email'), ('다산', 'Noun'), ('홈페이지', 'Noun'), (':', 'Punctuation'), ('http://www.gosigate.com/', 'URL'), ('수업', 'Noun'), ('시간', 'Noun'), (':', 'Punctuation'), ('오전', 'Noun'), ('타임', 'Noun'), ('09:30', 'Number'), ('~', 'Punctuation'), ('12:30', 'Number'), ('오후', 'Noun'), ('타임', 'Noun'), ('13:00', 'Number'), ('~', 'Punctuation'), ('18:00', 'Number'), ('야간', 'Noun'), ('타임', 'Noun'), ('19:00', 'Number'), ('~', 'Punctuation'), ('22:00', 'Number'), ('자세한', 'Adjective'), ('사항', 'Noun'), ('은', 'Josa'), (':', 'Punctuation'), ('032-439', 'Number'), ('-', 'Punctuation'), ('1127', 'Number'), ('문의', 'Noun'), ('부탁드립니다', 'Adjective'), ('.', 'Punctuation'), ('4', 'Number'), ('대', 'Verb'), ('보험', 'Noun'), ('의무', 'Noun'), ('가입', 'Noun'), ('합니다', 'Verb'), ('.', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('연구개발', 'Noun'), ('부문', 'Noun'), ('-', 'Punctuation'), ('하드웨어', 'Noun'), ('개발', 'Noun'), ('경력', 'Noun'), ('자', 'Suffix'), ('-', 'Punctuation'), ('AI', 'Alpha'), ('딥', 'Noun'), ('러닝', 'Noun'), ('개발', 'Noun'), ('경력', 'Noun'), ('자', 'Suffix'), ('-', 'Punctuation'), ('외국인', 'Noun'), ('지원', 'Noun'), ('가능', 'Noun'), ('*', 'Punctuation'), ('전기', 'Noun'), ('/', 'Punctuation'), ('전자공학', 'Noun'), ('우대', 'Noun'), ('*', 'Punctuation'), ('이력서', 'Noun'), ('확인', 'Noun'), ('후', 'Noun'), ('서류', 'Noun'), ('합격자', 'Noun'), ('에', 'Josa'), ('개별', 'Noun'), ('연락', 'Noun'), ('드리오니', 'Verb'), ('회사', 'Noun'), ('로', 'Josa'), ('전화', 'Noun'), ('삼가', 'Verb'), ('부탁드립니다', 'Adjective'), ('.', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('<', 'Punctuation'), ('주요', 'Modifier'), ('업무', 'Noun'), ('>', 'Punctuation'), ('-', 'Punctuation'), ('인공', 'Noun'), ('지능', 'Noun'), ('알고리즘', 'Noun'), ('개발', 'Noun'), ('및', 'Noun'), ('연구', 'Noun'), ('-', 'Punctuation'), ('인공', 'Noun'), ('지능', 'Noun'), ('서비스', 'Noun'), ('솔루션', 'Noun'), ('개발', 'Noun'), ('-', 'Punctuation'), ('Vision', 'Alpha'), ('/', 'Punctuation'), ('Time', 'Alpha'), ('Series', 'Alpha'), ('/', 'Punctuation'), ('NLP', 'Alpha'), ('데이터', 'Noun'), ('처리', 'Noun'), ('및', 'Noun'), ('분석', 'Noun'), ('<', 'Punctuation'), ('우대', 'Noun'), ('사항', 'Noun'), ('>', 'Punctuation'), ('-', 'Punctuation'), ('전반', 'Noun'), ('적', 'Suffix'), ('인', 'Josa'), ('AI', 'Alpha'), ('기술', 'Noun'), ('에', 'Josa'), ('대한', 'Noun'), ('이해', 'Noun'), ('가', 'Josa'), ('있으신', 'Adjective'), ('분', 'Noun'), ('-', 'Punctuation'), ('Vision', 'Alpha'), ('/', 'Punctuation'), ('Time', 'Alpha'), ('Series', 'Alpha'), ('/', 'Punctuation'), ('NLP', 'Alpha'), ('딥', 'Noun'), ('러닝', 'Noun'), ('모델', 'Noun'), ('에', 'Josa'), ('대한', 'Noun'), ('이해', 'Noun'), ('및', 'Noun'), ('학습', 'Noun'), ('경험', 'Noun'), ('-', 'Punctuation'), ('딥', 'Noun'), ('러닝', 'Noun'), ('프레임워크', 'Noun'), ('(', 'Punctuation'), ('Pytorch', 'Alpha'), (',', 'Punctuation'), ('Tensorflow', 'Alpha'), ('등', 'Noun'), (')', 'Punctuation'), ('사용', 'Noun'), ('-', 'Punctuation'), ('데이터', 'Noun'), ('를', 'Josa'), ('분석', 'Noun'), ('하', 'Suffix'), ('거나', 'Noun'), ('모델링', 'Noun'), ('을', 'Josa'), ('통해', 'Noun'), ('결과', 'Noun'), ('를', 'Josa'), ('도출', 'Noun'), ('해낸', 'Verb'), ('경험', 'Noun'), ('이', 'Josa'), ('있으신', 'Adjective'), ('분', 'Noun'), ('*', 'Punctuation'), ('서류', 'Noun'), ('전형', 'Noun'), ('합격자', 'Noun'), ('에', 'Josa'), ('한하여', 'Verb'), ('면접', 'Noun'), ('일정', 'Noun'), ('별도', 'Noun'), ('안', 'VerbPrefix'), ('내', 'VerbPrefix'), ('드립니다', 'Verb'), ('.', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('지원', 'Noun'), ('자격', 'Noun'), ('·', 'Punctuation'), ('학력', 'Noun'), (':', 'Punctuation'), ('학사', 'Noun'), ('학위', 'Noun'), ('이상', 'Noun'), ('·', 'Punctuation'), ('경력', 'Noun'), (':', 'Punctuation'), ('무관', 'Noun'), ('(', 'Punctuation'), ('신입', 'Noun'), ('도', 'Josa'), ('지원', 'Noun'), ('가능', 'Noun'), (')', 'Punctuation'), ('필수', 'Noun'), ('사항', 'Noun'), ('·', 'Punctuation'), ('Visual', 'Alpha'), ('Studio', 'Alpha'), ('C', 'Alpha'), ('/', 'Punctuation'), ('C', 'Alpha'), ('++', 'Punctuation'), ('프로그래밍', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), ('담당', 'Noun'), ('업무', 'Noun'), ('·', 'Punctuation'), ('검사', 'Noun'), ('알고리즘', 'Noun'), ('개발', 'Noun'), ('(', 'Punctuation'), ('C', 'Alpha'), ('++)', 'Punctuation'), ('·', 'Punctuation'), ('검사', 'Noun'), ('장비', 'Noun'), ('UI', 'Alpha'), ('개발', 'Noun'), ('(', 'Punctuation'), ('C', 'Alpha'), ('#)', 'Punctuation'), ('·', 'Punctuation'), ('데이터', 'Noun'), ('셋', 'Noun'), ('관리', 'Noun'), ('우대', 'Noun'), ('사항', 'Noun'), ('·', 'Punctuation'), ('C', 'Alpha'), ('/', 'Punctuation'), ('C', 'Alpha'), ('++', 'Punctuation'), ('활용', 'Noun'), ('/', 'Punctuation'), ('분석', 'Noun'), ('/', 'Punctuation'), ('코딩', 'Noun'), ('/', 'Punctuation'), ('디버깅', 'Noun'), ('능력', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('·', 'Punctuation'), ('OpenCV', 'Alpha'), ('활용', 'Noun'), ('및', 'Noun'), ('영', 'Modifier'), ('상처리', 'Noun'), ('기술', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('·', 'Punctuation'), ('임베디드', 'Noun'), ('시스템', 'Noun'), ('펌웨어', 'Noun'), ('개발', 'Noun'), ('경험', 'Noun'), ('·', 'Punctuation'), ('DeepLearning', 'Alpha'), (',', 'Punctuation'), ('Object', 'Alpha'), ('Detection', 'Alpha'), (',', 'Punctuation'), ('Darknet', 'Alpha'), (',', 'Punctuation'), ('Tensorflow', 'Alpha'), ('등', 'Noun'), ('Computer', 'Alpha'), ('Vision', 'Alpha'), ('관련', 'Noun'), ('지식', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('·', 'Punctuation'), ('C', 'Alpha'), ('#', 'Punctuation'), ('Winform', 'Alpha'), ('기반', 'Noun'), ('사용자', 'Noun'), ('UI', 'Alpha'), ('개발', 'Noun'), ('경험', 'Noun'), ('·', 'Punctuation'), ('Object', 'Alpha'), ('Detection', 'Alpha'), ('관련', 'Noun'), ('최신', 'Noun'), ('논문', 'Noun'), ('기술', 'Noun'), ('구현', 'Noun'), ('가능', 'Noun'), ('자', 'Suffix'), ('·', 'Punctuation'), ('컴퓨터공학', 'Noun'), (',', 'Punctuation'), ('응용소프트웨어', 'Noun'), ('공학', 'Noun'), (',', 'Punctuation'), ('정보', 'Noun'), ('·', 'Punctuation'), ('통신공학', 'Noun'), (',', 'Punctuation'), ('전자공학', 'Noun'), (',', 'Punctuation'), ('물리학', 'Noun'), (',', 'Punctuation'), ('광학', 'Noun'), ('전공자', 'Noun')]
# --------------------------------------------------------------------------------
# [('[', 'Punctuation'), ('공통', 'Noun'), ('자격', 'Noun'), ('요건', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('학력', 'Noun'), ('/', 'Punctuation'), ('성별', 'Noun'), (':', 'Punctuation'), ('무관', 'Noun'), ('ㆍ', 'Foreign'), ('경력', 'Noun'), (':', 'Punctuation'), ('경력', 'Noun'), ('(', 'Punctuation'), ('1년', 'Number'), ('이상', 'Noun'), ('또는', 'Adverb'), ('동등', 'Noun'), ('이상', 'Noun'), ('개발', 'Noun'), ('이력', 'Noun'), (')', 'Punctuation'), ('ㆍ', 'Foreign'), ('수습', 'Noun'), (':', 'Punctuation'), ('3', 'Number'), ('개월', 'Noun'), ('[', 'Punctuation'), ('담당', 'Noun'), ('업무', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('인공', 'Noun'), ('지능', 'Noun'), ('알고리즘', 'Noun'), ('개발', 'Noun'), ('[', 'Punctuation'), ('자격', 'Noun'), ('요건', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('Linux', 'Alpha'), (',', 'Punctuation'), ('Windows', 'Alpha'), ('환경', 'Noun'), ('에서', 'Josa'), ('어플리케이션', 'Noun'), ('설계', 'Noun'), ('및', 'Noun'), ('개발', 'Noun'), ('ㆍ', 'Foreign'), ('Python', 'Alpha'), ('언어', 'Noun'), ('개발', 'Noun'), ('가능', 'Noun'), ('자', 'Suffix'), ('ㆍ', 'Foreign'), ('인공', 'Noun'), ('지능', 'Noun'), ('모델', 'Noun'), ('개발', 'Noun'), ('에', 'Josa'), ('필요한', 'Adjective'), ('기술', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('[', 'Punctuation'), ('우대', 'Noun'), ('사항', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('인공', 'Noun'), ('지능', 'Noun'), ('모델', 'Noun'), ('서비스', 'Noun'), ('화', 'Suffix'), ('경험', 'Noun'), ('이', 'Josa'), ('있으신', 'Adjective'), ('분', 'Noun'), ('ㆍ', 'Foreign'), ('인공', 'Noun'), ('지능', 'Noun'), ('관련', 'Noun'), ('학과', 'Noun'), ('석', 'Modifier'), ('박사', 'Noun'), ('우대', 'Noun'), ('ㆍ', 'Foreign'), ('열린', 'Verb'), ('마음', 'Noun'), ('으로', 'Josa'), ('목표', 'Noun'), ('를', 'Josa'), ('위', 'Noun'), ('한', 'Josa'), ('원활한', 'Adjective'), ('커뮤니케이션', 'Noun'), ('을', 'Josa'), ('즐기시는', 'Verb'), ('분', 'Noun'), ('ㆍ', 'Foreign'), ('Git', 'Alpha'), ('-', 'Punctuation'), ('hub', 'Alpha'), ('주소', 'Noun'), (',', 'Punctuation'), ('개발', 'Noun'), ('포트폴리오', 'Noun'), ('제출', 'Noun'), ('이', 'Josa'), ('가능하신', 'Adjective'), ('분', 'Noun'), ('[', 'Punctuation'), ('복리', 'Noun'), ('후생', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('모든', 'Noun'), ('임', 'Noun'), ('직원', 'Noun'), ('통신비', 'Noun'), ('제공', 'Noun'), ('ㆍ', 'Foreign'), ('모든', 'Noun'), ('임', 'Noun'), ('직원', 'Noun'), ('중식', 'Noun'), ('제공', 'Noun'), ('ㆍ', 'Foreign'), ('명절', 'Noun'), ('(', 'Punctuation'), ('설', 'Noun'), ('/', 'Punctuation'), ('추석', 'Noun'), (')', 'Punctuation'), ('선물', 'Noun'), ('지급', 'Noun'), ('ㆍ', 'Foreign'), ('경', 'Modifier'), ('조금', 'Noun'), ('지원', 'Noun'), ('ㆍ', 'Foreign'), ('야근', 'Noun'), ('시', 'Noun'), ('식대', 'Noun'), ('지원', 'Noun'), ('ㆍ', 'Foreign'), ('출퇴근시간', 'Noun'), ('유연근무제', 'Noun'), ('시행', 'Noun'), ('ㆍ', 'Foreign'), ('자율', 'Noun'), ('적', 'Suffix'), ('인', 'Josa'), ('휴가', 'Noun'), ('사용', 'Noun'), ('(', 'Punctuation'), ('연차', 'Noun'), (',', 'Punctuation'), ('반', 'Modifier'), ('차', 'Noun'), ('등', 'Noun'), (')', 'Punctuation'), ('*', 'Punctuation'), ('회사', 'Noun'), ('성장', 'Noun'), ('에', 'Josa'), ('따라', 'Verb'), ('복리', 'Noun'), ('후생', 'Noun'), ('추가', 'Noun'), ('예정', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('데이터', 'Noun'), ('수집', 'Noun'), (',', 'Punctuation'), ('정제', 'Noun'), ('데이터', 'Noun'), ('분석', 'Noun'), ('인공', 'Noun'), ('지능', 'Noun'), ('개발', 'Noun'), ('논문', 'Noun'), ('연구', 'Noun')]
# --------------------------------------------------------------------------------
# [('사업', 'Noun'), ('계획', 'Noun'), ('서', 'Josa'), ('작성', 'Noun'), ('및', 'Noun'), ('관리', 'Noun'), ('문서', 'Noun'), ('작성', 'Noun'), ('경영', 'Noun'), ('전략', 'Noun'), ('마케팅', 'Noun'), ('전략', 'Noun'), ('기타', 'Noun'), ('행정', 'Noun'), ('업무', 'Noun'), ('[', 'Punctuation'), ('경', 'Modifier'), ('영기획', 'Noun'), ('>', 'Punctuation'), ('사업', 'Noun'), ('환경', 'Noun'), ('분석', 'Noun'), (']', 'Punctuation'), ('내부', 'Noun'), ('환경', 'Noun'), ('분석', 'Noun'), ('하기', 'Verb'), (',', 'Punctuation'), ('외부', 'Noun'), ('환경', 'Noun'), ('분석', 'Noun'), ('하기', 'Verb'), (',', 'Punctuation'), ('핵심', 'Noun'), ('성공', 'Noun'), ('요소', 'Noun'), ('도출', 'Noun'), ('하기', 'Verb'), ('[', 'Punctuation'), ('경', 'Modifier'), ('영기획', 'Noun'), ('>', 'Punctuation'), ('경영', 'Noun'), ('계획', 'Noun'), ('수립', 'Noun'), (']', 'Punctuation'), ('전략', 'Noun'), ('방향', 'Noun'), ('수립', 'Noun'), ('하기', 'Verb'), (',', 'Punctuation'), ('경영', 'Noun'), ('목표', 'Noun'), ('수립', 'Noun'), ('하기', 'Verb'), (',', 'Punctuation'), ('사업', 'Noun'), ('계획', 'Noun'), ('수립', 'Noun'), ('하기', 'Verb'), (',', 'Punctuation'), ('사업', 'Noun'), ('별', 'Noun'), ('경영', 'Noun'), ('계획', 'Noun'), ('조정', 'Noun'), ('하기', 'Verb'), ('[', 'Punctuation'), ('경', 'Modifier'), ('영기획', 'Noun'), ('>', 'Punctuation'), ('신규', 'Noun'), ('사업', 'Noun'), ('기획', 'Noun'), (']', 'Punctuation'), ('신규', 'Noun'), ('사업', 'Noun'), ('아이템', 'Noun'), ('발굴', 'Noun'), ('하기', 'Verb'), (',', 'Punctuation'), ('신규', 'Noun'), ('사업', 'Noun'), ('타당성', 'Noun'), ('검토', 'Noun'), ('하기', 'Verb'), (',', 'Punctuation'), ('신규', 'Noun'), ('사업', 'Noun'), ('투자', 'Noun'), ('계획', 'Noun'), ('수립', 'Noun'), ('하기', 'Verb'), (',', 'Punctuation'), ('신규', 'Noun'), ('사업', 'Noun'), ('성과', 'Noun'), ('평가', 'Noun'), ('하기', 'Verb')]
# --------------------------------------------------------------------------------
# [('1', 'Number'), ('.', 'Punctuation'), ('채용', 'Noun'), ('포지션', 'Noun'), (':', 'Punctuation'), ('솔루션', 'Noun'), ('영업', 'Noun'), ('총괄', 'Noun'), ('2', 'Number'), ('.', 'Punctuation'), ('담당', 'Noun'), ('업무', 'Noun'), (':', 'Punctuation'), ('-', 'Punctuation'), ('SI', 'Alpha'), ('기술', 'Noun'), ('영업', 'Noun'), ('팀', 'Noun'), ('총괄', 'Noun'), ('로', 'Josa'), ('SI', 'Alpha'), ('솔루션', 'Noun'), ('의', 'Josa'), ('기술', 'Noun'), ('적', 'Suffix'), ('영업', 'Noun'), ('-', 'Punctuation'), ('금융', 'Noun'), ('권', 'Suffix'), (',', 'Punctuation'), ('통신사', 'Noun'), ('등', 'Noun'), ('의', 'Josa'), ('고객', 'Noun'), ('사', 'Noun'), ('대상', 'Noun'), ('신규', 'Noun'), ('SI', 'Alpha'), ('(', 'Punctuation'), ('AI', 'Alpha'), (')', 'Punctuation'), ('제안', 'Noun'), ('및', 'Noun'), ('시장', 'Noun'), ('확대', 'Noun'), ('를', 'Josa'), ('위', 'Noun'), ('한', 'Josa'), ('세', 'Modifier'), ('일', 'Modifier'), ('즈', 'Modifier'), ('전략', 'Noun'), ('수립', 'Noun'), ('3', 'Number'), ('.', 'Punctuation'), ('자격', 'Noun'), ('요건', 'Noun'), ('-', 'Punctuation'), ('대졸', 'Noun'), ('이상', 'Noun'), ('-', 'Punctuation'), ('SI', 'Alpha'), (',', 'Punctuation'), ('AI', 'Alpha'), ('등', 'Noun'), ('의', 'Josa'), ('통신', 'Noun'), ('소프트웨어', 'Noun'), ('영업', 'Noun'), ('업무', 'Noun'), ('경력', 'Noun'), ('15년', 'Number'), ('이상', 'Noun'), ('4', 'Number'), ('.', 'Punctuation'), ('우대', 'Noun'), ('사항', 'Noun'), ('-', 'Punctuation'), ('AI', 'Alpha'), ('솔루션', 'Noun'), ('망구', 'Noun'), ('성', 'Suffix'), ('설계', 'Noun'), ('또는', 'Adverb'), ('개발', 'Noun'), ('에', 'Josa'), ('대한', 'Noun'), ('이해', 'Noun'), ('-', 'Punctuation'), ('AI', 'Alpha'), ('솔루션', 'Noun'), ('(', 'Punctuation'), ('Voice', 'Alpha'), ('G', 'Alpha'), ('/', 'Punctuation'), ('W', 'Alpha'), (',', 'Punctuation'), ('STT', 'Alpha'), (',', 'Punctuation'), ('TTS', 'Alpha'), (',', 'Punctuation'), ('SOE', 'Alpha'), (',', 'Punctuation'), ('NLP', 'Alpha'), ('등', 'Noun'), (')', 'Punctuation'), ('상품', 'Noun'), ('이해', 'Noun'), ('와', 'Josa'), ('영업', 'Noun'), ('경험', 'Noun'), ('-', 'Punctuation'), ('관련', 'Noun'), ('전공', 'Noun'), ('석사', 'Noun'), ('이상', 'Noun')]
# --------------------------------------------------------------------------------
# [('1', 'Number'), ('.', 'Punctuation'), ('채용', 'Noun'), ('부문', 'Noun'), (':', 'Punctuation'), ('유명', 'Noun'), ('상', 'Suffix'), ('장사', 'Noun'), ('-', 'Punctuation'), ('R', 'Alpha'), ('&', 'Punctuation'), ('D', 'Alpha'), ('연구', 'Noun'), ('기획', 'Noun'), ('부문', 'Noun'), ('채용', 'Noun'), ('(', 'Punctuation'), ('5년', 'Number'), ('-', 'Punctuation'), ('10년', 'Number'), ('경력', 'Noun'), ('자', 'Suffix'), (')', 'Punctuation'), ('2', 'Number'), ('.', 'Punctuation'), ('담당', 'Noun'), ('업무', 'Noun'), ('-', 'Punctuation'), ('R', 'Alpha'), ('&', 'Punctuation'), ('D', 'Alpha'), ('과제', 'Noun'), ('연구', 'Noun'), ('제안', 'Noun'), ('서', 'Josa'), ('작성', 'Noun'), ('-', 'Punctuation'), ('연구', 'Noun'), ('과제', 'Noun'), ('관리', 'Noun'), ('및', 'Noun'), ('보고', 'Noun'), ('-', 'Punctuation'), ('정부', 'Noun'), ('기관', 'Noun'), ('관련', 'Noun'), ('업무', 'Noun'), ('대응', 'Noun'), ('3', 'Number'), ('.', 'Punctuation'), ('자격', 'Noun'), ('요건', 'Noun'), ('-', 'Punctuation'), ('학사', 'Noun'), ('이상', 'Noun'), ('(', 'Punctuation'), ('컴퓨터', 'Noun'), (',', 'Punctuation'), ('전기', 'Noun'), ('전자', 'Noun'), (',', 'Punctuation'), ('산업', 'Noun'), ('공학', 'Noun'), ('등', 'Noun'), ('관련', 'Noun'), ('전공', 'Noun'), (')', 'Punctuation'), ('-', 'Punctuation'), ('의료기기', 'Noun'), ('/', 'Punctuation'), ('제약', 'Noun'), ('등', 'Noun'), ('관련', 'Noun'), ('산업', 'Noun'), ('연구', 'Noun'), ('기획', 'Noun'), ('경력', 'Noun'), ('5년', 'Number'), ('이상', 'Noun'), ('-', 'Punctuation'), ('컨소시엄', 'Noun'), ('구성', 'Noun'), ('및', 'Noun'), ('제안', 'Noun'), ('서', 'Josa'), ('작성', 'Noun'), ('유', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), ('-', 'Punctuation'), ('(', 'Punctuation'), ('우대', 'Noun'), ('사항', 'Noun'), (')', 'Punctuation'), ('AI', 'Alpha'), ('또는', 'Adverb'), ('SW', 'Alpha'), ('관련', 'Noun'), ('전공', 'Noun'), ('학사', 'Noun'), ('이상', 'Noun'), ('학위', 'Noun'), ('자', 'Suffix'), ('의료', 'Noun'), ('/', 'Punctuation'), ('인공', 'Noun'), ('지능', 'Noun'), ('(', 'Punctuation'), ('AI', 'Alpha'), (')', 'Punctuation'), ('관련', 'Noun'), ('프로젝트', 'Noun'), ('관리', 'Noun'), ('유', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), ('우대', 'Noun'), ('MBA', 'Alpha'), ('또는', 'Adverb'), ('PMP', 'Alpha'), ('자격', 'Noun'), ('을', 'Josa'), ('보유', 'Noun'), ('자', 'Suffix'), ('우대', 'Noun'), ('4', 'Number'), ('.', 'Punctuation'), ('기타', 'Noun'), ('사항', 'Noun'), ('-', 'Punctuation'), ('근무', 'Noun'), ('지', 'Josa'), (':', 'Punctuation'), ('서울', 'Noun'), ('-', 'Punctuation'), ('제출', 'Noun'), ('서류', 'Noun'), (':', 'Punctuation'), ('이력서', 'Noun'), ('및', 'Noun'), ('경력', 'Noun'), ('기술', 'Noun'), ('서', 'Josa'), ('(', 'Punctuation'), ('자유', 'Noun'), ('양식', 'Noun'), (')', 'Punctuation'), ('-', 'Punctuation'), ('접수', 'Noun'), ('/', 'Punctuation'), ('문의', 'Noun'), (':', 'Punctuation'), ('tony@pincus.co.kr', 'Email'), ('(', 'Punctuation'), ('핀', 'Noun'), ('커', 'Verb'), ('스코리아', 'Noun'), ('정재연', 'Noun'), ('이사', 'Noun'), (',', 'Punctuation'), ('02-2051', 'Number'), ('-', 'Punctuation'), ('3866', 'Number'), (')', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('1', 'Number'), ('.', 'Punctuation'), ('비전', 'Verb'), ('처리', 'Noun'), ('S', 'Alpha'), ('/', 'Punctuation'), ('W', 'Alpha'), ('프로그래밍', 'Noun'), ('및', 'Noun'), ('개발자', 'Noun'), ('-', 'Punctuation'), ('Vision', 'Alpha'), ('Rule', 'Alpha'), ('기반', 'Noun'), ('비전', 'Verb'), ('처리', 'Noun'), (',', 'Punctuation'), ('비전', 'Verb'), ('객체', 'Noun'), ('인식', 'Noun'), ('처리', 'Noun'), (',', 'Punctuation'), ('영상', 'Noun'), ('인식', 'Noun'), ('/', 'Punctuation'), ('이미지', 'Noun'), ('처리', 'Noun'), ('및', 'Noun'), ('인식', 'Noun'), ('관련', 'Noun'), ('S', 'Alpha'), ('/', 'Punctuation'), ('W', 'Alpha'), ('프로그래밍', 'Noun'), ('및', 'Noun'), ('관련', 'Noun'), ('산업', 'Noun'), ('용', 'Noun'), ('컨트롤러', 'Noun'), ('펌웨어', 'Noun'), ('개발', 'Noun'), ('업무', 'Noun'), ('2', 'Number'), ('.', 'Punctuation'), ('AI', 'Alpha'), ('가속', 'Noun'), ('기', 'Noun'), ('처리', 'Noun'), ('S', 'Alpha'), ('/', 'Punctuation'), ('W', 'Alpha'), ('프로그래밍', 'Noun'), ('및', 'Noun'), ('개발자', 'Noun'), ('-', 'Punctuation'), ('비전', 'Verb'), ('(', 'Punctuation'), ('Vision', 'Alpha'), (')', 'Punctuation'), ('차량', 'Noun'), ('번호판', 'Noun'), ('처리', 'Noun'), ('(', 'Punctuation'), ('LPR', 'Alpha'), ('),', 'Punctuation'), ('AI', 'Alpha'), ('기반', 'Noun'), ('객체', 'Noun'), ('인식', 'Noun'), ('처리', 'Noun'), ('S', 'Alpha'), ('/', 'Punctuation'), ('W', 'Alpha'), ('프로그래밍', 'Noun'), ('및', 'Noun'), ('관련', 'Noun'), ('산업', 'Noun'), ('용', 'Noun'), ('컨트롤러', 'Noun'), ('펌웨어', 'Noun'), ('개발', 'Noun'), ('업무', 'Noun')]
# --------------------------------------------------------------------------------
# ...
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('웹', 'Noun'), ('기획', 'Noun'), ('/', 'Punctuation'), ('PM', 'Alpha'), ('/', 'Punctuation'), ('웹마케팅', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('네트워크', 'Noun'), ('/', 'Punctuation'), ('서버', 'Noun'), ('/', 'Punctuation'), ('보안', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('설문', 'Noun'), ('/', 'Punctuation'), ('통계', 'Noun'), ('/', 'Punctuation'), ('리서치', 'Noun')]
# --------------------------------------------------------------------------------
# [('네트워크', 'Noun'), ('/', 'Punctuation'), ('서버', 'Noun'), ('/', 'Punctuation'), ('보안', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('네트워크', 'Noun'), ('/', 'Punctuation'), ('서버', 'Noun'), ('/', 'Punctuation'), ('보안', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('웹', 'Noun'), ('개발', 'Noun'), (',', 'Punctuation'), ('웹', 'Noun'), ('기획', 'Noun'), ('/', 'Punctuation'), ('PM', 'Alpha'), ('/', 'Punctuation'), ('웹마케팅', 'Noun'), (',', 'Punctuation'), ('응용프로그램', 'Noun'), ('개발', 'Noun'), (',', 'Punctuation'), ('콘텐츠', 'Noun'), ('/', 'Punctuation'), ('사이트', 'Noun'), ('운영', 'Noun'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun'), (',', 'Punctuation'), ('ERP', 'Alpha'), ('/', 'Punctuation'), ('시스템', 'Noun'), ('개발', 'Noun'), ('/', 'Punctuation'), ('설계', 'Noun'), (',', 'Punctuation'), ('HTML', 'Alpha'), ('/', 'Punctuation'), ('퍼블리싱', 'Noun'), ('/', 'Punctuation'), ('UI', 'Alpha'), ('개발', 'Noun'), (',', 'Punctuation'), ('QA', 'Alpha'), ('/', 'Punctuation'), ('테스트', 'Noun'), ('/', 'Punctuation'), ('검증', 'Noun')]
# --------------------------------------------------------------------------------
# [('네트워크', 'Noun'), ('/', 'Punctuation'), ('서버', 'Noun'), ('/', 'Punctuation'), ('보안', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('네트워크', 'Noun'), ('/', 'Punctuation'), ('서버', 'Noun'), ('/', 'Punctuation'), ('보안', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('웹', 'Noun'), ('개발', 'Noun')]
# --------------------------------------------------------------------------------
# [('기획', 'Noun'), ('/', 'Punctuation'), ('전략', 'Noun'), ('/', 'Punctuation'), ('경영', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('상품', 'Noun'), ('기획', 'Noun'), ('/', 'Punctuation'), ('MD', 'Alpha'), (',', 'Punctuation'), ('웹', 'Noun'), ('기획', 'Noun'), ('/', 'Punctuation'), ('PM', 'Alpha'), ('/', 'Punctuation'), ('웹마케팅', 'Noun'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('경영', 'Noun'), ('분석', 'Noun'), ('/', 'Punctuation'), ('컨설턴트', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('네트워크', 'Noun'), ('/', 'Punctuation'), ('서버', 'Noun'), ('/', 'Punctuation'), ('보안', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('기획', 'Noun'), ('/', 'Punctuation'), ('전략', 'Noun'), ('/', 'Punctuation'), ('경영', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('네트워크', 'Noun'), ('/', 'Punctuation'), ('서버', 'Noun'), ('/', 'Punctuation'), ('보안', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('웹', 'Noun'), ('개발', 'Noun'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('네트워크', 'Noun'), ('/', 'Punctuation'), ('서버', 'Noun'), ('/', 'Punctuation'), ('보안', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun'), (',', 'Punctuation'), ('ERP', 'Alpha'), ('/', 'Punctuation'), ('시스템', 'Noun'), ('개발', 'Noun'), ('/', 'Punctuation'), ('설계', 'Noun')]
# --------------------------------------------------------------------------------
# [('고객', 'Noun'), ('관리', 'Noun'), ('/', 'Punctuation'), ('인', 'Noun'), ('바운드', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('네트워크', 'Noun'), ('/', 'Punctuation'), ('서버', 'Noun'), ('/', 'Punctuation'), ('보안', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('네트워크', 'Noun'), ('/', 'Punctuation'), ('서버', 'Noun'), ('/', 'Punctuation'), ('보안', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('응용프로그램', 'Noun'), ('개발', 'Noun'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('건축', 'Noun'), ('/', 'Punctuation'), ('설계', 'Noun'), ('/', 'Punctuation'), ('인테리어', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('사무', 'Noun'), ('/', 'Punctuation'), ('총무', 'Noun'), ('/', 'Punctuation'), ('법무', 'Noun'), (',', 'Punctuation'), ('생산', 'Noun'), ('관리', 'Noun'), ('/', 'Punctuation'), ('공정', 'Noun'), ('관리', 'Noun'), ('/', 'Punctuation'), ('품질', 'Noun'), ('관리', 'Noun'), (',', 'Punctuation'), ('자동차', 'Noun'), ('/', 'Punctuation'), ('조선', 'Noun'), ('/', 'Punctuation'), ('기계', 'Noun'), (',', 'Punctuation'), ('전기', 'Noun'), ('/', 'Punctuation'), ('전자', 'Noun'), ('/', 'Punctuation'), ('제어', 'Noun'), (',', 'Punctuation'), ('토목', 'Noun'), ('/', 'Punctuation'), ('조경', 'Noun'), ('/', 'Punctuation'), ('도시', 'Noun'), ('/', 'Punctuation'), ('측량', 'Noun'), (',', 'Punctuation'), ('화학', 'Noun'), ('/', 'Punctuation'), ('에너지', 'Noun'), ('/', 'Punctuation'), ('환경', 'Noun')]
# --------------------------------------------------------------------------------
# [('기계설계', 'Noun'), ('/', 'Punctuation'), ('CAD', 'Alpha'), ('/', 'Punctuation'), ('CAM', 'Alpha'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('웹', 'Noun'), ('개발', 'Noun'), (',', 'Punctuation'), ('응용프로그램', 'Noun'), ('개발', 'Noun')]
# --------------------------------------------------------------------------------
# [('교육', 'Noun'), ('기획', 'Noun'), ('/', 'Punctuation'), ('교재', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('응용프로그램', 'Noun'), ('개발', 'Noun')]
# --------------------------------------------------------------------------------
# [('네트워크', 'Noun'), ('/', 'Punctuation'), ('서버', 'Noun'), ('/', 'Punctuation'), ('보안', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun'), (',', 'Punctuation'), ('ERP', 'Alpha'), ('/', 'Punctuation'), ('시스템', 'Noun'), ('개발', 'Noun'), ('/', 'Punctuation'), ('설계', 'Noun')]
# --------------------------------------------------------------------------------
# [('마케팅', 'Noun'), ('/', 'Punctuation'), ('PR', 'Alpha'), ('/', 'Punctuation'), ('분석', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('바이오', 'Noun'), ('/', 'Punctuation'), ('제약', 'Noun'), ('/', 'Punctuation'), ('식품', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('기획', 'Noun'), ('/', 'Punctuation'), ('전략', 'Noun'), ('/', 'Punctuation'), ('경영', 'Noun'), (',', 'Punctuation'), ('네트워크', 'Noun'), ('/', 'Punctuation'), ('서버', 'Noun'), ('/', 'Punctuation'), ('보안', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('기획', 'Noun'), ('/', 'Punctuation'), ('전략', 'Noun'), ('/', 'Punctuation'), ('경영', 'Noun'), (',', 'Punctuation'), ('바이오', 'Noun'), ('/', 'Punctuation'), ('제약', 'Noun'), ('/', 'Punctuation'), ('식품', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('사무', 'Noun'), ('/', 'Punctuation'), ('총무', 'Noun'), ('/', 'Punctuation'), ('법무', 'Noun'), (',', 'Punctuation'), ('생산', 'Noun'), ('/', 'Punctuation'), ('제조', 'Noun'), ('/', 'Punctuation'), ('설비', 'Noun'), ('/', 'Punctuation'), ('조립', 'Noun'), (',', 'Punctuation'), ('웹', 'Noun'), ('기획', 'Noun'), ('/', 'Punctuation'), ('PM', 'Alpha'), ('/', 'Punctuation'), ('웹마케팅', 'Noun'), (',', 'Punctuation'), ('응용프로그램', 'Noun'), ('개발', 'Noun'), (',', 'Punctuation'), ('QA', 'Alpha'), ('/', 'Punctuation'), ('테스트', 'Noun'), ('/', 'Punctuation'), ('검증', 'Noun')]
# --------------------------------------------------------------------------------
# [('[', 'Punctuation'), ('주요', 'Modifier'), ('업무', 'Noun'), (']', 'Punctuation'), ('•', 'Foreign'), ('AI', 'Alpha'), ('서비스', 'Noun'), ('의', 'Josa'), ('S', 'Alpha'), ('/', 'Punctuation'), ('W', 'Alpha'), ('개발', 'Noun'), ('과', 'Josa'), ('관련', 'Noun'), ('된', 'Verb'), ('프로젝트', 'Noun'), ('기획', 'Noun'), ('및', 'Noun'), ('수행', 'Noun'), ('관리', 'Noun'), ('•', 'Foreign'), ('RFP', 'Alpha'), ('분석', 'Noun'), ('부터', 'Josa'), ('제안', 'Noun'), ('전략', 'Noun'), ('수립', 'Noun'), ('및', 'Noun'), ('제안', 'Noun'), ('서', 'Josa'), ('작성', 'Noun'), (',', 'Punctuation'), ('최종', 'Noun'), ('검토', 'Noun'), ('까지', 'Josa'), ('제안', 'Noun'), ('업무', 'Noun'), ('총괄', 'Noun'), ('관리', 'Noun'), ('(', 'Punctuation'), ('제안', 'Noun'), ('총괄', 'Noun'), ('PM', 'Alpha'), (')', 'Punctuation'), ('•', 'Foreign'), ('RFP', 'Alpha'), ('분석', 'Noun'), ('을', 'Josa'), ('통해', 'Noun'), ('사업', 'Noun'), ('에서', 'Josa'), ('요구', 'Noun'), ('되는', 'Verb'), ('핵심', 'Noun'), ('내용', 'Noun'), ('파악', 'Noun'), ('및', 'Noun'), ('제안', 'Noun'), ('서', 'Josa'), ('기획', 'Noun'), ('•', 'Foreign'), ('IT', 'Alpha'), ('부문', 'Noun'), ('제안', 'Noun'), ('서', 'Josa'), ('/', 'Punctuation'), ('요약', 'Noun'), ('서', 'Josa'), ('/', 'Punctuation'), ('발표', 'Noun'), ('자료', 'Noun'), ('작성', 'Noun'), ('\u200b', 'Foreign'), ('[', 'Punctuation'), ('자격', 'Noun'), ('요건', 'Noun'), (']', 'Punctuation'), ('•', 'Foreign'), ('학력', 'Noun'), (':', 'Punctuation'), ('대졸', 'Noun'), ('이상', 'Noun'), ('•', 'Foreign'), ('전공', 'Noun'), (':', 'Punctuation'), ('자연', 'Noun'), ('계열', 'Noun'), (',', 'Punctuation'), ('공학', 'Noun'), ('계열', 'Noun'), ('등', 'Noun'), ('이공', 'Noun'), ('계', 'Suffix'), ('학사', 'Noun'), ('학위', 'Noun'), ('취득', 'Noun'), ('자', 'Suffix'), ('[', 'Punctuation'), ('필수', 'Noun'), ('요건', 'Noun'), ('및', 'Noun'), ('우대', 'Noun'), ('사항', 'Noun'), (']', 'Punctuation'), ('[', 'Punctuation'), ('필수', 'Noun'), ('요건', 'Noun'), (']', 'Punctuation'), ('A', 'Alpha'), ('-', 'Punctuation'), ('1', 'Number'), (')', 'Punctuation'), ('소프트웨어', 'Noun'), ('개발', 'Noun'), ('경험', 'Noun'), ('있는', 'Adjective'), ('사람', 'Noun'), ('(', 'Punctuation'), ('3년', 'Number'), ('이상', 'Noun'), (')', 'Punctuation'), ('A', 'Alpha'), ('-', 'Punctuation'), ('2', 'Number'), (')', 'Punctuation'), ('프로그래머', 'Noun'), ('와', 'Josa'), ('원활한', 'Adjective'), ('커뮤니케이션', 'Noun'), ('이', 'Josa'), ('가능한', 'Adjective'), ('사람', 'Noun'), ('A', 'Alpha'), ('-', 'Punctuation'), ('3', 'Number'), (')', 'Punctuation'), ('사업', 'Noun'), ('연구', 'Noun'), ('기획', 'Noun'), ('/', 'Punctuation'), ('수행', 'Noun'), ('경력', 'Noun'), ('3년', 'Number'), ('이상', 'Noun'), ('A', 'Alpha'), ('-', 'Punctuation'), ('4', 'Number'), (')', 'Punctuation'), ('기술', 'Noun'), ('적', 'Suffix'), (',', 'Punctuation'), ('비즈니스', 'Noun'), ('적', 'Suffix'), ('프로그램', 'Noun'), ('/', 'Punctuation'), ('프로젝트', 'Noun'), ('관리', 'Noun'), ('경험', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('\u200b', 'Foreign'), ('\u200b', 'Foreign'), ('[', 'Punctuation'), ('우대', 'Noun'), ('사항', 'Noun'), (']', 'Punctuation'), ('B', 'Alpha'), ('-', 'Punctuation'), ('1', 'Number'), (')', 'Punctuation'), ('PMP', 'Alpha'), ('또는', 'Adverb'), ('ITIL', 'Alpha'), ('등', 'Noun'), ('프로젝트', 'Noun'), ('관리', 'Noun'), ('자격증', 'Noun'), ('을', 'Josa'), ('취득', 'Noun'), ('또는', 'Adverb'), ('교육', 'Noun'), ('수료', 'Noun'), ('자', 'Suffix'), ('B', 'Alpha'), ('-', 'Punctuation'), ('2', 'Number'), (')', 'Punctuation'), ('컴퓨터', 'Noun'), ('활용', 'Noun'), ('능력', 'Noun'), (',', 'Punctuation'), ('문서', 'Noun'), ('작성', 'Noun'), (',', 'Punctuation'), ('PPT', 'Alpha'), ('자료', 'Noun'), ('작성', 'Noun'), ('우수', 'Noun'), ('자', 'Suffix'), ('B', 'Alpha'), ('-', 'Punctuation'), ('3', 'Number'), (')', 'Punctuation'), ('긍정', 'Noun'), ('적', 'Suffix'), (',', 'Punctuation'), ('발전', 'Noun'), ('적', 'Suffix'), ('인', 'Josa'), ('협업', 'Noun'), ('이', 'Josa'), ('가능한', 'Adjective'), ('사람', 'Noun'), ('B', 'Alpha'), ('-', 'Punctuation'), ('4', 'Number'), (')', 'Punctuation'), ('UML', 'Alpha'), ('(', 'Punctuation'), ('unified', 'Alpha'), ('modeling', 'Alpha'), ('language', 'Alpha'), (')', 'Punctuation'), ('과', 'Noun'), ('같은', 'Adjective'),  ...
# --------------------------------------------------------------------------------
# [('ㆍ', 'Foreign'), ('정형', 'Noun'), ('/', 'Punctuation'), ('비정', 'Noun'), ('형', 'Suffix'), ('문서', 'Noun'), ('의', 'Josa'), ('인식', 'Noun'), ('모델', 'Noun'), ('개발', 'Noun'), ('ㆍ', 'Foreign'), ('AI', 'Alpha'), ('엔진', 'Noun'), ('성능', 'Noun'), ('향상', 'Noun'), ('을', 'Josa'), ('위', 'Noun'), ('한', 'Josa'), ('딥', 'Noun'), ('러닝', 'Noun'), ('모델', 'Noun'), ('개발', 'Noun'), ('ㆍ', 'Foreign'), ('딥', 'Noun'), ('러닝', 'Noun'), ('모델', 'Noun'), ('serving', 'Alpha'), ('을', 'Josa'), ('위', 'Noun'), ('한', 'Josa'), ('변환', 'Noun'), ('및', 'Noun'), ('최적화', 'Noun'), ('ㆍ', 'Foreign'), ('모델', 'Noun'), ('성능', 'Noun'), ('개선', 'Noun'), ('및', 'Noun'), ('관리', 'Noun')]
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [('빅데이터', 165), ('개발', 100), ('데이터베이스', 59), ('및', 46), ('관련', 36), ('기획', 31), ('등', 30), ('웹', 27), ('업무', 26), ('경험', 26), ('경력', 26), ('응용프로그램', 25), ('사업', 21), ('우대', 20), ('분석', 20), ('관리', 19), ('기술', 18), ('작성', 18), ('이상', 17), ('사항', 16), ('지원', 15), ('기반', 14), ('설계', 14), ('자격', 13), ('요건', 13), ('서비스', 13), ('분', 13), ('인공', 13), ('지능', 13), ('경영', 13), ('사람', 12), ('모델', 12), ('네트워크', 12), ('서버', 12), ('보안', 12), ('연구', 11), ('전략', 11), ('데이터', 10), ('운영', 10), ('가능', 10), ('플랫폼', 10), ('솔루션', 10), ('제안', 10), ('분야', 9), ('자료', 9), ('위', 9), ('회사', 9), ('수립', 9), ('시스템', 9), ('환경', 8)]
# {'개발': 100, '데이터베이스': 59, '기획': 31, '웹': 27, '업무': 26, '경험': 26, '경력': 26, '응용프로그램': 25, '사업': 21, '우대': 20, '분석': 20, '관리': 19, '기술': 18, '작성': 18, '사항': 16, '지원': 15, '기반': 14, '설계': 14, '자격': 13, '요건': 13, '서비스': 13, '분': 13, '인공': 13, '지능': 13, '경영': 13, '사람': 12, '모델': 12, '네트워크': 12, '서버': 12, '보안': 12, '연구': 11, '전략': 11, '운영': 10, '가능': 10, '플랫폼': 10, '솔루션': 10, '제안': 10, '분야': 9, '자료': 9, '위': 9, '회사': 9, '수립': 9, '시스템': 9, '환경': 8}

# %% [markdown]
# ## 경력조건 비율 알아보기

# %%
AI_df["경력조건"].value_counts()
# Out:
# 무관                  143
# 경력 (최소 12개월 이상)      13
# 신입, 경력 (연수무관)         6
# 경력 (최소 5년 이상)         6
# 경력                    4
# 경력 (최소 3년 이상)         4
# 신입                    4
# 관계없음                  3
# 신입/경력                 3
# 경력 (최소 1년 이상) 우대      3
# 경력 (연수무관)             2
# 경력 (최소 2년 이상)         1
# 경력 (최소 4년 이상)         1
# 경력 (최소 24개월 이상)       1
# 경력 (최소 5년 이상) 우대      1
# 경력 (최소 7년 이상)         1
# 경력 (최소 1년 이상)         1
# 경력 (최소 15년 이상)        1
# 경력 (최소 10년 이상)        1
# 경력 (최소 3년 이상) 우대      1
# Name: 경력조건, dtype: int64

# %%
sum(list(AI_df["경력조건"].value_counts()))
# Out:
# 200

# %%
ratio = [(143+7), 50]
labels = ['신입/무관', '경력']

pie_graph(ratio, labels)

# %% [markdown]
# ## 학력 비율알아보기

# %%
AI_df["학력"].value_counts()
# Out:
# 학력무관           111
# 대졸(4년)          45
# 석사              33
# -                4
# 대졸(2~3년)         3
# 대졸(4년) ~ 박사      2
# 고졸 ~ 석사          1
# 박사               1
# Name: 학력, dtype: int64

# %%
AI_df["학력"].value_counts()
# Out:
# 학력무관           111
# 대졸(4년)          45
# 석사              33
# -                4
# 대졸(2~3년)         3
# 대졸(4년) ~ 박사      2
# 고졸 ~ 석사          1
# 박사               1
# Name: 학력, dtype: int64

# %%
ratio = [115, (45+3), (33+4)]
labels = ['학력무관', '대졸(전문대 및 4년)', "석사 이상"]
pie_graph(ratio, labels)

# %% [markdown]
# <hr><hr><hr><hr><hr><hr><hr>

# %%
def draw_graph(df, name):
    plt.figure(figsize=(20, 10))
    # x = group_area.index.to_list()
    x = ["2013", "2015", "2017", "2019", "2021", "2023"]
    y = df.iloc[0].to_list()
    
    plt.plot(x, y, "k--")
    
    
    plt.xticks(rotation=70)
    # plt.ylim(220000, 350000)
    plt.rc('xtick', labelsize=30)
    plt.rc('ytick', labelsize=30)
    
    plt.title(name, size = 30)
    # 숫자 넣는 부분
    idx = 0
    '''
    for rect in bar:
        height = rect.get_height()
        if idx < 8:
            plt.text(rect.get_x() + rect.get_width()/2.0, height, company[idx], ha='center', va='top', size = 15, rotation=90)
        else:    
            plt.text(rect.get_x() + rect.get_width()/2.0, height, company[idx], ha='center', va='bottom', size = 15, rotation=90)
        idx += 1
    
    plt.text(rect.get_x() + rect.get_width()/2.0, avg, f"평균:{round(avg)}", ha='center', va='bottom', size = 15)
    '''
    plt.show()

# %%
for i in range(len(df_list)):
    draw_graph(df_list[i], name_list[i])

# %% [markdown]
# # <hr> multi bar

# %%
def draw_graph2(df, name):
    plt.figure(figsize=(15, 7))
    # x = group_area.index.to_list()
    x = ["2013", "2015", "2017", "2019", "2021", "2023"]
    y = df.iloc[0].to_list()
    # 'gold', 'b', '#FF0000', 'green'
    # df_list[0].loc[["서울특별시", "부산광역시", "대구광역시", "경기도"]]
    # 서울 경기 부산 대구 
    sum = 0
    p1 = plt.bar(x, df.loc["대구광역시"], color='yellowgreen', label = "대구광역시")
    sum += df.loc["대구광역시"]
    p2 = plt.bar(x, df.loc["부산광역시"], color='gold', bottom=sum, label = "부산광역시")
    sum += df.loc["부산광역시"]
    p3 = plt.bar(x, df.loc["경기도"], color='cornflowerblue', bottom=sum, label = "경기도")
    sum += df.loc["경기도"]
    p4 = plt.bar(x, df.loc["서울특별시"], color='pink' ,bottom=sum, label = "서울특별시")
    sum += df.loc["서울특별시"]
    
    # plt.xticks(rotation=70)
    # plt.ylim(220000, 350000)
    plt.rc('xtick', labelsize=15)
    plt.rc('ytick', labelsize=15)
    
    plt.title(name, size = 30)
    # 숫자 넣는 부분
    idx = 0
    '''
    for rect in bar:
        height = rect.get_height()
        if idx < 8:
            plt.text(rect.get_x() + rect.get_width()/2.0, height, company[idx], ha='center', va='top', size = 15, rotation=90)
        else:    
            plt.text(rect.get_x() + rect.get_width()/2.0, height, company[idx], ha='center', va='bottom', size = 15, rotation=90)
        idx += 1
    
    plt.text(rect.get_x() + rect.get_width()/2.0, avg, f"평균:{round(avg)}", ha='center', va='bottom', size = 15)
    '''
    plt.xlabel('연도', size = 15)
    plt.ylabel('개', size = 15)
    plt.legend(loc=2, fontsize=15, handles=[p4, p3, p2, p1])
    plt.show()

# %%
for i in range(len(df_list)):
    draw_graph2(df_list[i], name_list[i])

# %%
name_list
# Out:
# ['계',
#  '내과',
#  '신경과',
#  '정신건강의학과',
#  '외과',
#  '정형외과',
#  '신경외과',
#  '심장혈관흉부외과',
#  '성형외과',
#  '마취통증의학과',
#  '산부인과',
#  '소아청소년과',
#  '안과',
#  '이비인후과',
#  '피부과',
#  '비뇨의학과',
#  '영상의학과',
#  '병리과',
#  '진단검사의학과',
#  '결핵과',
#  '재활의학과',
#  '핵의학과',
#  '가정의학과',
#  '전문과목미표시전문의',
#  '일반의']

# %%
df_list[0]
x = ["2013", "2015", "2017", "2019", "2021", "2023"]
df_list[0].loc[["서울특별시", "부산광역시", "대구광역시", "인천광역시"]].T.plot(kind='bar', stacked=True)
# Out:
# <Axes: >

# %%
df_list[0].loc[["서울특별시", "부산광역시", "대구광역시", "경기도"]]
# 서울 경기 부산 대구 
sum = 0
p1 = plt.bar(x, df_list[0].loc["대구광역시"], color='b')
sum += df_list[0].loc["대구광역시"]
p2 = plt.bar(x, df_list[0].loc["부산광역시"], color='g', bottom=sum)
sum += df_list[0].loc["부산광역시"]
p3 = plt.bar(x, df_list[0].loc["경기도"], color='y', bottom=sum)
sum += df_list[0].loc["경기도"]
p4 = plt.bar(x, df_list[0].loc["서울특별시"], color='r' ,bottom=sum)
sum += df_list[0].loc["서울특별시"]

# %%
df_list[0]
# Out:
#           2013   2015   2017   2019   2021   2023
# 0
# 계        28328  29488  30938  32491  33912  35580
# 서울특별시     7505   7802   8155   8628   9189   9669
# 부산광역시     2119   2198   2279   2384   2468   2588
# 대구광역시     1576   1615   1712   1803   1884   1971
# 인천광역시     1384   1444   1496   1573   1633   1772
# 광주광역시      864    893    915    948    970   1041
# 대전광역시      995   1026   1057   1078   1112   1114
# 울산광역시      537    574    592    609    618    633
# 세종특별자치시     57    100    147    181    198    229
# 경기도       5876   6159   6600   7065   7487   8048
# 강원특별자치도    695    717    743    769    782    798
# 충청북도       775    815    847    891    912    936
# 충청남도       991   1024   1055   1074   1094   1108
# 전라북도      1080   1107   1143   1165   1179   1208
# 전라남도       894    905    931    944    962    966
# 경상북도      1168   1226   1260   1292   1279   1296
# 경상남도      1481   1522   1594   1639   1682   1707
# 제주특별자치도    331    361    412    448    463    496
