# %%
import pandas as pd
import numpy as np
import koreanize_matplotlib
import matplotlib.pyplot as plt
import pymysql

from bs4 import BeautifulSoup
import requests
from konlpy.tag import Okt
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import time
import platform
import numpy as np
from PIL import Image

# %%
def pie_graph(ratio, labels, name):
    colors = ['silver', 'gold', 'whitesmoke', 'lightgray']
    plt.pie(ratio, labels=labels, autopct='%.1f%%', colors=colors)
    plt.title(name, size = 30)
    plt.show()

# %%
df = pd.read_csv("temp_work_net_bigdata.csv")
AI_df = df.drop('Unnamed: 0', axis=1)
AI_df
# Out:
#                                              모집직종  \
# 0                          데이터 분석가(빅데이터 분석가) 직업정보
# 1                          데이터 분석가(빅데이터 분석가) 직업정보
# 2                                        IT개발·데이터
# 3                                        IT개발·데이터
# 4                          데이터 분석가(빅데이터 분석가) 직업정보
# ..                                            ...
# 195                                             -
# 196                                             -
# 197                                             -
# 198                                             -
# 199  DBA,데이터엔지니어,데이터사이언티스트,웹기획,R&D·연구원,경영·비즈니스 기획
#
#                                                   직무내용              경력조건  \
# 0                        데이터수집, 정제 데이터 분석 인공지능 개발 논문연구  경력 (최소 1년 이상) 우대
# 1    자료조사(문헌, 설문 등) 데이터분석(엑셀, R프로그램, 파이썬 등) 보고서 작성(...              관계없음
# 2                                                    -                무관
# 3                                                    -     경력 (최소 2년 이상)
# 4    브래키츠(주)에서 아래와 같이 태블로(Tableau) 경력자를 모집합니다. [ 회사...  경력 (최소 2년 이상) 필수
# ..                                                 ...               ...
# 195                                빅데이터/AI, DBA/데이터베이스                무관
# 196                      빅데이터/AI, 응용프로그램개발, DBA/데이터베이스                무관
# 197                      빅데이터/AI, 응용프로그램개발, DBA/데이터베이스                무관
# 198                      빅데이터/AI, 응용프로그램개발, DBA/데이터베이스                무관
# 199                                                  -     신입, 경력 (연수무관)
#
#               학력                                       전공  \
# 0           학력무관  정보·통신공학(학과 : 데이터정보학과) 통계학(학과 : 데이터경영학과)
# 1    대졸(4년) ~ 박사                                        -
# 2           학력무관                                        -
# 3         대졸(4년)                                        -
# 4           학력무관                                        -
# ..           ...                                      ...
# 195         학력무관                                        -
# 196           석사                                        -
# 197           석사                                        -
# 198       대졸(4년)                                        -
# 199       대졸(4년)                                        -
#
#                              자격면허 우대조건
# 0    우대 : 데이터분석준전문가 우대 : 빅데이터분석기사    -
# 1                               -    -
# 2                               -    -
# 3                               -    -
# 4                               -    -
# ..                            ...  ...
# 195                             -    -
# 196                             -    -
# 197                             -    -
# 198                             -    -
# 199                             -    -
#
# [200 rows x 7 columns]

# %%
df = pd.read_csv("iframe_data.csv")
AI_df2 = df.drop('Unnamed: 0', axis=1)
AI_df2
# Out:
#                                                    우대  \
# 0   모집부문상세내용공통 자격요건ㆍ 학력 : 무관ㆍ 경력 : 신입/경력데이터인텔리전스팀데...
# 1                                                   -
# 2                                                   -
# 3                                                   -
# 4                                                   -
# 5   공통 자격요건ㆍ학력 : 학사이상 (졸업예정자 가능)ㆍ경력 : 관련 경력 2~3년 필...
# 6                                                   -
# 7                                                   -
# 8                                                   -
# 9                                                   -
# 10                                                  -
# 11                                                  -
# 12                                                  -
# 13  모집부문상세내용공통 자격요건ㆍ학력 : 대졸 이상 (4년)지능화 감시체계 사업[ 업무...
# 14  ㆍ근무형태:계약직-1년11개월2023.3.4 이전 근무 시작 권장 장기 계약(약 1...
# 15                                                  -
# 16                                                  -
# 17                                                  -
# 18  공통 자격요건ㆍ학력 : 대졸 이상 (4년)백엔드 Python 개발자 신입/경력 채용...
# 19                                                  -
# 20                                                  -
# 21  ㆍ접수기간:2024년 2월 6일 (화) 17시  ~ 2024년 4월 6일 (토) 2...
# 22                                                  -
# 23                                                  -
# 24                                                  -
# 25  모집부문상세내용공통 자격요건ㆍ학력 : 무관보안,네트워크 영업영업2팀 1명담당업무ㆍ지...
# 26                                                  -
# 27                                                  -
# 28                                                  -
# 29                                                  -
# 30                                                  -
# 31                                                  -
# 32  공통 자격요건ㆍ학력 : 무관AI 데이터 가공 및 검수 계약직시험평가연구소 3명담당업...
# 33                                                  -
# 34                                                  -
# 35                                                  -
# 36                                                  -
# 37  모집부문상세내용공통 자격요건ㆍ학력 : 대졸 이상응용 / 웹 프로그램 / 데이터베이스...
# 38                                                  -
# 39                                                  -
# 40                                                  -
# 41                                                  -
# 42  공통 자격요건ㆍ학력 : 대졸 이상 (4년)(빅데이터/AI(머신러닝딥러닝)/파이썬/자...
# 43                                                  -
# 44                                                  -
# 45                                                  -
# 46                                                  -
# 47  모집부문상세내용사업운영부[담당업무]ㆍ부동산 권리조사 상품기획ㆍ권리조사 서비스 운용 ...
# 48                                                  -
# 49                                                  -
# 50                                                  -
# 51                                                  -
#
#                                                    요건  \
# 0   모집부문상세내용공통 자격요건ㆍ 학력 : 무관ㆍ 경력 : 신입/경력데이터인텔리전스팀데...
# 1                                                   -
# 2                                                   -
# 3                                                   -
# 4                                                   -
# 5   공통 자격요건ㆍ학력 : 학사이상 (졸업예정자 가능)ㆍ경력 : 관련 경력 2~3년 필...
# 6                                                   -
# 7                                                   -
# 8                                                   -
# 9                                                   -
# 10                                                  -
# 11                                                  -
# 12                                                  -
# 13  모집부문상세내용공통 자격요건ㆍ학력 : 대졸 이상 (4년)지능화 감시체계 사업[ 업무...
# 14                                                  -
# 15                                                  -
# 16                                                  -
# 17                                                  -
# 18  공통 자격요건ㆍ학력 : 대졸 이상 (4년)백엔드 Python 개발자 신입/경력 채용...
# 19                                                  -
# 20                                                  -
# 21                                                  -
# 22                                                  -
# 23                                                  -
# 24                                                  -
# 25  모집부문상세내용공통 자격요건ㆍ학력 : 무관보안,네트워크 영업영업2팀 1명담당업무ㆍ지...
# 26                                                  -
# 27                                                  -
# 28                                                  -
# 29                                                  -
# 30                                                  -
# 31                                                  -
# 32  공통 자격요건ㆍ학력 : 무관AI 데이터 가공 및 검수 계약직시험평가연구소 3명담당업...
# 33                                                  -
# 34                                                  -
# 35                                                  -
# 36                                                  -
# 37  모집부문상세내용공통 자격요건ㆍ학력 : 대졸 이상응용 / 웹 프로그램 / 데이터베이스...
# 38                                                  -
# 39                                                  -
# 40                                                  -
# 41                                                  -
# 42  공통 자격요건ㆍ학력 : 대졸 이상 (4년)(빅데이터/AI(머신러닝딥러닝)/파이썬/자...
# 43                                                  -
# 44                                                  -
# 45                                                  -
# 46                                                  -
# 47  모집부문상세내용사업운영부[담당업무]ㆍ부동산 권리조사 상품기획ㆍ권리조사 서비스 운용 ...
# 48                                                  -
# 49                                                  -
# 50                                                  -
# 51                                                  -
#
#                                                    업무
# 0   모집부문상세내용공통 자격요건ㆍ 학력 : 무관ㆍ 경력 : 신입/경력데이터인텔리전스팀데...
# 1                                                   -
# 2                                                   -
# 3                                                   -
# 4                                                   -
# 5   공통 자격요건ㆍ학력 : 학사이상 (졸업예정자 가능)ㆍ경력 : 관련 경력 2~3년 필...
# 6                                                   -
# 7                                                   -
# 8                                                   -
# 9                                                   -
# 10                                                  -
# 11                                                  -
# 12                                                  -
# 13  모집부문상세내용공통 자격요건ㆍ학력 : 대졸 이상 (4년)지능화 감시체계 사업[ 업무...
# 14  ㆍ근무형태:계약직-1년11개월2023.3.4 이전 근무 시작 권장 장기 계약(약 1...
# 15                                                  -
# 16                                                  -
# 17                                                  -
# 18  공통 자격요건ㆍ학력 : 대졸 이상 (4년)백엔드 Python 개발자 신입/경력 채용...
# 19                                                  -
# 20                                                  -
# 21                                                  -
# 22                                                  -
# 23                                                  -
# 24                                                  -
# 25  모집부문상세내용공통 자격요건ㆍ학력 : 무관보안,네트워크 영업영업2팀 1명담당업무ㆍ지...
# 26                                                  -
# 27                                                  -
# 28                                                  -
# 29                                                  -
# 30                                                  -
# 31                                                  -
# 32  공통 자격요건ㆍ학력 : 무관AI 데이터 가공 및 검수 계약직시험평가연구소 3명담당업...
# 33                                                  -
# 34                                                  -
# 35                                                  -
# 36                                                  -
# 37  모집부문상세내용공통 자격요건ㆍ학력 : 대졸 이상응용 / 웹 프로그램 / 데이터베이스...
# 38                                                  -
# 39                                                  -
# 40                                                  -
# 41                                                  -
# 42  공통 자격요건ㆍ학력 : 대졸 이상 (4년)(빅데이터/AI(머신러닝딥러닝)/파이썬/자...
# 43                                                  -
# 44                                                  -
# 45                                                  -
# 46                                                  -
# 47  모집부문상세내용사업운영부[담당업무]ㆍ부동산 권리조사 상품기획ㆍ권리조사 서비스 운용 ...
# 48                                                  -
# 49                                                  -
# 50                                                  -
# 51                                                  -

# %%
AI_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   모집직종    200 non-null    object
#  1   직무내용    200 non-null    object
#  2   경력조건    200 non-null    object
#  3   학력      200 non-null    object
#  4   전공      200 non-null    object
#  5   자격면허    200 non-null    object
#  6   우대조건    200 non-null    object
# dtypes: object(7)
# memory usage: 11.1+ KB

# %%
AI_df = AI_df.astype({'경력조건':'category', '학력':'category'})

# %%
AI_df.head()
# Out:
#                      모집직종                                               직무내용  \
# 0  데이터 분석가(빅데이터 분석가) 직업정보                      데이터수집, 정제 데이터 분석 인공지능 개발 논문연구
# 1  데이터 분석가(빅데이터 분석가) 직업정보  자료조사(문헌, 설문 등) 데이터분석(엑셀, R프로그램, 파이썬 등) 보고서 작성(...
# 2                IT개발·데이터                                                  -
# 3                IT개발·데이터                                                  -
# 4  데이터 분석가(빅데이터 분석가) 직업정보  브래키츠(주)에서 아래와 같이 태블로(Tableau) 경력자를 모집합니다. [ 회사...
#
#                경력조건           학력                                       전공  \
# 0  경력 (최소 1년 이상) 우대         학력무관  정보·통신공학(학과 : 데이터정보학과) 통계학(학과 : 데이터경영학과)
# 1              관계없음  대졸(4년) ~ 박사                                        -
# 2                무관         학력무관                                        -
# 3     경력 (최소 2년 이상)       대졸(4년)                                        -
# 4  경력 (최소 2년 이상) 필수         학력무관                                        -
#
#                            자격면허 우대조건
# 0  우대 : 데이터분석준전문가 우대 : 빅데이터분석기사    -
# 1                             -    -
# 2                             -    -
# 3                             -    -
# 4                             -    -

# %% [markdown]
# ## 규티빠띠 cloud 그리기

# %%
title_list = list(AI_df["직무내용"]) + list(AI_df2["우대"])
title_list
# Out:
# ['데이터수집, 정제 데이터 분석 인공지능 개발 논문연구',
#  '자료조사(문헌, 설문 등) 데이터분석(엑셀, R프로그램, 파이썬 등) 보고서 작성(아래한글, PPT 등) 지원 ※ 고용센터 채용대행건으로 구직신청 후 워크넷으로 입사지원 바랍니다. - 실업급여 구직활동을 위한 지원을 자제 부탁드리며, 실제 취업의사가 있는 분만 지원 바랍니다.',
#  '-',
#  '-',
#  '브래키츠(주)에서 아래와 같이 태블로(Tableau) 경력자를 모집합니다. [ 회사 소개 ] ‘디지털 해결소’를 표방하는 브래키츠(주)는 다양한 분야 유수의 고객사에 DT(Digital Transformation), Analytics, Cloud 등 ERP·BI 분야 전반에 걸쳐 실용적인 솔루션을 제공하는 IT 컨설팅 기업입니다. 2021년 창사 이래 급속한 성장과 함께 우리는 열정 있는 인재들을 찾아 함께 성장하고자 합니다. [ 직무 및 업무 내용 ] ▶   태블로(Tableau)를 이용한 데이터 시각화 및 분석 작업 수행 ▶   다양한 데이터 소스로부터의 데이터 추출 및 가공 ▶   리포트 및 대시보드 개발 및 유지보수 ▶   데이터 분석 결과에 대한 해석 및 비즈니스(고객사)에 제안 [ 자격 요건 ] ▶   태블로(Tableau) 경력 2년 이상 ✔  세일즈포스 태블로 신병훈련소 교육자료 생성/이해 가능 실력 ✔   태블로 장표 생성에 필요한 데이터셋(포맷) 구성 능력 필요 ▶   SQL 조회문(select) 작성 실력 ✔   서브쿼리, 피벗 사용 가능자 [ 우대 사항 ] ▶   태블로 구축 프로젝트 진행 경험 3회 이상 [ 지원 방법 ] ▶   접수: 워크넷 ▶   제출 서류: 이력서, 자기소개서, 포트폴리오(있을 경우) BI(Business Intelligence)는 비즈니스 의사결정 시 근거를 제공하고 의사결정 이후에도 기업활동을 모니터링하기 위한 필수 시스템으로서, 한 회사의 경영 노하우를 시스템에 녹여낸 회사 경영의 필수 요소입니다. 태블로(Tableau)는 이러한 BI 시장에서 최근 몇 년 동안 독보적인 입지를 유지하고 있으며, 많은 기업들이 본격적으로 태블로를 도입하고 Self-BI 환경을 구축함으로써 경영활동에 필요한 인사이트를 발굴하고 가시화하고자 노력하고 있습니다. 이에 브래키츠(주)는 열정 있고 도전적인 인재와 함께 다양한 태블로 프로젝트를 추진함으로써 자사의 성장뿐만 아니라 고객사, 나아가 비즈니스 업계의 성장에 일조하고자 합니다. 관심 있는 경력자 분들의 지원을 기대합니다. 감사합니다. 브래키츠(주)',
#  '[공통 자격요건] ㆍ학력/성별 : 무관 ㆍ경력 : 경력 (1년 이상 또는 동등이상 개발이력) ㆍ수습 : 3개월 [담당업무] ㆍ인공지능 알고리즘 개발 [자격요건] ㆍLinux, Windows 환경에서 어플리케이션 설계 및 개발 ㆍPython 언어 개발 가능자 ㆍ인공지능 모델 개발에 필요한 기술 보유자 [우대사항] ㆍ인공지능 모델 서비스화 경험이 있으신 분 ㆍ인공지능 관련학과 석박사 우대 ㆍ열린 마음으로 목표를 위한 원활한 커뮤니케이션을 즐기시는 분 ㆍGit-hub 주소, 개발 포트폴리오 제출이 가능하신 분 [복리후생] ㆍ모든 임직원 통신비 제공 ㆍ모든 임직원 중식 제공 ㆍ명절(설/추석) 선물 지급 ㆍ경조금 지원 ㆍ야근시 식대 지원 ㆍ출퇴근시간 유연근무제 시행 ㆍ자율적인 휴가 사용(연차, 반차 등) * 회사 성장에 따라 복리후생 추가 예정',
#  '○ 데이터기반행정 활성화 (시행계획 수립, 역량강화, 데이터 공유 등) ○ 데이터기반행정 실태 점검 대응 ○ 공공데이터 품질관리',
#  '-',
#  '-',
#  '드라마 제작 현장에서 함께 일할 스텝 모집합니다. 안녕하세요 저희 회사는 마포구 상암동에 소재하고 있으며 스텝 분들은   촬영 현장에 따라 상암동 또는 여의도, 일산에서 스텝 버스를 타고 현장 근무 합니다. 주요 업무는 현장 데이터 매니저이며 촬영 된 데이터를 복제 및 변환 / 가공 하는 업무입니다. 처음 접하시는 분들을 위해 사내에서 사전 교육과 현장에서 서포터분이 함께 참가해 교육을 시켜 드리기에 기존의 경험 및 기초 지식은 필요치 않습니다. 데이터 매니저의 역할을 하다가 촬영 현장에 익숙해 지시면 촬영 / 편집 / 제작 / 연출 등의 타 업무로의 전환도 가능합니다. 드라마 촬영 스텝 분야의 관심 있는 분들의 많은 지원 바랍니다',
#  '국립금오공과대학교에서는 2024년 국립대학 육성사업 업무 추진을 위해 참신하고 유능한 인재를 다음과 같이 모집합니다. 1. 채용분야 및 인원 ◎ 전문계약직(데이터 관리 및 분석) 1명 - 학생 역량 관리 시스템 고도화 2. 접수기간: 2024.2.9.(금) ~ 2.16.(금) 18:00 3. 접수방법: 이메일 접수 * 기타 자세한 사항은 붙임파일 참조 바랍니다. 2024년 2월 8일 국립금오공과대학교총장',
#  '공공기관 데이터 표준 품질 업무 (가) 데이터 사업 수행 경력 최소 3년 이상 + PM 수행경험 보유 (나) 데이터관리체계 구축 컨설팅, 데이터 표준 수립, 데이터 품질진단, 데이터 개발 등 데이터 관련 사업 유경험자 (다) 빅데이터 분석 및 플랫폼 구축 사업 유경험자, 빅데이터 분석기술 보유자 (R, 파이썬 등) (라) KS_META_DQ 솔루션의 고도화 및 유지관리를 위한 개발인력 (마) 데이터 관련 자격증 소지자 우대 (DAP, ADP, 빅데이터분석기사, DQC-V 등)',
#  '-',
#  'ㆍ자동차 데이터 비교 업무로, 자동차 전장에 대한 이해도가 있는 분과 엑셀등 기본적인 문서 작성을 할 수 있는 분을 모집하고 있습니다. ㆍ새로운 프로젝트인 만큼 데이터 분석에 대해 같이 배우고 업무에 실행할 예정입니다. 부담 없이 지원해 주세요.',
#  '-',
#  '-',
#  '-',
#  '- 신입 : 연봉 2,500 만원은 기본급 2,280 만원 + 상여금과 식대가 포함된 금액입니다. : 인센티브 별도. [ 인턴기간 :2개월 이내 기본급 월 174 만원 ] - 경력직 : 입찰 경력 있으신 분은 상호 협의 가능 ㆍ 공공기관 전자입찰 금액 분석 및 원격투찰. - 나라장터, 국방부, 한전 등 관공서 전자 입찰  발주 공고 분석 업무 및 업체 관리입니다. ㆍ전자입찰 분석 경험자 우대. - 신입도 충분히 가능합니다. 하지만 이쪽 계통에서는 영업 직원들은 구인하지만 분석 업무는 배울 기회가 없습니다. 저희도 경력직만 채용하다가 신입도 채용할려고 하는 거니 많은 지원 바랍니다~ ㆍ인근 거주자 ㆍ착실하고 책임감있는분. ㆍ다른뭔가를 찾고계시는분. ㆍ점심 시간 11시 45분~ 13시 15분 1시간 30분으로 충분한 휴식. ㆍ월~금(주 5일 근무) ㆍ9시 출근 ~ 오후 6시 퇴근 ( 점심시간 1시간 30분포함) ㆍ주5일만 근무합니다. ㆍ야근없고, 주말 근무 없습니다.',
#  '-',
#  '[모집부문 및 상세내용] - 공통 자격요건 ㆍ학력 : 대졸 이상 (2,3년) [Database 기술 엔지니어 신입 및 경력직 채용\t 2명] - 지원자격 ㆍ경력 : 신입/경력 2년 ~ 5년(면접 후 결정) ㆍ관계형 데이터베이스 구축 경험 ㆍDBMS 운영 및 장애 대응 ㆍ운영체제 및 네트워크에 대한 이해도 - 우대사항 ㆍ공학계열, 관련학과(전산학과) 졸업자 ㆍSQL 숙련자 ㆍ관련 인증 자격 소지자 ㆍ해당직무 근무경험 - 복리후생 ㆍ건강보험, 국민연금, 산재보험, 고용보혐 등 ㆍ정기 휴가 및 연차 사용 관리 ㆍ경조사비 지원 ㆍ근무시간 및 장소 유연성 제공 ㆍ업무 관련 교육 및 세미나 참석 기회 제공 ㆍ사내 우수 인원에 대한 승진 및 연봉 인상 기회 - 근무조건 ㆍ\t근무형태\t:\t정규직(수습기간)-3개월 ㆍ\t근무지역\t:\t(06083) 서울 강남구 영동대로 602, E동 6층 205호 - 서울 9호선 봉은사 에서 100m 이내 [전형절차] - 서류전형 1차면접 - 최종합격 유의사항 ㆍ입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.',
#  '- 데이터 모델링 표준 정의 및 인스펙션 수행 - 데이터 관리 체계 수립 및 검토 수행 - 데이터베이스 아키텍처 설계 및 검토 수행 - 데이터베이스 아카이빙 정책 수립 및 검토 - 메타데이터 표준화 수행 - 성능 개선 및 튜닝 정책/가이드 관리 - 프로젝트 기획 및 구축 수행',
#  '※ YOLO 기반 이미지/영상 실시간 분석, AIoT 융합기술 개발 [빅데이터플랫폼구축 > 빅데이터 플랫폼 아키텍처 설계] 빅데이터 플랫폼 인프라구조 설계하기,빅데이터 입출력구조 설계하기 [빅데이터플랫폼구축 > 빅데이터 수집시스템 개발] 빅데이터 수집시스템 설계하기,빅데이터 수집시스템 구성하기,빅데이터 수집·변환 모듈 개발하기,수집 데이터 검증모듈 개발하기 [빅데이터플랫폼구축 > 빅데이터 분석시스템 개발] 빅데이터 분석시스템 설계하기,빅데이터 분석시스템 구성하기,빅데이터 분석모듈 개발하기 [빅데이터플랫폼구축 > 빅데이터 플랫폼 테스트] 빅데이터 플랫폼 테스트 설계하기,빅데이터 플랫폼 기능 테스트하기,빅데이터 플랫폼 비기능 테스트하기',
#  '- SQL을 사용한 데이터 추출 및 전처리를 통한 지표관리 - 데이터 시각화 및 대시보드(Tableau 등) 제작 및 운영 -  분석 요건 기획 및 데이터 수집 관리 - 데이터에 기반한 가설 수립 및 검증 - 각종 지표 정의 및 트래킹 자동화',
#  '<모집분야> Bioinformatics (생물정보학) 데이터 처리 및 분석 <담당업무> 암 유전체, 전사체, 단백체, 대사체 등 공공 팬오믹스 데이터 확보 암 팬오믹스 데이터 처리 파이프라인 구축 및 최적화 암 팬오믹스 데이터 모델링을 통한 신규 바이오마커 발굴 및 치료 내성 기전 규명 <공통자격요건> 생물정보학, 유전학, 컴퓨터공학 및 유사 학문 전공자 Python, R, MATLAB 및 기타 프로그래밍 언어를 활용한 유전체 분석 경험자 <개별자격요건> 책임급 – 연봉 6,000 ~ 8,000만원 박사 이상 및 동종업계 경력 6년 이상 선임급 – 연봉 4,000 ~ 6,000만원 석사 이상 및 동종업계 경력 2년 이상 <우대사항> NGS (Next-Generation Sequencing) 데이터 처리 및 분석 유경험자 Mass spectrometry 데이터 처리 및 분석 유경험자 암유전체 포함한 관련 연구 경험자 <근무환경> 근무지역: 서울시 서초구 태봉로 114, AI 양재 허브 807호 근무시간: 오전 9시 ~ 오후 6시 (휴게시간 1시간) <복리후생> 자율복장 자유로운 연차/반차 사용 식대지원 구내식당 이용 가능 사내 카페테리아 이용 가능 직무 관련 자기계발비 지원 근로자 여름휴가비 지원 경조사 지원제도 명절 선물 제공 출산전후휴가, 육아휴직, 임신기/육아기 단축근무제도 운영',
#  '데이터엔지니어링: 데이터의 수집/ 가공/ 적재 및 pipeline 관리',
#  '▶ 자금세탁방지(AML) 데이터 분석 – 거래모니터링 시스템 검증, 룰 최적화, STR/CTR 데이터 검증, 위험평가 모델링 ▶ 컴플라이언스 업무 프로세스 및 화면 설계, 데이터 및 IT 개발요건 정의 - 금융정보 자동교환(FATCA/CRS) 시스템 - 금융기관 내부통제 시스템 - 금융기관 이상거래탐지(FDS) 시스템',
#  '-',
#  'Position •\t소속: 전략기획팀 •\t직위: 협의 •\t연봉: 협의 Job Description •\t빅데이터를 이용한 데이터 관리 •\t비즈니스 프로젝트 관리 •\t비즈니스 중, 장기 전략 수립 및 실행 •\t브랜드 및 제품 캠페인 관리 지원자격 •\t화장품 외 다양한 산업계 경험 보유하신 분 •\t마케팅 관련 업무 경험 있으신 분 •\t다양한 프로젝트의 PM 경험 있으신 분 •\t빅데이터를 이용한 전략 기획 경험자 •\t데이터활용 경험자 우대사항 •\t다양한 업종 관련 경력 우대 •\t외국어(영어/중국어/일본어) 능통자 우대 근무조건 •\t근무형태: 정규직 •\t근무일시: 주 5일 (월~금) •\t근무시간: 오전 9시~6시 (월~금) •\t급여: 협의 •\t근무지역: 서울 강남구 - 서울 7호선 강남구청역에서 50m 이내 •\t복리후생: 4대보험, 건강검진, 생일휴가, 문화회식 (월1회 전시회 관람), 간식 외',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '네트워크/서버/보안, 빅데이터/AI, 웹개발, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, 웹기획/PM/웹마케팅, DBA/데이터베이스',
#  '-  데이터 구축 - 이미지 데이터라벨링(폴리곤/비박스)',
#  '-',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '무관-AI/빅데이터-데이터라벨링-서울',
#  '- AI/빅데이터/클라우드 인프라 클러스터 구성 및 운영 - AI/빅데이터/클라우드 아키텍처 설계 및 구축',
#  '- AI/빅데이터/클라우드 관련 비즈니스 모델 발굴 - AI/빅데이터/클라우드 과제 관리 및 팀 운영',
#  '-',
#  'DBA/데이터베이스',
#  'DBA/데이터베이스',
#  'DBA/데이터베이스',
#  '설문/통계/리서치, DBA/데이터베이스',
#  '-',
#  'DBA/데이터베이스',
#  '-',
#  'DBA/데이터베이스',
#  'DBA/데이터베이스',
#  'DBA/데이터베이스',
#  '빅데이터/AI',
#  'DBA/데이터베이스',
#  '빅데이터/AI',
#  '빅데이터/AI',
#  '설문/통계/리서치, DBA/데이터베이스',
#  'DBA/데이터베이스',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  'DBA/데이터베이스',
#  '기획/전략/경영, DBA/데이터베이스',
#  'DBA/데이터베이스',
#  '빅데이터/AI',
#  '-',
#  '-',
#  '-',
#  'DBA/데이터베이스',
#  '-',
#  'DBA/데이터베이스',
#  '빅데이터/AI, 웹기획/PM/웹마케팅',
#  '빅데이터/AI',
#  '증권/투자/펀드/외환, DBA/데이터베이스',
#  'DBA/데이터베이스',
#  'DBA/데이터베이스',
#  'DBA/데이터베이스, ERP/시스템개발/설계',
#  '-',
#  '-',
#  '-',
#  'DBA/데이터베이스',
#  '-',
#  '-',
#  'DBA/데이터베이스',
#  '마케팅/PR/분석, DBA/데이터베이스',
#  '-',
#  '웹기획/PM/웹마케팅, DBA/데이터베이스, QA/테스트/검증',
#  'B2B영업/기술영업, DBA/데이터베이스',
#  '-',
#  'ㆍ파트너사의 빅데이터를 활용한 타겟 마케팅 기획 및 운영 ㆍ기존 클라이언트 관리 및 신규 매체 제안 ㆍ광고 성과(효율)분석 및 인사이트 도출',
#  '설문/통계/리서치, DBA/데이터베이스',
#  'DBA/데이터베이스',
#  '빅데이터/AI',
#  'DBA/데이터베이스',
#  '-',
#  'DBA/데이터베이스',
#  '빅데이터/AI',
#  '설문/통계/리서치, DBA/데이터베이스',
#  'DBA/데이터베이스',
#  '-',
#  '서비스 기획/운영/메타데이터',
#  '-',
#  '당소는 쾌적한 환경의 근무 환경을 제공하고 있습니다. 함께 성장해나가실 신입 직원분을 구인중에 있으니 많은 지원 부탁드립니다. 감사합니다. 해당업무는 2인이 진행하며 주5일 근무합니다. 다만, 평일 5일이 아닌 두분 협의하에 매일 같이 업무가 돌아가야 합니다. ex A조 -> 화~ 토 근무 (월, 일 휴무) B 조-> 일~목 근무 (금, 토 휴무) 업무는 명절등 모든날을 포함해서 업무가 진행되어야 하며 주말, 명절, 공휴일 근무는 오전 근무만 합니다. 특정 프로그램에서 데이터를 다운받아 내부관리하는 엑셀에 데이터를 기입하고 관리하는 작업입니다. 엑셀을 이용하며 위 작업한 데이터를 위하고 라는 내부관리 프로그램에 입력도 해야합니다. 추가로 세금계산서 발급 등의 업무도 있습니다.',
#  '품질 검사원 (팀원) 모집 품질 관리, 순회검사, 초.중.종물 검사, 3차원 측정기, 비전 측정기 데이터 측정,  성적서 관리, 샘플 데이터 측정 등',
#  '[주요 업무 - 오시면 이런 업무를 하게 되실거에요! ] - 기존 API 서비스 유지관리 및 신규 API 서비스 개발 - 세일즈 데이터 분석 플랫폼 서비스 개발(데이터엔지니어 팀과 협업개발) - 세일즈 데이터 기반 신규 프로젝트의 아키텍처 설계 및 개발 - 대용량 데이터 처리 인프라 구축 및 유지관리 [자격 요건 - 이런 분을 찾고 있어요!] - RDBMS 환경에서 DB 스키마를 설계하실 수 있는 분 - 검색 서비스 개발, 최적화를 하실 수 있는 분 - Node.js Backend 개발 및 운용, 유지관리를 하실 수 있는분 - AWS 기반의 MSA구조 Node.js 개발 및 서비스간의 node 모니터링 및 트랜잭션 유지관리를 하실 수 있는 분 - AWS, GCP 클라우드 환경 운영경험 3년 이상이거나 그에 준하는 실력을 보유하신 분 - Hadoop과 Spark 경험이 있으신 분 - 다양한 기술 스택에 대한 이해를 바탕으로 아키텍쳐를 설계 경험이 있으신 분 [우대 사항 - 이런분이면 더 좋아요!] - Spring(Java) 기반 프레임워크를 활용하여 인증/보안, 검색, REST API 설계 및 개발 경험이 있으신 분 - Python과 Django 프레임워크나 flask 프레임워크를 사용하여서 backend 개발 경험이 있으신 분 - 클린 아키텍처, DDD 등 프로젝트 구조와 설계에 관심이 있으신 분 - Kubernetes, Docker 등 컨테이너 환경의 배포 경험이 있으신 분 - 데이터 비즈니스에 대한 이해가 있는 분 [복지 및 혜택] 딥세일즈는 팀원들의 편의를 위해 여러 복지를 갖추고 있어요. 회사 성장에 맞게 복지와 혜택도 빠르게 업그레이드 되고 있어요~! 현재 저희는 업무에만 최대한 집중할 수 있도록!! - 복장은 자유롭게! (비오는 날 반바지, 크록스 OK) - 팀원들의 점심은 든든하게 점심 식대 17,000원 제공!!! 팀원이 개별적으로 성장할 수 있도록 쓸모없는 시간은 줄이고, 필요한 교육을 들을 수 있도록!! - 삼성역에서 사무실 Door to Door 10분 ( 우리의 시간은 소중하니깐!) - 매주 금요일 5시 30분 퇴근 ( 우리의 시간은 소중하니깐 x2!! ) - 업무 성장에 필요한 도서 및 강의 지원 - 1년 이상 근무자에게 ‘내일채움공제’ 가입 제공 팀원들의 행복을 위해!! - 다양한 간식 무한 제공 - 폴바셋 커피(에스프레소 머신 및 드립), 차(tea) 무한 제공 - 매주 목요일, 금요일 오후 4시~6시 맥주 제공 - 점심시간은 넉넉하게 1시간 30분!! ( 내 점심 시간은 소중하니깐!!! ) - 업무 성과에 따라 스톡옵션 제공 [고용형태 및 근무환경] - 정규직 - Culture-Fit과 On boarding을 위한 수습기간 3개월 (급여는 100% 지급) - 장소 : 위워크 삼성2호점 - 시간 : 월~금, 09 : 00 ~ 18 : 00 - 점심시간 : 11시 30분 ~ 13시 (1시간 30분) [합류여정] - 입사 지원 서류 : 이력서 또는 자기소개서, Notion 등 포트폴리오 혹은 경력 기술서 (여러분의 이야기를 자유롭게 적어주세요! - 자유양식) - 합류 여정 : 서류 전형 > 인터뷰 전형 > 처우협의 > 최종 합격 - 해당 공고는 수시 채용으로, 채용 완료 시 조기에 마감될 수 있습니다. - 지원자의 이력 및 경력 사항에 따라 일부 과정이 생략되거나 추가될 수 있습니다.',
#  '-',
#  '데이터 기반의 CRM 메세지 발송 관리',
#  '-',
#  '-',
#  '저희 회사는 우편물 발송 전문 회사로써 평문형식의 데이터를 안내장 혹은 청구서 및 고지서 등의 형식에 맞게 데이터를 출력하여, 우편발송을 하는 전문 업체입니다. 프로그램 개발이 아니어도 자료처리의 기본 개념만이라도 습득하신 분이면, 편하게 입사 지원 부탁드립니다.',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '자동차 관련 데이터 비교분석 일입니다.',
#  '- 사업계획서 작성 및 기안 - 사업 및 프로젝트 기획 / 전략수립 및 운영 - 기술 및 제품 시장조사 및 분석 - 데이터 정리 및 분석 - 유관기관 연계 / 협업',
#  '마케팅/PR/분석',
#  '-',
#  '-',
#  '-',
#  '-',
#  "◆ 데이터 엔지니어 [2명] [주요 업무] ㆍ실시간으로 대용량 데이터를 분석 및 조회 ㆍ데이터 구조화 및 파이프라인 아키텍처 구축 및 유지 ㆍ데이터 모델링 및 데이터 분석 환경의 최적화와 자동화 ㆍ다양한 데이터 소스에서 데이터를 최적으로 추출, 변환 및 로드하는 데 필요한 인프라를 구축 [자격 요건] ㆍ학력 : 무관 ㆍ경력 :  1년 이상 필수 ㆍ다양한 이해 관계자와 조율이 가능한 커뮤니케이션 능력 ㆍ데이터 전처리 및 모델링을 위한 개발 경험 2년 이상 ㆍ AWS 기반의 데이터 플랫폼 개발 및 운영 역량이 있으신 분 ㆍ대용량 데이터 처리 및 분석을 위한 시스템 요구 사항을 이해하고 구축 경험이 있으신 분 ㆍSpark을 이용한 빅데이터 처리 경험이 있으신 분 ㆍAirflow, Jenkins 운영 경험이 있으신 분 ㆍSQL, Python에 대한 기술 역량이 있으신 분 ㆍ프로젝트 관리 및 문제 해결 역량이 있으신 분 ㆍ높은 창의성, 혁신성, 결과 지향적 사고 역량이 있으신 분 [우대 사항] ㆍ컴퓨터 / 시스템 공학 우대ㆍ정보처리기사 우대ㆍ영어가능자 우대ㆍHadoop 우대 ㆍAWS 관련 교육 이수 or 운영 경험 ㆍAWS 클라우드 서비스 내 구현 및 운영 경험을 보유하신 분 ◆ 웹개발자 ( 프론트엔드 )[1명] [주요 업무] ㆍ데이터 플랫폼 솔루션 개발 및 프로젝트 수행 [자격 요건] ㆍReact , Nextjs 등의 프레임워크 기반 개발 경험 ㆍHTML, CSS 등  W3C 웹 표준 규격에 대한 이해자\ufeff ㆍAWS 환경에서의 CI / CD 경험이 있으신 분 ㆍ포지션을 넘어 비즈니스 동료, 파트너로서 비즈니스 도메인에 대한 깊은 이해를 추구하시는 분 ㆍ커뮤니케이션과 협업 스킬이 좋으신 분 [우대 사항] ㆍ컴퓨터 공학, 전산 분야의 학사 학위 이상(또는 동등한 경력) 우대 ㆍ영어 가능자 우대 ◆ 웹개발자 ( 백엔드 )[1명] [주요 업무] ㆍ데이터 플랫폼 솔루션 개발 및 프로젝트 수행 [자격 요건] ㆍJava 에 대한 충분한 지식을 보유하신 분 ㆍAWS 클라우드 서비스 내 구현 및 운영 경험 ㆍ백엔드 시스템에 대한 설계 및 개발 / 운영 경험 ㆍ데이터베이스 설계 경험 ㆍSQL 지식이 있으신 분 ㆍJava 기반의 서비스 개발 / 운영 경험 ㆍ다양한 이해 관계자와 조율이 가능한 커뮤니케이션 능력을 보유하신 분 [우대 사항] ㆍ컴퓨터 공학, 전산 분야의 학사 학위 이상(또는 동등한 경력) 우대 ㆍ영어 가능자 우대 [조직 문화 및 사무 환경] ㆍ 자율적인 업무 시간 관리- Core Time (11시 ~ 4시)만 지켜주세요 ㆍ 자유로운 의견 교환과 상호 신뢰에 근거한 수평적 커뮤니케이션 '님' 호칭 사용 ㆍ 시간, 장소, 상황에 맞게 개성을 표현할 수 있는 자유 복장 ㆍ 입사 시 직무 별 최적화된 장비와 소프트웨어 제공• 업무 관련 도서, 강의 수강 지원 ㆍ 명절 선물, 종무식 선물 등 전 직원 지급 ㆍ 건강 검진 , 각종 경조사 비 지원 ㆍ 자유로운 연차 사용과 예비군, 건강 검진, 결혼 등 각종 경조사에 해당하는 휴가 추가 부여 [근무 예정지] 송파구, 종로구, 마포구",
#  '[주요업무] - 고객 세그먼트 설계, 행동 패턴, 구매이력, 선호도 파악 등 고객 데이터 분석 - 분석 데이터 기반 개인화 마케팅 전략 수립, 캠페인 설계 및 운영((A/B TEST, 채널별 메시지 기획 포함) - 고객 충성도 및 장기적 관계 구축을 위한 프로그램 개발 - 데이터 기반 마케팅 성과 측정 및 분석, 개선을 위한 인사이트 도출 [자격요건] - 5년 이상의 CRM, 고객 데이터 분석, 타겟 마케팅 관련 경력을 보유하신 분 - 데이터 분석 기술 및 관련 도구 활용능력이 우수하신 분(예: Google Analytics, CRM 소프트웨어) - 명확한 커뮤니케이션 능력과 데이터를 기반한 가설 수립 및 검증 과정이 가능하신 분 [우대사항] - CRM 마케팅 툴 사용 경험을 보유하신 분 - SQL, Python 프로그램 이해도가 높고 활용이 가능하신 분 - 국내 외 주요 선불카드 Payment 서비스, O2O(B2C) 서비스 및 보상형 앱 서비스 분야에서의 사업 리드 경험',
#  '▣ 담당업무 - 고객 행동 분석을 위한 Google Analytics 분석 및 관리 - 고객 및 주문 기반 데이터 분석 - CRM 및 고도화 된 분석을 위한 고객 세그먼트 구성 - 데이터 정제 및 고도화를 위한 데이터 관리 - 데이터 관리를 위한 DB 스키마 및 데이터 처리 과정 효율화',
#  '1. 데이터 관리, 데이터 활용  등 데이터 측면 솔루션 개발 - 데이터 관리 : 메타데이터 관리, 데이터 연계 관리, 데이터 거버넌스 관리 등 - 데이터 활용 : 빅데이터 분석 플랫폼, AI 적용 서비스 솔루션 개발 등 2. 솔루션 개발 계획 수립 및 연구과제 지원 등',
#  '담당업무 ㆍ데이터 분석 서비스를 개발 ㆍ구축된 분석 서비스의 다양한 데이터를 시각화 하기 위한 UI 개발 ㆍ분석 데이터를 제공하기 위한 API 개발 ㆍ자동 메시지 발송을 위한 알람 서버를 개발 자격요건 ㆍJava, JSP, Javascript 언어로 개발 경험 ㆍHTML5, CSS 기본지식 및 마크업 능력 ㆍJQuery 사용 경험 ㆍVue JS, React, Angular 중 하나 이상 경험 ㆍRestful API를 활용한 개발 경험 우대사항 ㆍ웹표준, 웹 접근성에 대한 적용 경험 ㆍ검색엔진 사용 경험 ㆍ데이터 시각화 관련 경험 ㆍdocker를 사용한 서비스 개발 경험 ㆍSVG, d3.js, Zingchart 등 차트라이브러리 사용 경험 사용하는 기술 ㆍ웹 프레임워크로 Spring, Spring Boot, Mybatis, 웹서버는 Tomcat, Apache 사용 ㆍ데이터 저장에는 Oracle, PostgreSql 사용 ㆍ개발언어는 Java, 자바스크립트 라이브러리는 JQuery, Vue.JS, Kendo UI, Zingchart 사용 ㆍ데이터를 효율적으로 분석하기 위해 오픈소스 기반의 플랫폼 사용(Elasticsearch, Kibana, Logstach) ㆍ소스코드 형상관리를 위해 SVN을 사용 ㆍ통합, 테스트, 배포를 위해 Jenkins를 사용 ㆍ업무 관리를 위해 네이버웍스, Redmine, Slack을 사용 복지 및 혜택 ㆍ커피 메이커, 음료 자동판매기, 간식 바 지원 ㆍ휴게실 지원 ㆍ팀별 회식비 지원 ㆍ매주 금요일은 2시간의 자유로운 점심 시간 ㆍ3, 5, 7년 근속 시 리프레시 휴가(5일) 및 근속 장려금(백만원) 지급 ㆍ생일 축하 유급 휴가 부여 ㆍ경조사(50만, 휴가 5일) 지급 ㆍ설, 추석 명절 10만원 상품권 제공 ㆍ함께 일하는 구성원 추천시 추천자와 입사자 모두에게 50만원 지급 ㆍ육아 휴직 지원 ㆍ도서 구입비 및 직무 관련 교육비용 지원 ㆍ자유로운 연차 사용 타파크로는 빅데이터 기술을 이용하여 소셜 데이터 속에 숨겨진 가치를 해석하고 고객이 원하는 인사 이트를 제공합니다. 더불어 어떻게 하면 고객들이 궁금해 하고 알고 싶어하는 정보는 무엇일까 라는 고민을 하면서 일 하는 조직입니다. 고객이 원하는 정보를 찾을 수 있도록 도움을 줄 수 있는 서비스를 만듭니다. 기술연구소는 수집, 웹, 검색, 인프라 파트로 구분되며 2~12년 경력을 가진 멤버로 구성되었습니 다. 직군에 국한하지 않고 본인의 흥미로 의지가 있다면 다른 업무도 지원 가능합니다.',
#  '- 다양한 데이터 소스에서 정보를 수집하고 분석하여 조직 내부 또는 외부의 통찰력 도출 - 리서치 및 조사 수행: 시장 조사 / 소비자 인사이트  경쟁 분석 등 - 수집한 데이터와 분석 결과를 활용하여 의사 결정 지원 - 비즈니스 전략 수립 및 마케팅 전략 개발 - 다양한 데이터 분석 도구와 기술을 활용한 데이터 처리 및  분석 - 다양한 부서 및 팀과 협업하여 프로젝트를 진행하고 효과적인 목적 달성',
#  '• 오픈서베이는 고객이 가지고 있는 비즈니스 이슈를 제품과 데이터를 활용해 해결하며, 이를 위해 데이터를 수집하고 분석하는 전 과정을 ‘프로젝트’라고 합니다. AM은 담당 프로젝트가 성공적으로 종료되기까지 필요한 모든 일을 기획하고 운영합니다. • 프로젝트는 크게 다음과 같은 단계로 진행됩니다 ⸰ 고객의 비즈니스 이슈를 해결하는 최적의 리서치 방법을 고민하고 제안합니다. ⸰ 적합한 리서치 대상자를 찾고, 데이터를 수집합니다. ⸰ 수집한 데이터를 분석합니다. • AM은 다양한 기업 고객의 여러 프로젝트를 동시에 수행해야 합니다. 따라서 프로젝트의 특징을 고려해 우선순위를 설정하고, 내/외부 전문가들과 적극적인 협업을 통해서 효율적으로 업무를 진행해야 합니다.',
#  '빅데이터 자료 수집 계약직 직원 모집 - 인공지능(AI) 데이터 확보를 위한 라벨링 작업 - 차량, 사람, 자동차번호판, 안전모 등 라벨링 * 데이터라벨링이란? : 컴퓨터를 활용하여 인공지능(AI) 적용 전에 학습 데이터에 특정 값을 부여 해주는 것 : 데이터 라벨링 툴 교육 수료 후(1~2시간) 바로 근무 가능 * 중식비 포함 * 3개월 계약직',
#  '담당하시게 될 업무를 소개합니다 영업 전략 수립 및 프로세스 개선 신규 고객 데이터 분석 및 컨설팅 방법론 개선 신규 서비스 영업 전략 제시 및 실행, 최적의 방법 도출 신규 영업 파이프라인 개발 관리 고객사 피드백 수집을 통한 시장의 unmet needs 발굴과 제안 영업 채널 다변화 전략 실행 세일즈 프로모션 기획 및 성과 리뷰 신규 리드 발굴을 위한 아웃바운드 세일즈 전략 수립 영업 성과 지표 관리 및 현황 분석 영업 forecasting report 및 실적 관리 영업 활동 기업 니즈 또는 액션 아이템을 기반으로 신규BM 개발/기획하고, 타겟 기업에게 빠르게 제안하여 사업타탕성 분석 어카운트의 데이터 분석을 통한 컨설팅 및 솔루션 제안 기존 어카운트 관리 : 기업에서 솔루션 도입 이후 지속적으로 이동 데이터를 모니터링하며, 니즈에 부합하는 상품 컨설팅 신규 어카운트 확보 : 신규 법인 니즈 및 이동 데이터 분석을 통해 문제점을 진단하여, 불필요한 고정비를 없애고 효율적인 차량 이용 솔루션 제안',
#  '부산 도시브랜드 경쟁력 강화 평가지표 구축사업 (채용일~2024.12.31) 1. 부산시 도시지표 개발 및 분석 2. 부산시 공공데이터 및 민관데이터 분석 및 시정 인사이트 개발 3. 기타 디지털도시정보센터 연구 업무 지원',
#  '- 데이터 수집 및 전처리 - 데이터 분석 및 모델링 - 시각화 및 결과 해석 - 모델 평가 및 최적화',
#  '국립금오공과대학교에서는 2024년 국립대학 육성사업 업무 추진을 위해 참신하고 유능한 인재를 다음과 같이 모집합니다. 1. 채용분야 및 인원 ◎ 전문계약직(학내 데이터 분석시스템 업무) 1명 - 학내 데이터 분석시스템 관련 업무 2. 접수기간: 2024.2.9.(금) ~ 2.16.(금) 18:00 3. 접수방법: 이메일 접수 * 기타 자세한 사항은 붙임파일 참조 바랍니다. 2024년 2월 8일 국립금오공과대학교총장',
#  '<주요업무> - 인공지능 알고리즘 개발 및 연구 - 인공지능 서비스 솔루션 개발 - Vision/Time Series/NLP 데이터 처리 및 분석 <우대사항> - 전반적인 AI 기술에 대한 이해가 있으신 분 - Vision/Time Series/NLP 딥러닝 모델에 대한 이해 및 학습경험 - 딥러닝 프레임워크(Pytorch, Tensorflow 등) 사용 - 데이터를 분석하거나 모델링을 통해 결과를 도출해낸 경험이 있으신 분 * 서류전형 합격자에 한하여 면접일정 별도 안내드립니다.',
#  '-',
#  '**[서초구]부동산114// 부동산 데이터 수집원 모집(1명) - 근무지:서초구 효령로346,8~9층 - 주 5일 (월~금) - 근무시간: 08:00~17:00  or  08:30~17:30 - 월급: 2,060,740원 - 엑셀활용 우수자 모집 - 부동산 시세 조사, 문서정리, 데이터입력, 아파트 상세정보 구축 및 정비, 관련 CS 처리 **[서초구]부동산114 // 외부 데이터 수집 담당자 모집(1명) - 근무지:서초구 효령로346,8~9층 - 주 5일 (월~금) - 근무시간: 08:00~17:00  or  08:30~17:30 - 월급: 2,060,740원 - 엑셀활용 우수자 모집 - 외부(행안부, 한국부동산원, 금감원, 통계청 등)의 부동산 금융 데이터를 당사 구축 폼에 입력, 검수 **[서초구]부동산114 // 아웃바운드 콜조사원 모집(1명) - 부동산 시세 및 기타정보 콜조사(only 아웃바운드) 당사에 시세를 제공하는 중개사무소에 전화해서 매주 부동산 시세  및  부동산 정보 (평형, 관리비 등 수집이 안된 항목) 전화조사 - 주3일 근무 (월, 화, 수 오전 8시 30분 ~ 오후 5시 30분 / 조정 가능), "업무량에 따라서 목,금 추가 근무 요청드릴 수 있음" - 일당 94,656원(주휴 포함) / 엑셀 가능자, 전화조사 경험자 우대 - 연차 사용이 자유로움/커뮤니케이션이 원활한 분 지원바람 - 문의:070-4048-6104',
#  '-스마트뱅킹/ 마이데이터 앱, 웹 등 디지털채널 UI/ UX 디자인 -사용자 관점 및 데이터 기반 UX 설계 -디자인 시스템가이드 구축 및 관리 - 제휴 채널 및 마케팅 디자인',
#  '- 스마트뱅킹/마이데이터 앱, 웹 등 디지털채널 UI/UX 디자인 - 사용자 관점 및 데이터 기반 UX 설계 - 디자인 시스템 가이드 구축 및 관리 - 제휴 채널 및 마케팅 디자인',
#  '- CRM 데이터 분석 및 전략수립 - 고객 DB 추출 및 가공, 데이터화 - 모바일앱 멤버십 기획 및 운영관리',
#  '[담당업무] 1. CRM 데이터 분석 및 전략수립 - CRM 리포트 관리 및 고객 데이터 기반 보고서 기획/관리 - 고객 DB추출, 가공, 분석을 통한 인사이트 도출 - Target 마케팅 기획 및 성과분석 2. 모바일 APP 멤버십 기획 및 운영관리 - 신규회원 및 승급유도 등 이벤트 기획 - 멤버십 리워드 프로그램 분석, 기획 및 개편 [자격요건] - 관련업무 경력 7년 이상자 (과장급) - 통계 프로그램 (SAS,, R, SQL 등) 활용 가능자 우대 - 4년제 대학 졸업자 이상 (경영/통계학 우대)',
#  '담당하시게 될 업무를 소개합니다 쏘카존 운영 관련 대관 업무 기 개설된 카셰어링 스팟 매니징 수익성 확보를 위한 쏘카존 매출 데이터 분석 및 관리 데이터에 기반한 부산/울산/경남 지역 우수 카셰어링 입지 분석 지역 기반/수익 관점의 사업 확대를 위한 각종 기획 및 실행 현장 커뮤니케이션을 통한 카셰어링 쏘카존 신규 개설',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, 웹개발, 응용프로그램개발, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, 웹개발, 응용프로그램개발, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, 웹개발, 응용프로그램개발, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, 전기/전자/제어, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, 응용프로그램개발, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, 응용프로그램개발, DBA/데이터베이스',
#  '빅데이터/AI, 응용프로그램개발, DBA/데이터베이스',
#  '빅데이터/AI, 웹개발, 응용프로그램개발, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '-',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, DBA/데이터베이스',
#  '빅데이터/AI, 응용프로그램개발, DBA/데이터베이스',
#  '빅데이터/AI, 응용프로그램개발, DBA/데이터베이스',
#  '빅데이터/AI, 응용프로그램개발, DBA/데이터베이스',
#  '-',
#  '모집부문상세내용공통 자격요건ㆍ 학력 : 무관ㆍ 경력 : 신입/경력데이터인텔리전스팀데이터인텔리전스팀 0명담당업무ㆍ주요업무ㆍ 데이터 서버 관리 및 유지ㆍ 고객사 업무프로세스 분석 및 관련 데이터 수집(엑셀 VBA, 파워쿼리 활용)ㆍ MS POWER BI 활용한 데이터 분석, 모델링 및 VISUALIZATIONㆍ MS POWER FLATFORM 활용 업무 효율화\n            ㆍ기타 필수 사항\n        우대사항ㆍ컴퓨터/시스템공학, 수학/통계학ㆍ데이터분석전문가(ADP), 데이터분석준전문가(ADsP), 빅데이터 분석기사ㆍ해당직무 인턴경력, 통계분석능숙자, 해당직무 근무경험, 엑셀 고급능력자, 지방근무 가능자',
#  '-',
#  '-',
#  '-',
#  '-',
#  '공통 자격요건ㆍ학력 : 학사이상 (졸업예정자 가능)ㆍ경력 : 관련 경력 2~3년 필수ㆍ해외여행에 결격 사유가 없는 자ㆍ다양한 분야에 대한 도전을 좋아하시는 분ㆍ학력 : 대졸 이상 (4년)데이터 분석 및 AI 개발 1명담당업무ㆍ담당업무ㆍ데이터 분석 및 AI 개발ㆍPython 등을 활용한 텍스트 데이터 수집, 분석, 구축 처리ㆍLLM 업무 기획 및 수행ㆍAI 기술 개발에 필요한 언어 자원 구출(Labeling)ㆍ인공지능 R&D 연구 개발 및 국책 과제 지원필요스킬ㆍPython우대사항ㆍIT 계열, 통계학 관련 전공자ㆍMachine Learning/Data Mining 수행 경험',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  "모집부문상세내용공통 자격요건ㆍ학력 : 대졸 이상 (4년)지능화 감시체계 사업[ 업무 안내 ]ㆍ데이터셋 구축 사업 제반사항 관리 업무(PMO)ㆍ데이터 및 프로젝트 산출물 작성 및 관리ㆍ프로젝트 일정 및 인력 관리ㆍ데이터 수집 및 가공 사업 운영 및 모니터링ㆍ일부 라벨링 작업 및 검수 백업\xa0\xa0[ 업무 진행을 위한 필요 역량 ]ㆍ원활한 커뮤니케이션 능력을 보유하신 분ㆍ주도적인 업무 능력이 있으신 분ㆍ사업 특성(야간 촬영)에 따른 야간 근무 또는 출장 업무에 문제가 없으신 분\xa0*단,\xa0야간 근무에 따른 근무 스케줄 조정(익일 오전 오프 or 데이 오프) 총괄 PM과 협의 예정[ 필수(자격) 조건 ]ㆍ라벨링 프로젝트 or 사업 '운영'에 참여 경력이 있으신 분ㆍ근무지(논산시 양촌면 거사리 부근)로 출퇴근이 문제 없이 가능하신 분 (자차 이용 추천)ㆍ사업 특성에 따른 보안지역 출입을 위한 신원 조사에 문제가 없으신 분*개인정보 보호를 위하여 아래의 서류를 공공신원조회 '사이트'에 직접 제출 필수**필요서류: 신원진술서, 개인신용정보서,병역관계증명서 등\xa0ㆍ공식 문서 작성 능력 또는 보고서 작성 경험(파워포인트, 엑셀, 구글 스프레드시트 등)이 있으신 분ㆍ기본적인 OA 및 컴퓨터 활용 능력을 보유하고 계신 분\xa0[\xa0우대 조건 ]ㆍ약 1년 11개월 연속적으로 근무가 가능하신 분\xa0ㆍ데이터 수집 및 가공 사업 or 프로젝트 운영 PM 및 PMO 경력이 있으신 분ㆍ군 사업 경력이 있으신 분ㆍ공공 및 정부과제 사업 경력이 있으신 분우대사항",
#  'ㆍ근무형태:계약직-1년11개월2023.3.4 이전 근무 시작 권장\xa0장기 계약(약 1년 11개월) 근무 가능인원 우대ㆍ근무일시:주 5일(월~금) 09:00~18:00사업 특성(야간 촬영)에 따른 야간 근무 또는 출장 업무에 문제가 없으신 분 우대 *단, 야간 근무에 따른 근무 스케줄 조정(익일 오전 오프 or 데이 오프) 총괄 PM과 협의 예정ㆍ근무지역:(33021) 충남 논산시 양촌면 황산벌로 1040 국방대학교',
#  '-',
#  '-',
#  '-',
#  '공통 자격요건ㆍ학력 : 대졸 이상 (4년)백엔드 Python 개발자 신입/경력 채용개발실 2명담당업무ㆍ지원자격ㆍ경력 : 무관 (신입도 지원 가능)(사원, 팀원급)\n            ㆍ기타 필수 사항\n        - 전기/전자공학, 컴퓨터/시스템공학, 산업공학우대사항ㆍ해당직무 근무경험, 석사학위 수여자, AWS, Docker, Linux, Github, Python, Django, RDBMS',
#  '-',
#  '-',
#  'ㆍ접수기간:2024년 2월 6일 (화) 17시  ~ 2024년 4월 6일 (토) 24시ㆍ접수방법:사람인 입사지원ㆍ이력서양식:사람인 온라인 이력서ㆍ제출서류:· (필수) 입사지원서(자기 소개, 학력/경력 소개 내용 등 포함)\n· (필수) 대학교, 대학원 성적표 및 졸업증명서\n· (선택/우대) 프로젝트 산출물 또는 포트폴리오 (개발 및 분석 프로젝트의 경우 코드 제출 필수)\n· (선택/우대) 석사학위 이상자는 졸업논문\n· 필수 서류 미제출 시 서류 탈락',
#  '-',
#  '-',
#  '-',
#  '모집부문상세내용공통 자격요건ㆍ학력 : 무관보안,네트워크 영업영업2팀 1명담당업무ㆍ지원자격ㆍ경력 : 경력 (년수무관)(사원, 대리, 과장급)\n            ㆍ기타 필수 사항\n        우대사항ㆍ2종소형운전면허ㆍ해당직무 근무경험',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '공통 자격요건ㆍ학력 : 무관AI 데이터 가공 및 검수 계약직시험평가연구소 3명담당업무ㆍ지원자격ㆍ경력 : 경력 1년 이상(연구원, 선임연구원급)ㆍ수행 업무 : AI 학습용 데이터 가공 보조 및 검수\n            ㆍ기타 필수 사항\n        우대사항ㆍ인근거주자, 해당직무 근무경험',
#  '-',
#  '-',
#  '-',
#  '-',
#  '모집부문상세내용공통 자격요건ㆍ학력 : 대졸 이상응용 / 웹 프로그램 / 데이터베이스 개발 0명담당업무ㆍ지원자격ㆍ경력 : 신입\xa0(연구원)\n            ㆍ기타 필수 사항\n        담당업무ㆍ응용프로그램 개발 (C#, Java, ASP.NET, Web 등)ㆍ데이터베이스 개발 (Oralce, MSSQL 등)우대사항ㆍ컴퓨터/시스템공학, 공학계열, 수학/통계학ㆍTOEIC 00급(점) 이상, TOEFL 00급(점) 이상ㆍ정보처리기사',
#  '-',
#  '-',
#  '-',
#  '-',
#  '공통 자격요건ㆍ학력 : 대졸 이상 (4년)(빅데이터/AI(머신러닝딥러닝)/파이썬/자바) 강사채용 3명담당업무ㆍ지원자격ㆍ경력 : 경력 2년 이상\n            ㆍ기타 필수 사항\n        우대사항',
#  '-',
#  '-',
#  '-',
#  '-',
#  '모집부문상세내용사업운영부[담당업무]ㆍ부동산 권리조사 상품기획ㆍ권리조사 서비스 운용 및 프로세스 개선ㆍ부동산 권리조사 사고 원인 추적 및 분석[자격요건]ㆍ부동산 권리조사 상품 및 서비스 기획 경력 보유자ㆍ부동산 권리조사 업무 수행 경력 보유자ㆍ금융권 협업 경험 보유자[우대사항]ㆍ관련 직종 경험자ㆍ부동산 관련 전공자 또는 관련 자격증 보유자법인영업부담당업무ㆍ[담당업무]ㆍ전세대출 관련 금융권 B2B 영업ㆍ시장 동향 파악, 상품 제안, 입찰업무 대응ㆍ고객사별 마케팅 및 신규 거래처 발굴[자격요건]ㆍ부동산 권리조사 상품 및 서비스 기획 경력 보유자ㆍ금융권 법인영업 경력 보유자[우대사항]ㆍ관련 직종 경험자ㆍ부동산 관련 전공자 또는 관련 자격증 보유자ㆍ금융권 또는 금융권 영업 경력 보유자\n            ㆍ기타 필수 사항\n        우대사항',
#  '-',
#  '-',
#  '-',
#  '-']

# %%
def make_wordcloud(title_list, stopwords, word_count):  # 딕셔너리로 만듦
    okt = Okt()
    sentences_tag = []
    # 형태소 분석하여 리스트에 넣기
    for sentence in title_list:
        morph = okt.pos(sentence)
        sentences_tag.append(morph)
        print(morph)
        print('-' * 80)
    noun_adj_list = []
    # 명사와 형용사만 구분하여 리스트에 추가
    for sentence1 in sentences_tag:
        for word, tag in sentence1:
            if tag in ['Noun', 'Adjective', "Alpha"]:
                noun_adj_list.append(word)
    # 형태소별 count
    counts = Counter(noun_adj_list)
    tags = counts.most_common(word_count)
    print('-' * 80)
    print(tags)
    tag_dict = dict(tags)
    # 검색어 제외 방법 2: dict에서 해당 검색어 제거
    for stopword in stopwords:
        if stopword in tag_dict:
            tag_dict.pop(stopword)
    print(tag_dict)
    if platform.system() == 'Windows':
        path = r'c:\Windows\Fonts\malgun.ttf'
    elif platform.system() == 'Darwin':  # Mac OS
        path = r'/System/Library/Fonts/AppleGothic'
    else:
        path = r'/usr/share/fonts/truetype/name/NanumMyeongjo.ttf'
    img_mask = np.array(Image.open('cloud.png'))
    wordcloud = WordCloud(font_path=path, width=800, height=600,
                          background_color="white", max_font_size=200,
                          repeat=True,
                          colormap='inferno', mask=img_mask)
    cloud = wordcloud.generate_from_frequencies(tag_dict)
    plt.figure(figsize=(10, 8))
    plt.axis('off')
    plt.imshow(cloud)
    plt.show()


if __name__ == '__main__':
    #search_word = "ChatGPT"  # 검색어 지정
    #title_list = []
    stopwords = ['데이터', "빅데이터", "및", "이상", "등", "관련", "분", "위", "있으신"]  # wordcloud에서 제외할 단어
    # 1~200번게시글 까지 크롤링
    #get_titles(1, 200, search_word, title_list)
    # 단어 50개까지 wordcloud로 출력
    make_wordcloud(title_list, stopwords, 50)
# Out:
# [('데이터', 'Noun'), ('수집', 'Noun'), (',', 'Punctuation'), ('정제', 'Noun'), ('데이터', 'Noun'), ('분석', 'Noun'), ('인공', 'Noun'), ('지능', 'Noun'), ('개발', 'Noun'), ('논문', 'Noun'), ('연구', 'Noun')]
# --------------------------------------------------------------------------------
# [('자료', 'Noun'), ('조사', 'Noun'), ('(', 'Punctuation'), ('문헌', 'Noun'), (',', 'Punctuation'), ('설문', 'Noun'), ('등', 'Noun'), (')', 'Punctuation'), ('데이터', 'Noun'), ('분석', 'Noun'), ('(', 'Punctuation'), ('엑셀', 'Noun'), (',', 'Punctuation'), ('R', 'Alpha'), ('프로그램', 'Noun'), (',', 'Punctuation'), ('파이썬', 'Noun'), ('등', 'Noun'), (')', 'Punctuation'), ('보고서', 'Noun'), ('작성', 'Noun'), ('(', 'Punctuation'), ('아래한글', 'Noun'), (',', 'Punctuation'), ('PPT', 'Alpha'), ('등', 'Noun'), (')', 'Punctuation'), ('지원', 'Noun'), ('※', 'Foreign'), ('고용', 'Noun'), ('센터', 'Noun'), ('채용', 'Noun'), ('대행', 'Noun'), ('건', 'Noun'), ('으로', 'Josa'), ('구직', 'Noun'), ('신청', 'Noun'), ('후', 'Noun'), ('워크넷', 'Noun'), ('으로', 'Josa'), ('입사', 'Noun'), ('지원', 'Noun'), ('바랍니다', 'Verb'), ('.', 'Punctuation'), ('-', 'Punctuation'), ('실업', 'Noun'), ('급여', 'Noun'), ('구직', 'Noun'), ('활동', 'Noun'), ('을', 'Josa'), ('위', 'Noun'), ('한', 'Josa'), ('지원', 'Noun'), ('을', 'Josa'), ('자제', 'Noun'), ('부탁드리며', 'Adjective'), (',', 'Punctuation'), ('실제', 'Noun'), ('취업', 'Noun'), ('의사', 'Noun'), ('가', 'Josa'), ('있는', 'Adjective'), ('분만', 'Noun'), ('지원', 'Noun'), ('바랍니다', 'Verb'), ('.', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('브', 'Noun'), ('래', 'Josa'), ('키츠', 'Noun'), ('(', 'Punctuation'), ('주', 'Noun'), (')', 'Punctuation'), ('에서', 'Josa'), ('아래', 'Noun'), ('와', 'Josa'), ('같이', 'Adverb'), ('태블', 'Noun'), ('로', 'Josa'), ('(', 'Punctuation'), ('Tableau', 'Alpha'), (')', 'Punctuation'), ('경력', 'Noun'), ('자', 'Suffix'), ('를', 'Josa'), ('모집', 'Noun'), ('합니다', 'Verb'), ('.', 'Punctuation'), ('[', 'Punctuation'), ('회사', 'Noun'), ('소개', 'Noun'), (']', 'Punctuation'), ('‘', 'Foreign'), ('디지털', 'Noun'), ('해결', 'Noun'), ('소', 'Noun'), ('’', 'Punctuation'), ('를', 'Noun'), ('표방', 'Noun'), ('하는', 'Verb'), ('브', 'Noun'), ('래', 'Josa'), ('키츠', 'Noun'), ('(', 'Punctuation'), ('주', 'Noun'), (')', 'Punctuation'), ('는', 'Verb'), ('다양한', 'Adjective'), ('분야', 'Noun'), ('유수', 'Noun'), ('의', 'Josa'), ('고객', 'Noun'), ('사', 'Noun'), ('에', 'Josa'), ('DT', 'Alpha'), ('(', 'Punctuation'), ('Digital', 'Alpha'), ('Transformation', 'Alpha'), ('),', 'Punctuation'), ('Analytics', 'Alpha'), (',', 'Punctuation'), ('Cloud', 'Alpha'), ('등', 'Noun'), ('ERP', 'Alpha'), ('·', 'Punctuation'), ('BI', 'Alpha'), ('분야', 'Noun'), ('전반', 'Noun'), ('에', 'Josa'), ('걸쳐', 'Verb'), ('실용', 'Noun'), ('적', 'Suffix'), ('인', 'Josa'), ('솔루션', 'Noun'), ('을', 'Josa'), ('제공', 'Noun'), ('하는', 'Verb'), ('IT', 'Alpha'), ('컨설팅', 'Noun'), ('기업', 'Noun'), ('입니다', 'Adjective'), ('.', 'Punctuation'), ('2021년', 'Number'), ('창사', 'Noun'), ('이래', 'Adjective'), ('급속한', 'Adjective'), ('성장', 'Noun'), ('과', 'Josa'), ('함께', 'Adverb'), ('우리', 'Noun'), ('는', 'Josa'), ('열정', 'Noun'), ('있는', 'Adjective'), ('인재', 'Noun'), ('들', 'Suffix'), ('을', 'Josa'), ('찾아', 'Verb'), ('함께', 'Adverb'), ('성장하고자', 'Adjective'), ('합니다', 'Verb'), ('.', 'Punctuation'), ('[', 'Punctuation'), ('직무', 'Noun'), ('및', 'Noun'), ('업무', 'Noun'), ('내용', 'Noun'), (']', 'Punctuation'), ('▶', 'Foreign'), ('태블', 'Noun'), ('로', 'Josa'), ('(', 'Punctuation'), ('Tableau', 'Alpha'), (')', 'Punctuation'), ('를', 'Noun'), ('이용', 'Noun'), ('한', 'Josa'), ('데이터', 'Noun'), ('시각', 'Noun'), ('화', 'Suffix'), ('및', 'Noun'), ('분석', 'Noun'), ('작업', 'Noun'), ('수행', 'Noun'), ('▶', 'Foreign'), ('다양한', 'Adjective'), ('데이터', 'Noun'), ('소스', 'Noun'), ('로부터', 'Noun'), ('의', 'Josa'), ('데이터', 'Noun'), ('추출', 'Noun'), ('및', 'Noun'), ('가공', 'Noun'), ('▶', 'Foreign'), ('리포트', 'Noun'), ('및', 'Noun'), ('대시보드', 'Noun'), ('개발', 'Noun'), ('및', 'Noun'), ('유지', 'Noun'), ('보수', 'Noun'), ('▶', 'Foreign'), ('데이터', 'Noun'), ('분석', 'Noun'), ('결과', 'Noun'), ('에', 'Josa'), ('대한', 'Noun'), ('해석', 'Noun'), ('및', 'Noun'), ('비즈니스', 'Noun'), ('(', 'Punctuation'), ('고객', 'Noun'), ('사', 'Noun'), (')', 'Punctuation'), ('에', 'Josa'), ('제안', 'Noun'), ('[', 'Punctuation'), ('자격', 'Noun'), ('요건', 'Noun'), (']', 'Punctuation'), ('▶', 'Foreign'), ('태블', 'Noun'), ('로', 'Josa'), ('(', 'Punctuation'), ('Tableau', 'Alpha'), (')', 'Punctuation'), ('경력', 'Noun'), ('2년', 'Number'), ('이상', 'Noun'), ('✔', 'Foreign'), ('세', 'Modifier'), ('일', 'Modifier'), ('즈', 'Modifier'), ('포스', 'Noun'), ('태블', 'Noun'), ('로', 'Josa'), ('신병', 'Noun'), ('훈련소', 'Noun'), ('교육', 'Noun'), ('자료', 'Noun'), ('생', 'Noun'), ('성', 'Suffix'), ('/', 'Punctuation'), ('이해', 'Noun'), ('가능', 'Noun'), ('실력', 'Noun'), ('✔', 'Foreign'), ('태블', 'Noun'), ('로', 'Josa'), ('장표', 'Noun'), ('생', 'Noun'), ('성', 'Suffix'), ('에', 'Josa'), ('필요한', 'Adjective'), ('데이터', 'Noun'), ('셋', 'Noun'), ('(', 'Punctuation'), ('포맷', 'Noun'), (')', 'Punctuation'), ('구성', 'Noun'), ('능력', 'Noun'), ('필요', 'Noun'), ('▶', 'Foreign'), ('SQL', 'Alpha'), ('조', 'Modifier'), ('회문', 'Noun'), ('(', 'Punctuation'), ('select', 'Alpha'), (')', 'Punctuation'), ('작성', 'Noun'), ('실력', 'Noun'), ('✔', 'Foreign'), ('서브', 'Noun'), ('쿼리', 'Noun'), (',', 'Punctuation'), ('피벗', 'Noun'), ('사용', 'Noun'), ('가능', 'Noun'), ('자', 'Suffix'), ('[', 'Punctuation'), ('우대', 'Noun'), ('사항', 'Noun'), (']', 'Punctuation'), ('▶', 'Foreign'), ('태블', 'Noun'), ('로', 'Josa'), ('구축', 'Noun'), ('프로젝트', 'Noun'), ('진행', 'Noun'), ('경험', 'Noun'), ('3회', 'Number'), ('이상', 'Noun'), ('[', 'Punctuation'), ('지원', 'Noun'), ('방법', 'Noun'), ...
# --------------------------------------------------------------------------------
# [('[', 'Punctuation'), ('공통', 'Noun'), ('자격', 'Noun'), ('요건', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('학력', 'Noun'), ('/', 'Punctuation'), ('성별', 'Noun'), (':', 'Punctuation'), ('무관', 'Noun'), ('ㆍ', 'Foreign'), ('경력', 'Noun'), (':', 'Punctuation'), ('경력', 'Noun'), ('(', 'Punctuation'), ('1년', 'Number'), ('이상', 'Noun'), ('또는', 'Adverb'), ('동등', 'Noun'), ('이상', 'Noun'), ('개발', 'Noun'), ('이력', 'Noun'), (')', 'Punctuation'), ('ㆍ', 'Foreign'), ('수습', 'Noun'), (':', 'Punctuation'), ('3', 'Number'), ('개월', 'Noun'), ('[', 'Punctuation'), ('담당', 'Noun'), ('업무', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('인공', 'Noun'), ('지능', 'Noun'), ('알고리즘', 'Noun'), ('개발', 'Noun'), ('[', 'Punctuation'), ('자격', 'Noun'), ('요건', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('Linux', 'Alpha'), (',', 'Punctuation'), ('Windows', 'Alpha'), ('환경', 'Noun'), ('에서', 'Josa'), ('어플리케이션', 'Noun'), ('설계', 'Noun'), ('및', 'Noun'), ('개발', 'Noun'), ('ㆍ', 'Foreign'), ('Python', 'Alpha'), ('언어', 'Noun'), ('개발', 'Noun'), ('가능', 'Noun'), ('자', 'Suffix'), ('ㆍ', 'Foreign'), ('인공', 'Noun'), ('지능', 'Noun'), ('모델', 'Noun'), ('개발', 'Noun'), ('에', 'Josa'), ('필요한', 'Adjective'), ('기술', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('[', 'Punctuation'), ('우대', 'Noun'), ('사항', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('인공', 'Noun'), ('지능', 'Noun'), ('모델', 'Noun'), ('서비스', 'Noun'), ('화', 'Suffix'), ('경험', 'Noun'), ('이', 'Josa'), ('있으신', 'Adjective'), ('분', 'Noun'), ('ㆍ', 'Foreign'), ('인공', 'Noun'), ('지능', 'Noun'), ('관련', 'Noun'), ('학과', 'Noun'), ('석', 'Modifier'), ('박사', 'Noun'), ('우대', 'Noun'), ('ㆍ', 'Foreign'), ('열린', 'Verb'), ('마음', 'Noun'), ('으로', 'Josa'), ('목표', 'Noun'), ('를', 'Josa'), ('위', 'Noun'), ('한', 'Josa'), ('원활한', 'Adjective'), ('커뮤니케이션', 'Noun'), ('을', 'Josa'), ('즐기시는', 'Verb'), ('분', 'Noun'), ('ㆍ', 'Foreign'), ('Git', 'Alpha'), ('-', 'Punctuation'), ('hub', 'Alpha'), ('주소', 'Noun'), (',', 'Punctuation'), ('개발', 'Noun'), ('포트폴리오', 'Noun'), ('제출', 'Noun'), ('이', 'Josa'), ('가능하신', 'Adjective'), ('분', 'Noun'), ('[', 'Punctuation'), ('복리', 'Noun'), ('후생', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('모든', 'Noun'), ('임', 'Noun'), ('직원', 'Noun'), ('통신비', 'Noun'), ('제공', 'Noun'), ('ㆍ', 'Foreign'), ('모든', 'Noun'), ('임', 'Noun'), ('직원', 'Noun'), ('중식', 'Noun'), ('제공', 'Noun'), ('ㆍ', 'Foreign'), ('명절', 'Noun'), ('(', 'Punctuation'), ('설', 'Noun'), ('/', 'Punctuation'), ('추석', 'Noun'), (')', 'Punctuation'), ('선물', 'Noun'), ('지급', 'Noun'), ('ㆍ', 'Foreign'), ('경', 'Modifier'), ('조금', 'Noun'), ('지원', 'Noun'), ('ㆍ', 'Foreign'), ('야근', 'Noun'), ('시', 'Noun'), ('식대', 'Noun'), ('지원', 'Noun'), ('ㆍ', 'Foreign'), ('출퇴근시간', 'Noun'), ('유연근무제', 'Noun'), ('시행', 'Noun'), ('ㆍ', 'Foreign'), ('자율', 'Noun'), ('적', 'Suffix'), ('인', 'Josa'), ('휴가', 'Noun'), ('사용', 'Noun'), ('(', 'Punctuation'), ('연차', 'Noun'), (',', 'Punctuation'), ('반', 'Modifier'), ('차', 'Noun'), ('등', 'Noun'), (')', 'Punctuation'), ('*', 'Punctuation'), ('회사', 'Noun'), ('성장', 'Noun'), ('에', 'Josa'), ('따라', 'Verb'), ('복리', 'Noun'), ('후생', 'Noun'), ('추가', 'Noun'), ('예정', 'Noun')]
# --------------------------------------------------------------------------------
# [('○', 'Foreign'), ('데이터', 'Noun'), ('기반', 'Noun'), ('행정', 'Noun'), ('활성화', 'Noun'), ('(', 'Punctuation'), ('시행', 'Noun'), ('계획', 'Noun'), ('수립', 'Noun'), (',', 'Punctuation'), ('역량', 'Noun'), ('강화', 'Noun'), (',', 'Punctuation'), ('데이터', 'Noun'), ('공유', 'Noun'), ('등', 'Noun'), (')', 'Punctuation'), ('○', 'Foreign'), ('데이터', 'Noun'), ('기반', 'Noun'), ('행정', 'Noun'), ('실태', 'Noun'), ('점검', 'Noun'), ('대응', 'Noun'), ('○', 'Foreign'), ('공공', 'Modifier'), ('데이터', 'Noun'), ('품질', 'Noun'), ('관리', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('드라마', 'Noun'), ('제작', 'Noun'), ('현장', 'Noun'), ('에서', 'Josa'), ('함께', 'Adverb'), ('일', 'Noun'), ('할', 'Verb'), ('스텝', 'Noun'), ('모집', 'Noun'), ('합니다', 'Verb'), ('.', 'Punctuation'), ('안녕하세요', 'Adjective'), ('저희', 'Noun'), ('회사', 'Noun'), ('는', 'Josa'), ('마포구', 'Noun'), ('상암동', 'Noun'), ('에', 'Josa'), ('소재', 'Noun'), ('하고', 'Josa'), ('있으며', 'Adjective'), ('스텝', 'Noun'), ('분', 'Noun'), ('들', 'Suffix'), ('은', 'Josa'), ('촬영', 'Noun'), ('현장', 'Noun'), ('에', 'Josa'), ('따라', 'Verb'), ('상암동', 'Noun'), ('또는', 'Adverb'), ('여의도', 'Noun'), (',', 'Punctuation'), ('일산', 'Noun'), ('에서', 'Josa'), ('스텝', 'Noun'), ('버스', 'Noun'), ('를', 'Josa'), ('타고', 'Noun'), ('현장', 'Noun'), ('근무', 'Noun'), ('합니다', 'Verb'), ('.', 'Punctuation'), ('주요', 'Noun'), ('업무', 'Noun'), ('는', 'Josa'), ('현장', 'Noun'), ('데이터', 'Noun'), ('매니저', 'Noun'), ('이며', 'Josa'), ('촬영', 'Noun'), ('된', 'Verb'), ('데이터', 'Noun'), ('를', 'Josa'), ('복제', 'Noun'), ('및', 'Noun'), ('변환', 'Noun'), ('/', 'Punctuation'), ('가공', 'Noun'), ('하는', 'Verb'), ('업무', 'Noun'), ('입니다', 'Adjective'), ('.', 'Punctuation'), ('처음', 'Noun'), ('접', 'Noun'), ('하시는', 'Verb'), ('분', 'Noun'), ('들', 'Suffix'), ('을', 'Josa'), ('위해', 'Noun'), ('사내', 'Noun'), ('에서', 'Josa'), ('사전', 'Noun'), ('교육', 'Noun'), ('과', 'Josa'), ('현장', 'Noun'), ('에서', 'Josa'), ('서포터', 'Noun'), ('분', 'Suffix'), ('이', 'Josa'), ('함께', 'Adverb'), ('참가', 'Noun'), ('해', 'Verb'), ('교육', 'Noun'), ('을', 'Josa'), ('시켜', 'Verb'), ('드리기에', 'Verb'), ('기존', 'Noun'), ('의', 'Josa'), ('경험', 'Noun'), ('및', 'Noun'), ('기초', 'Noun'), ('지식', 'Noun'), ('은', 'Josa'), ('필요', 'Noun'), ('치', 'Noun'), ('않습니다', 'Verb'), ('.', 'Punctuation'), ('데이터', 'Noun'), ('매니저', 'Noun'), ('의', 'Josa'), ('역할', 'Noun'), ('을', 'Josa'), ('하다가', 'Verb'), ('촬영', 'Noun'), ('현장', 'Noun'), ('에', 'Josa'), ('익숙해', 'Adjective'), ('지시', 'Noun'), ('면', 'Josa'), ('촬영', 'Noun'), ('/', 'Punctuation'), ('편집', 'Noun'), ('/', 'Punctuation'), ('제작', 'Noun'), ('/', 'Punctuation'), ('연출', 'Noun'), ('등', 'Noun'), ('의', 'Josa'), ('타', 'Noun'), ('업무', 'Noun'), ('로', 'Josa'), ('의', 'Noun'), ('전환', 'Noun'), ('도', 'Josa'), ('가능합니다', 'Adjective'), ('.', 'Punctuation'), ('드라마', 'Noun'), ('촬영', 'Noun'), ('스텝', 'Noun'), ('분야', 'Noun'), ('의', 'Josa'), ('관심', 'Noun'), ('있는', 'Adjective'), ('분', 'Noun'), ('들', 'Suffix'), ('의', 'Josa'), ('많은', 'Adjective'), ('지원', 'Noun'), ('바랍니다', 'Verb')]
# --------------------------------------------------------------------------------
# [('국립', 'Noun'), ('금오공과대', 'Noun'), ('학교', 'Noun'), ('에서는', 'Josa'), ('2024년', 'Number'), ('국립', 'Noun'), ('대학', 'Noun'), ('육성', 'Noun'), ('사업', 'Noun'), ('업무', 'Noun'), ('추진', 'Noun'), ('을', 'Josa'), ('위해', 'Noun'), ('참신하고', 'Adjective'), ('유능한', 'Adjective'), ('인재', 'Noun'), ('를', 'Josa'), ('다음', 'Noun'), ('과', 'Josa'), ('같이', 'Adverb'), ('모집', 'Noun'), ('합니다', 'Verb'), ('.', 'Punctuation'), ('1', 'Number'), ('.', 'Punctuation'), ('채용', 'Noun'), ('분야', 'Noun'), ('및', 'Noun'), ('인원', 'Noun'), ('◎', 'Foreign'), ('전문', 'Noun'), ('계약', 'Noun'), ('직', 'Noun'), ('(', 'Punctuation'), ('데이터', 'Noun'), ('관리', 'Noun'), ('및', 'Noun'), ('분석', 'Noun'), (')', 'Punctuation'), ('1', 'Number'), ('명', 'Noun'), ('-', 'Punctuation'), ('학생', 'Noun'), ('역량', 'Noun'), ('관리', 'Noun'), ('시스템', 'Noun'), ('고도화', 'Noun'), ('2', 'Number'), ('.', 'Punctuation'), ('접수', 'Noun'), ('기간', 'Noun'), (':', 'Punctuation'), ('2024.2', 'Number'), ('.', 'Punctuation'), ('9', 'Number'), ('.(', 'Punctuation'), ('금', 'Noun'), (')', 'Punctuation'), ('~', 'Punctuation'), ('2.16', 'Number'), ('.(', 'Punctuation'), ('금', 'Noun'), (')', 'Punctuation'), ('18:00', 'Number'), ('3', 'Number'), ('.', 'Punctuation'), ('접수', 'Noun'), ('방법', 'Noun'), (':', 'Punctuation'), ('이메일', 'Noun'), ('접수', 'Noun'), ('*', 'Punctuation'), ('기타', 'Noun'), ('자세한', 'Adjective'), ('사항', 'Noun'), ('은', 'Josa'), ('붙임', 'Verb'), ('파일', 'Noun'), ('참조', 'Noun'), ('바랍니다', 'Verb'), ('.', 'Punctuation'), ('2024년', 'Number'), ('2월', 'Number'), ('8일', 'Number'), ('국립', 'Noun'), ('금오공과대', 'Noun'), ('학교', 'Noun'), ('총장', 'Noun')]
# --------------------------------------------------------------------------------
# [('공공기관', 'Noun'), ('데이터', 'Noun'), ('표준', 'Noun'), ('품질', 'Noun'), ('업무', 'Noun'), ('(', 'Punctuation'), ('가', 'Verb'), (')', 'Punctuation'), ('데이터', 'Noun'), ('사업', 'Noun'), ('수행', 'Noun'), ('경력', 'Noun'), ('최소', 'Noun'), ('3년', 'Number'), ('이상', 'Noun'), ('+', 'Punctuation'), ('PM', 'Alpha'), ('수행', 'Noun'), ('경험', 'Noun'), ('보유', 'Noun'), ('(', 'Punctuation'), ('나', 'Noun'), (')', 'Punctuation'), ('데이터', 'Noun'), ('관리', 'Noun'), ('체계', 'Noun'), ('구축', 'Noun'), ('컨설팅', 'Noun'), (',', 'Punctuation'), ('데이터', 'Noun'), ('표준', 'Noun'), ('수립', 'Noun'), (',', 'Punctuation'), ('데이터', 'Noun'), ('품질', 'Noun'), ('진단', 'Noun'), (',', 'Punctuation'), ('데이터', 'Noun'), ('개발', 'Noun'), ('등', 'Noun'), ('데이터', 'Noun'), ('관련', 'Noun'), ('사업', 'Noun'), ('유', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), ('(', 'Punctuation'), ('다', 'Adverb'), (')', 'Punctuation'), ('빅데이터', 'Noun'), ('분석', 'Noun'), ('및', 'Noun'), ('플랫폼', 'Noun'), ('구축', 'Noun'), ('사업', 'Noun'), ('유', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('분석', 'Noun'), ('기술', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('(', 'Punctuation'), ('R', 'Alpha'), (',', 'Punctuation'), ('파이썬', 'Noun'), ('등', 'Noun'), (')', 'Punctuation'), ('(', 'Punctuation'), ('라', 'Josa'), (')', 'Punctuation'), ('KS', 'Alpha'), ('_', 'Punctuation'), ('META', 'Alpha'), ('_', 'Punctuation'), ('DQ', 'Alpha'), ('솔루션', 'Noun'), ('의', 'Josa'), ('고도화', 'Noun'), ('및', 'Noun'), ('유지관리', 'Noun'), ('를', 'Josa'), ('위', 'Noun'), ('한', 'Josa'), ('개발', 'Noun'), ('인력', 'Noun'), ('(', 'Punctuation'), ('마', 'Noun'), (')', 'Punctuation'), ('데이터', 'Noun'), ('관련', 'Noun'), ('자격증', 'Noun'), ('소지', 'Noun'), ('자', 'Suffix'), ('우대', 'Noun'), ('(', 'Punctuation'), ('DAP', 'Alpha'), (',', 'Punctuation'), ('ADP', 'Alpha'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('분석', 'Noun'), ('기사', 'Noun'), (',', 'Punctuation'), ('DQC', 'Alpha'), ('-', 'Punctuation'), ('V', 'Alpha'), ('등', 'Noun'), (')', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('ㆍ', 'Foreign'), ('자동차', 'Noun'), ('데이터', 'Noun'), ('비교', 'Noun'), ('업무', 'Noun'), ('로', 'Josa'), (',', 'Punctuation'), ('자동차', 'Noun'), ('전장', 'Noun'), ('에', 'Josa'), ('대한', 'Noun'), ('이해도', 'Noun'), ('가', 'Josa'), ('있는', 'Adjective'), ('분과', 'Noun'), ('엑셀', 'Noun'), ('등', 'Noun'), ('기본', 'Noun'), ('적', 'Suffix'), ('인', 'Josa'), ('문서', 'Noun'), ('작성', 'Noun'), ('을', 'Josa'), ('할', 'Verb'), ('수', 'Noun'), ('있는', 'Adjective'), ('분', 'Noun'), ('을', 'Josa'), ('모집', 'Noun'), ('하고', 'Josa'), ('있습니다', 'Adjective'), ('.', 'Punctuation'), ('ㆍ', 'Foreign'), ('새로운', 'Adjective'), ('프로젝트', 'Noun'), ('인', 'Josa'), ('만큼', 'Noun'), ('데이터', 'Noun'), ('분석', 'Noun'), ('에', 'Josa'), ('대해', 'Noun'), ('같이', 'Adverb'), ('배우고', 'Verb'), ('업무', 'Noun'), ('에', 'Josa'), ('실행', 'Noun'), ('할', 'Verb'), ('예정', 'Noun'), ('입니다', 'Adjective'), ('.', 'Punctuation'), ('부담', 'Noun'), ('없이', 'Adverb'), ('지원', 'Noun'), ('해', 'Verb'), ('주세요', 'Verb'), ('.', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation'), ('신입', 'Noun'), (':', 'Punctuation'), ('연봉', 'Noun'), ('2,500', 'Number'), ('만원', 'Noun'), ('은', 'Josa'), ('기본', 'Noun'), ('급', 'Suffix'), ('2,280', 'Number'), ('만원', 'Noun'), ('+', 'Punctuation'), ('상여금', 'Noun'), ('과', 'Josa'), ('식대', 'Noun'), ('가', 'Josa'), ('포함', 'Noun'), ('된', 'Verb'), ('금액', 'Noun'), ('입니다', 'Adjective'), ('.', 'Punctuation'), (':', 'Punctuation'), ('인', 'Noun'), ('센티', 'Noun'), ('브', 'Noun'), ('별도', 'Noun'), ('.', 'Punctuation'), ('[', 'Punctuation'), ('인턴', 'Noun'), ('기간', 'Noun'), (':', 'Punctuation'), ('2', 'Number'), ('개월', 'Noun'), ('이내', 'Noun'), ('기본', 'Noun'), ('급', 'Suffix'), ('월', 'Noun'), ('174', 'Number'), ('만원', 'Noun'), (']', 'Punctuation'), ('-', 'Punctuation'), ('경력', 'Noun'), ('직', 'Noun'), (':', 'Punctuation'), ('입찰', 'Noun'), ('경력', 'Noun'), ('있으신', 'Adjective'), ('분', 'Noun'), ('은', 'Josa'), ('상호', 'Noun'), ('협의', 'Noun'), ('가능', 'Noun'), ('ㆍ', 'Foreign'), ('공공기관', 'Noun'), ('전자', 'Noun'), ('입찰', 'Noun'), ('금액', 'Noun'), ('분석', 'Noun'), ('및', 'Noun'), ('원', 'Modifier'), ('격투', 'Noun'), ('찰', 'Noun'), ('.', 'Punctuation'), ('-', 'Punctuation'), ('나라장터', 'Noun'), (',', 'Punctuation'), ('국방부', 'Noun'), (',', 'Punctuation'), ('한전', 'Noun'), ('등', 'Noun'), ('관공서', 'Noun'), ('전자', 'Noun'), ('입찰', 'Noun'), ('발주', 'Noun'), ('공고', 'Noun'), ('분석', 'Noun'), ('업무', 'Noun'), ('및', 'Noun'), ('업체', 'Noun'), ('관리', 'Noun'), ('입니다', 'Adjective'), ('.', 'Punctuation'), ('ㆍ', 'Foreign'), ('전자', 'Noun'), ('입찰', 'Noun'), ('분석', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), ('우대', 'Noun'), ('.', 'Punctuation'), ('-', 'Punctuation'), ('신입', 'Noun'), ('도', 'Josa'), ('충분히', 'Adjective'), ('가능합니다', 'Adjective'), ('.', 'Punctuation'), ('하지만', 'Conjunction'), ('이', 'Determiner'), ('쪽', 'Noun'), ('계통', 'Noun'), ('에서는', 'Josa'), ('영업', 'Noun'), ('직원', 'Noun'), ('들', 'Suffix'), ('은', 'Josa'), ('구인', 'Noun'), ('하', 'Suffix'), ('지만', 'Josa'), ('분석', 'Noun'), ('업무', 'Noun'), ('는', 'Josa'), ('배울', 'Verb'), ('기회', 'Noun'), ('가', 'Josa'), ('없습니다', 'Adjective'), ('.', 'Punctuation'), ('저희', 'Noun'), ('도', 'Josa'), ('경력', 'Noun'), ('직', 'Noun'), ('만', 'Josa'), ('채용', 'Noun'), ('하다가', 'Verb'), ('신입', 'Noun'), ('도', 'Josa'), ('채용', 'Noun'), ('할려고', 'Verb'), ('하는', 'Verb'), ('거니', 'Eomi'), ('많은', 'Adjective'), ('지원', 'Noun'), ('바랍니다', 'Verb'), ('~', 'Punctuation'), ('ㆍ', 'Foreign'), ('인근', 'Noun'), ('거주', 'Noun'), ('자', 'Suffix'), ('ㆍ', 'Foreign'), ('착실하고', 'Adjective'), ('책임감', 'Noun'), ('있는', 'Adjective'), ('분', 'Noun'), ('.', 'Punctuation'), ('ㆍ', 'Foreign'), ('다른', 'Modifier'), ('뭔가', 'Noun'), ('를', 'Josa'), ('찾고', 'Verb'), ('계시는', 'Adjective'), ('분', 'Noun'), ('.', 'Punctuation'), ('ㆍ', 'Foreign'), ('점심', 'Noun'), ('시간', 'Noun'), ('11시', 'Number'), ('45분', 'Number'), ('~', 'Punctuation'), ('13시', 'Number'), ('15분', 'Number'), ('1시간', 'Number'), ('30분', 'Number'), ('으로', 'Foreign'), ('충분한', 'Adjective'), ('휴식', 'Noun'), ('.', 'Punctuation'), ('ㆍ', 'Foreign'), ('월', 'Noun'), ('~', 'Punctuation'), ('금', 'Noun'), ('(', 'Punctuation'), ('주', 'Noun'), ('5일', 'Number'), ('근무', 'Noun'), (')', 'Punctuation'), ('ㆍ', 'Foreign'), ('9시', 'Number'), ('출근', 'Noun'), ('~', 'Punctuation'), ('오후', 'Noun'), ('6시', 'Number'), ('퇴근', 'Noun'), ('(', 'Punctuation'), ('점심시간', 'Noun'), ('1시간', 'Number'), ('30분', 'Number'), ('포함', 'Foreign'), (')', 'Punctuation'), ('ㆍ', 'Foreign'), ('주', 'Noun'), ('5일', 'Number'), ('만', 'Foreign'), ('근무', 'Noun'), ('합니다', 'Verb'), ('.', 'Punctuation'), ('ㆍ', 'Foreign'), ('야근', 'Noun'), ('없고', 'Adjective'), (',', 'Punctuation'), ('주말', 'Noun'), ('근무', 'Noun'), ('없습니다', 'Adjective'), ('.', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('[', 'Punctuation'), ('모집', 'Noun'), ('부문', 'Noun'), ('및', 'Noun'), ('상세', 'Noun'), ('내용', 'Noun'), (']', 'Punctuation'), ('-', 'Punctuation'), ('공통', 'Noun'), ('자격', 'Noun'), ('요건', 'Noun'), ('ㆍ', 'Foreign'), ('학력', 'Noun'), (':', 'Punctuation'), ('대졸', 'Noun'), ('이상', 'Noun'), ('(', 'Punctuation'), ('2', 'Number'), (',', 'Punctuation'), ('3년', 'Number'), (')', 'Punctuation'), ('[', 'Punctuation'), ('Database', 'Alpha'), ('기술', 'Noun'), ('엔지니어', 'Noun'), ('신입', 'Noun'), ('및', 'Noun'), ('경력', 'Noun'), ('직', 'Noun'), ('채용', 'Noun'), ('\t ', 'Foreign'), ('2', 'Number'), ('명', 'Noun'), (']', 'Punctuation'), ('-', 'Punctuation'), ('지원', 'Noun'), ('자격', 'Noun'), ('ㆍ', 'Foreign'), ('경력', 'Noun'), (':', 'Punctuation'), ('신입', 'Noun'), ('/', 'Punctuation'), ('경력', 'Noun'), ('2년', 'Number'), ('~', 'Punctuation'), ('5년', 'Number'), ('(', 'Punctuation'), ('면접', 'Noun'), ('후', 'Noun'), ('결정', 'Noun'), (')', 'Punctuation'), ('ㆍ', 'Foreign'), ('관계', 'Noun'), ('형', 'Suffix'), ('데이터베이스', 'Noun'), ('구축', 'Noun'), ('경험', 'Noun'), ('ㆍ', 'Foreign'), ('DBMS', 'Alpha'), ('운영', 'Noun'), ('및', 'Noun'), ('장애', 'Noun'), ('대응', 'Noun'), ('ㆍ', 'Foreign'), ('운영체제', 'Noun'), ('및', 'Noun'), ('네트워크', 'Noun'), ('에', 'Josa'), ('대한', 'Noun'), ('이해도', 'Noun'), ('-', 'Punctuation'), ('우대', 'Noun'), ('사항', 'Noun'), ('ㆍ', 'Foreign'), ('공학', 'Noun'), ('계열', 'Noun'), (',', 'Punctuation'), ('관련', 'Noun'), ('학과', 'Noun'), ('(', 'Punctuation'), ('전산학', 'Noun'), ('과', 'Josa'), (')', 'Punctuation'), ('졸업', 'Noun'), ('자', 'Suffix'), ('ㆍ', 'Foreign'), ('SQL', 'Alpha'), ('숙련', 'Noun'), ('자', 'Suffix'), ('ㆍ', 'Foreign'), ('관련', 'Noun'), ('인증', 'Noun'), ('자격', 'Noun'), ('소지', 'Noun'), ('자', 'Suffix'), ('ㆍ', 'Foreign'), ('해당', 'Noun'), ('직무', 'Noun'), ('근무', 'Noun'), ('경험', 'Noun'), ('-', 'Punctuation'), ('복리', 'Noun'), ('후생', 'Noun'), ('ㆍ', 'Foreign'), ('건강', 'Noun'), ('보험', 'Noun'), (',', 'Punctuation'), ('국민연금', 'Noun'), (',', 'Punctuation'), ('산재', 'Noun'), ('보험', 'Noun'), (',', 'Punctuation'), ('고용보', 'Noun'), ('혐', 'Noun'), ('등', 'Noun'), ('ㆍ', 'Foreign'), ('정기', 'Noun'), ('휴가', 'Noun'), ('및', 'Noun'), ('연차', 'Noun'), ('사용', 'Noun'), ('관리', 'Noun'), ('ㆍ', 'Foreign'), ('경', 'Modifier'), ('조', 'Modifier'), ('사비', 'Noun'), ('지원', 'Noun'), ('ㆍ', 'Foreign'), ('근무시간', 'Noun'), ('및', 'Noun'), ('장소', 'Noun'), ('유연성', 'Noun'), ('제공', 'Noun'), ('ㆍ', 'Foreign'), ('업무', 'Noun'), ('관련', 'Noun'), ('교육', 'Noun'), ('및', 'Noun'), ('세미나', 'Noun'), ('참석', 'Noun'), ('기회', 'Noun'), ('제공', 'Noun'), ('ㆍ', 'Foreign'), ('사내', 'Noun'), ('우수', 'Noun'), ('인원', 'Noun'), ('에', 'Josa'), ('대한', 'Noun'), ('승진', 'Noun'), ('및', 'Noun'), ('연봉', 'Noun'), ('인상', 'Noun'), ('기회', 'Noun'), ('-', 'Punctuation'), ('근', 'Modifier'), ('무조건', 'Noun'), ('ㆍ', 'Foreign'), ('\t', 'Foreign'), ('근무', 'Noun'), ('형태', 'Noun'), ('\t', 'Foreign'), (':', 'Punctuation'), ('\t', 'Foreign'), ('정규직', 'Noun'), ('(', 'Punctuation'), ('수습', 'Noun'), ('기간', 'Noun'), (')-', 'Punctuation'), ('3', 'Number'), ('개월', 'Noun'), ('ㆍ', 'Foreign'), ('\t', 'Foreign'), ('근무', 'Noun'), ('지역', 'Noun'), ('\t', 'Foreign'), (':', 'Punctuation'), ('\t', 'Foreign'), ('(', 'Punctuation'), ('06083', 'Number'), (')', 'Punctuation'), ('서울', 'Noun'), ('강남구', 'Noun'), ('영동대로', 'Noun'), ('602', 'Number'), (',', 'Punctuation'), ('E', 'Alpha'), ('동', 'Modifier'), ('6', 'Number'), ('층', 'Noun'), ('205', 'Number'), ('호', 'Noun'), ('-', 'Punctuation'), ('서울', 'Noun'), ('9', 'Number'), ('호선', 'Noun'), ('봉은사', 'Noun'), ('에서', 'Josa'), ('100', 'Number'), ('m', 'Alpha'), ('이내', 'Noun'), ('[', 'Punctuation'), ('전형', 'Noun'), ('절차', 'Noun'), (']', 'Punctuation'), ('-', 'Punctuation'), ('서류', 'Noun'), ('전형', 'Noun'), ('1', 'Number'), ('차', 'Noun'), ('면접', 'Noun'), ('-', 'Punctuation'), ('최종', 'Noun'), ('합격', 'Noun'), ('유의사항', 'Noun'), ('ㆍ', 'Foreign'), ('입사', 'Noun'), ('지원', 'Noun'), ('서류', 'Noun'), ('에', 'Josa'), ('허위', 'Noun'), ('사실', 'Noun'), ('이', 'Josa'), ('발견', 'Noun'), ('될', 'Verb'), ('경우', 'Noun'), (',', 'Punctuation'), ('채용', 'Noun'), ('확정', 'Noun'), ('이후', 'Nou ...
# --------------------------------------------------------------------------------
# [('-', 'Punctuation'), ('데이터', 'Noun'), ('모델링', 'Noun'), ('표준', 'Noun'), ('정의', 'Noun'), ('및', 'Noun'), ('인', 'Noun'), ('스펙', 'Noun'), ('션', 'Noun'), ('수행', 'Noun'), ('-', 'Punctuation'), ('데이터', 'Noun'), ('관리', 'Noun'), ('체계', 'Noun'), ('수립', 'Noun'), ('및', 'Noun'), ('검토', 'Noun'), ('수행', 'Noun'), ('-', 'Punctuation'), ('데이터베이스', 'Noun'), ('아키텍처', 'Noun'), ('설계', 'Noun'), ('및', 'Noun'), ('검토', 'Noun'), ('수행', 'Noun'), ('-', 'Punctuation'), ('데이터베이스', 'Noun'), ('아', 'Exclamation'), ('카이', 'Noun'), ('빙', 'Noun'), ('정책', 'Noun'), ('수립', 'Noun'), ('및', 'Noun'), ('검토', 'Noun'), ('-', 'Punctuation'), ('메타데이터', 'Noun'), ('표준화', 'Noun'), ('수행', 'Noun'), ('-', 'Punctuation'), ('성능', 'Noun'), ('개선', 'Noun'), ('및', 'Noun'), ('튜닝', 'Noun'), ('정책', 'Noun'), ('/', 'Punctuation'), ('가이드', 'Noun'), ('관리', 'Noun'), ('-', 'Punctuation'), ('프로젝트', 'Noun'), ('기획', 'Noun'), ('및', 'Noun'), ('구축', 'Noun'), ('수행', 'Noun')]
# --------------------------------------------------------------------------------
# [('※', 'Foreign'), ('YOLO', 'Alpha'), ('기반', 'Noun'), ('이미지', 'Noun'), ('/', 'Punctuation'), ('영상', 'Noun'), ('실시간', 'Noun'), ('분석', 'Noun'), (',', 'Punctuation'), ('AIoT', 'Alpha'), ('융합', 'Noun'), ('기술', 'Noun'), ('개발', 'Noun'), ('[', 'Punctuation'), ('빅데이터', 'Noun'), ('플랫폼', 'Noun'), ('구축', 'Noun'), ('>', 'Punctuation'), ('빅데이터', 'Noun'), ('플랫폼', 'Noun'), ('아키텍처', 'Noun'), ('설계', 'Noun'), (']', 'Punctuation'), ('빅데이터', 'Noun'), ('플랫폼', 'Noun'), ('인프라', 'Noun'), ('구조', 'Noun'), ('설계', 'Noun'), ('하기', 'Verb'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('입출력', 'Noun'), ('구조', 'Noun'), ('설계', 'Noun'), ('하기', 'Verb'), ('[', 'Punctuation'), ('빅데이터', 'Noun'), ('플랫폼', 'Noun'), ('구축', 'Noun'), ('>', 'Punctuation'), ('빅데이터', 'Noun'), ('수집', 'Noun'), ('시스템', 'Noun'), ('개발', 'Noun'), (']', 'Punctuation'), ('빅데이터', 'Noun'), ('수집', 'Noun'), ('시스템', 'Noun'), ('설계', 'Noun'), ('하기', 'Verb'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('수집', 'Noun'), ('시스템', 'Noun'), ('구성', 'Noun'), ('하기', 'Verb'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('수집', 'Noun'), ('·', 'Punctuation'), ('변환', 'Noun'), ('모듈', 'Noun'), ('개발', 'Noun'), ('하기', 'Verb'), (',', 'Punctuation'), ('수집', 'Noun'), ('데이터', 'Noun'), ('검증', 'Noun'), ('모듈', 'Noun'), ('개발', 'Noun'), ('하기', 'Verb'), ('[', 'Punctuation'), ('빅데이터', 'Noun'), ('플랫폼', 'Noun'), ('구축', 'Noun'), ('>', 'Punctuation'), ('빅데이터', 'Noun'), ('분석', 'Noun'), ('시스템', 'Noun'), ('개발', 'Noun'), (']', 'Punctuation'), ('빅데이터', 'Noun'), ('분석', 'Noun'), ('시스템', 'Noun'), ('설계', 'Noun'), ('하기', 'Verb'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('분석', 'Noun'), ('시스템', 'Noun'), ('구성', 'Noun'), ('하기', 'Verb'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('분석', 'Noun'), ('모듈', 'Noun'), ('개발', 'Noun'), ('하기', 'Verb'), ('[', 'Punctuation'), ('빅데이터', 'Noun'), ('플랫폼', 'Noun'), ('구축', 'Noun'), ('>', 'Punctuation'), ('빅데이터', 'Noun'), ('플랫폼', 'Noun'), ('테스트', 'Noun'), (']', 'Punctuation'), ('빅데이터', 'Noun'), ('플랫폼', 'Noun'), ('테스트', 'Noun'), ('설계', 'Noun'), ('하기', 'Verb'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('플랫폼', 'Noun'), ('기능', 'Noun'), ('테스트', 'Noun'), ('하기', 'Verb'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('플랫폼', 'Noun'), ('비', 'Noun'), ('기능', 'Noun'), ('테스트', 'Noun'), ('하기', 'Verb')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation'), ('SQL', 'Alpha'), ('을', 'Josa'), ('사용', 'Noun'), ('한', 'Josa'), ('데이터', 'Noun'), ('추출', 'Noun'), ('및', 'Noun'), ('전', 'Modifier'), ('처리', 'Noun'), ('를', 'Josa'), ('통한', 'Noun'), ('지표', 'Noun'), ('관리', 'Noun'), ('-', 'Punctuation'), ('데이터', 'Noun'), ('시각', 'Noun'), ('화', 'Suffix'), ('및', 'Noun'), ('대시보드', 'Noun'), ('(', 'Punctuation'), ('Tableau', 'Alpha'), ('등', 'Noun'), (')', 'Punctuation'), ('제작', 'Noun'), ('및', 'Noun'), ('운영', 'Noun'), ('-', 'Punctuation'), ('분석', 'Noun'), ('요건', 'Noun'), ('기획', 'Noun'), ('및', 'Noun'), ('데이터', 'Noun'), ('수집', 'Noun'), ('관리', 'Noun'), ('-', 'Punctuation'), ('데이터', 'Noun'), ('에', 'Josa'), ('기반', 'Noun'), ('한', 'Josa'), ('가설', 'Noun'), ('수립', 'Noun'), ('및', 'Noun'), ('검증', 'Noun'), ('-', 'Punctuation'), ('각종', 'Noun'), ('지표', 'Noun'), ('정의', 'Noun'), ('및', 'Noun'), ('트래킹', 'Noun'), ('자동화', 'Noun')]
# --------------------------------------------------------------------------------
# [('<', 'Punctuation'), ('모집', 'Noun'), ('분야', 'Noun'), ('>', 'Punctuation'), ('Bioinformatics', 'Alpha'), ('(', 'Punctuation'), ('생물정보학', 'Noun'), (')', 'Punctuation'), ('데이터', 'Noun'), ('처리', 'Noun'), ('및', 'Noun'), ('분석', 'Noun'), ('<', 'Punctuation'), ('담당', 'Noun'), ('업무', 'Noun'), ('>', 'Punctuation'), ('암', 'Noun'), ('유전체', 'Noun'), (',', 'Punctuation'), ('전사체', 'Noun'), (',', 'Punctuation'), ('단백체', 'Noun'), (',', 'Punctuation'), ('대사체', 'Noun'), ('등', 'Noun'), ('공공', 'Noun'), ('팬', 'Noun'), ('오믹스', 'Noun'), ('데이터', 'Noun'), ('확보', 'Noun'), ('암', 'Noun'), ('팬', 'Noun'), ('오믹스', 'Noun'), ('데이터', 'Noun'), ('처리', 'Noun'), ('파이프라인', 'Noun'), ('구축', 'Noun'), ('및', 'Noun'), ('최적화', 'Noun'), ('암', 'Noun'), ('팬', 'Noun'), ('오믹스', 'Noun'), ('데이터', 'Noun'), ('모델링', 'Noun'), ('을', 'Josa'), ('통한', 'Noun'), ('신규', 'Noun'), ('바이오', 'Noun'), ('마커', 'Adverb'), ('발굴', 'Noun'), ('및', 'Noun'), ('치료', 'Noun'), ('내', 'Determiner'), ('성', 'Noun'), ('기전', 'Noun'), ('규명', 'Noun'), ('<', 'Punctuation'), ('공통', 'Noun'), ('자격', 'Noun'), ('요건', 'Noun'), ('>', 'Punctuation'), ('생물정보학', 'Noun'), (',', 'Punctuation'), ('유전학', 'Noun'), (',', 'Punctuation'), ('컴퓨터공학', 'Noun'), ('및', 'Noun'), ('유사', 'Noun'), ('학문', 'Noun'), ('전공자', 'Noun'), ('Python', 'Alpha'), (',', 'Punctuation'), ('R', 'Alpha'), (',', 'Punctuation'), ('MATLAB', 'Alpha'), ('및', 'Noun'), ('기타', 'Noun'), ('프로그래밍', 'Noun'), ('언어', 'Noun'), ('를', 'Josa'), ('활용', 'Noun'), ('한', 'Josa'), ('유전체', 'Noun'), ('분석', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), ('<', 'Punctuation'), ('개별', 'Noun'), ('자격', 'Noun'), ('요건', 'Noun'), ('>', 'Punctuation'), ('책임', 'Noun'), ('급', 'Suffix'), ('–', 'Foreign'), ('연봉', 'Noun'), ('6,000', 'Number'), ('~', 'Punctuation'), ('8,000만원', 'Number'), ('박사', 'Noun'), ('이상', 'Noun'), ('및', 'Noun'), ('동', 'Modifier'), ('종업', 'Noun'), ('계', 'Suffix'), ('경력', 'Noun'), ('6년', 'Number'), ('이상', 'Noun'), ('선임', 'Noun'), ('급', 'Suffix'), ('–', 'Foreign'), ('연봉', 'Noun'), ('4,000', 'Number'), ('~', 'Punctuation'), ('6,000만원', 'Number'), ('석사', 'Noun'), ('이상', 'Noun'), ('및', 'Noun'), ('동', 'Modifier'), ('종업', 'Noun'), ('계', 'Suffix'), ('경력', 'Noun'), ('2년', 'Number'), ('이상', 'Noun'), ('<', 'Punctuation'), ('우대', 'Noun'), ('사항', 'Noun'), ('>', 'Punctuation'), ('NGS', 'Alpha'), ('(', 'Punctuation'), ('Next', 'Alpha'), ('-', 'Punctuation'), ('Generation', 'Alpha'), ('Sequencing', 'Alpha'), (')', 'Punctuation'), ('데이터', 'Noun'), ('처리', 'Noun'), ('및', 'Noun'), ('분석', 'Noun'), ('유', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), ('Mass', 'Alpha'), ('spectrometry', 'Alpha'), ('데이터', 'Noun'), ('처리', 'Noun'), ('및', 'Noun'), ('분석', 'Noun'), ('유', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), ('암', 'Modifier'), ('유전체', 'Noun'), ('포함', 'Noun'), ('한', 'Josa'), ('관련', 'Noun'), ('연구', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), ('<', 'Punctuation'), ('근무', 'Noun'), ('환경', 'Noun'), ('>', 'Punctuation'), ('근무', 'Noun'), ('지역', 'Noun'), (':', 'Punctuation'), ('서울시', 'Noun'), ('서초구', 'Noun'), ('태봉로', 'Noun'), ('114', 'Number'), (',', 'Punctuation'), ('AI', 'Alpha'), ('양재', 'Noun'), ('허브', 'Noun'), ('807', 'Number'), ('호', 'Noun'), ('근무시간', 'Noun'), (':', 'Punctuation'), ('오전', 'Noun'), ('9시', 'Number'), ('~', 'Punctuation'), ('오후', 'Noun'), ('6시', 'Number'), ('(', 'Punctuation'), ('휴게', 'Noun'), ('시간', 'Noun'), ('1시간', 'Number'), (')', 'Punctuation'), ('<', 'Punctuation'), ('복리', 'Noun'), ('후생', 'Noun'), ('>', 'Punctuation'), ('자율', 'Noun'), ('복장', 'Noun'), ('자유로운', 'Adjective'), ('연차', 'Noun'), ('/', 'Punctuation'), ('반', 'Modifier'), ('차', 'Noun'), ('사용', 'Noun'), ('식대', 'Noun'), ('지원', 'Noun'), ('구내식당', 'Noun'), ('이용', 'Noun'), ('가능', 'Noun'), ('사내', 'Noun'), ('카페테리아', 'Noun'), ('이용', 'Noun'), ('가능', 'Noun'), ('직무', 'Noun'), ('관련', 'Noun'), ('자기계발', 'Noun'), ('비', 'Noun'), ('지원', 'Noun'), ('근로자', 'Noun'), ('여름', 'Noun'), ('휴가', 'Noun'), ('비', 'Noun'), ('지원', 'Noun'), ('경조사', 'Noun'), ('지원', 'Noun'), ('제도', 'Noun'), ('명절', 'Noun'), ('선물', 'Noun'), ('제공', 'Noun'), ('출산전후', 'Noun'), ('휴가', 'Noun'), (',', 'Pu ...
# --------------------------------------------------------------------------------
# [('데이터', 'Noun'), ('엔지니어링', 'Noun'), (':', 'Punctuation'), ('데이터', 'Noun'), ('의', 'Josa'), ('수집', 'Noun'), ('/', 'Punctuation'), ('가공', 'Noun'), ('/', 'Punctuation'), ('적재', 'Noun'), ('및', 'Noun'), ('pipeline', 'Alpha'), ('관리', 'Noun')]
# --------------------------------------------------------------------------------
# [('▶', 'Foreign'), ('자금세탁', 'Noun'), ('방지', 'Noun'), ('(', 'Punctuation'), ('AML', 'Alpha'), (')', 'Punctuation'), ('데이터', 'Noun'), ('분석', 'Noun'), ('–', 'Foreign'), ('거래', 'Noun'), ('모니터링', 'Noun'), ('시스템', 'Noun'), ('검증', 'Noun'), (',', 'Punctuation'), ('룰', 'Noun'), ('최적화', 'Noun'), (',', 'Punctuation'), ('STR', 'Alpha'), ('/', 'Punctuation'), ('CTR', 'Alpha'), ('데이터', 'Noun'), ('검증', 'Noun'), (',', 'Punctuation'), ('위험', 'Noun'), ('평가', 'Noun'), ('모델링', 'Noun'), ('▶', 'Foreign'), ('컴플라이언스', 'Noun'), ('업무', 'Noun'), ('프로세스', 'Noun'), ('및', 'Noun'), ('화면', 'Noun'), ('설계', 'Noun'), (',', 'Punctuation'), ('데이터', 'Noun'), ('및', 'Noun'), ('IT', 'Alpha'), ('개발', 'Noun'), ('요건', 'Noun'), ('정의', 'Noun'), ('-', 'Punctuation'), ('금융', 'Noun'), ('정보', 'Noun'), ('자동', 'Noun'), ('교환', 'Noun'), ('(', 'Punctuation'), ('FATCA', 'Alpha'), ('/', 'Punctuation'), ('CRS', 'Alpha'), (')', 'Punctuation'), ('시스템', 'Noun'), ('-', 'Punctuation'), ('금융기관', 'Noun'), ('내부통제', 'Noun'), ('시스템', 'Noun'), ('-', 'Punctuation'), ('금융기관', 'Noun'), ('이', 'Determiner'), ('상거래', 'Noun'), ('탐지', 'Noun'), ('(', 'Punctuation'), ('FDS', 'Alpha'), (')', 'Punctuation'), ('시스템', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('Position', 'Alpha'), ('•', 'Foreign'), ('\t', 'Foreign'), ('소속', 'Noun'), (':', 'Punctuation'), ('전략기획', 'Noun'), ('팀', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('직위', 'Noun'), (':', 'Punctuation'), ('협의', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('연봉', 'Noun'), (':', 'Punctuation'), ('협의', 'Noun'), ('Job', 'Alpha'), ('Description', 'Alpha'), ('•', 'Foreign'), ('\t', 'Foreign'), ('빅데이터', 'Noun'), ('를', 'Josa'), ('이용', 'Noun'), ('한', 'Josa'), ('데이터', 'Noun'), ('관리', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('비즈니스', 'Noun'), ('프로젝트', 'Noun'), ('관리', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('비즈니스', 'Noun'), ('중', 'Noun'), (',', 'Punctuation'), ('장기', 'Noun'), ('전략', 'Noun'), ('수립', 'Noun'), ('및', 'Noun'), ('실행', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('브랜드', 'Noun'), ('및', 'Noun'), ('제품', 'Noun'), ('캠페인', 'Noun'), ('관리', 'Noun'), ('지원', 'Noun'), ('자격', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('화장품', 'Noun'), ('외', 'Noun'), ('다양한', 'Adjective'), ('산업', 'Noun'), ('계', 'Suffix'), ('경험', 'Noun'), ('보유', 'Noun'), ('하신', 'Verb'), ('분', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('마케팅', 'Noun'), ('관련', 'Noun'), ('업무', 'Noun'), ('경험', 'Noun'), ('있으신', 'Adjective'), ('분', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('다양한', 'Adjective'), ('프로젝트', 'Noun'), ('의', 'Josa'), ('PM', 'Alpha'), ('경험', 'Noun'), ('있으신', 'Adjective'), ('분', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('빅데이터', 'Noun'), ('를', 'Josa'), ('이용', 'Noun'), ('한', 'Josa'), ('전략', 'Noun'), ('기획', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), ('•', 'Foreign'), ('\t', 'Foreign'), ('데이터', 'Noun'), ('활용', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), ('우대', 'Noun'), ('사항', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('다양한', 'Adjective'), ('업종', 'Noun'), ('관련', 'Noun'), ('경력', 'Noun'), ('우대', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('외국어', 'Noun'), ('(', 'Punctuation'), ('영어', 'Noun'), ('/', 'Punctuation'), ('중국어', 'Noun'), ('/', 'Punctuation'), ('일본어', 'Noun'), (')', 'Punctuation'), ('능통', 'Noun'), ('자', 'Suffix'), ('우대', 'Noun'), ('근', 'Modifier'), ('무조건', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('근무', 'Noun'), ('형태', 'Noun'), (':', 'Punctuation'), ('정규직', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('근무', 'Noun'), ('일시', 'Noun'), (':', 'Punctuation'), ('주', 'Noun'), ('5일', 'Number'), ('(', 'Punctuation'), ('월', 'Noun'), ('~', 'Punctuation'), ('금', 'Noun'), (')', 'Punctuation'), ('•', 'Foreign'), ('\t', 'Foreign'), ('근무시간', 'Noun'), (':', 'Punctuation'), ('오전', 'Noun'), ('9시', 'Number'), ('~', 'Punctuation'), ('6시', 'Number'), ('(', 'Punctuation'), ('월', 'Noun'), ('~', 'Punctuation'), ('금', 'Noun'), (')', 'Punctuation'), ('•', 'Foreign'), ('\t', 'Foreign'), ('급여', 'Noun'), (':', 'Punctuation'), ('협의', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('근무', 'Noun'), ('지역', 'Noun'), (':', 'Punctuation'), ('서울', 'Noun'), ('강남구', 'Noun'), ('-', 'Punctuation'), ('서울', 'Noun'), ('7', 'Number'), ('호선', 'Noun'), ('강남구청역', 'Noun'), ('에서', 'Josa'), ('50', 'Number'), ('m', 'Alpha'), ('이내', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('복리', 'Noun'), ('후생', 'Noun'), (':', 'Punctuation'), ('4', 'Number'), ('대', 'Modifier'), ('보험', 'Noun'), (',', 'Punctuation'), ('건강검진', 'Noun'), (',', 'Punctuation'), ('생일', 'Noun'), ('휴가', 'Noun'), (',', 'Punctuation'), ('문화', 'Noun'), ('회식', 'Noun'), ('(', 'Punctuation'), ('월', 'Noun'), ('1회', 'Number'), ('전시회', 'Noun'), ('관람', 'Noun'), ('),', 'Punctuation'), ('간식', 'Noun'), ('외', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('네트워크', 'Noun'), ('/', 'Punctuation'), ('서버', 'Noun'), ('/', 'Punctuation'), ('보안', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('웹', 'Noun'), ('개발', 'Noun'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('웹', 'Noun'), ('기획', 'Noun'), ('/', 'Punctuation'), ('PM', 'Alpha'), ('/', 'Punctuation'), ('웹마케팅', 'Noun'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation'), ('데이터', 'Noun'), ('구축', 'Noun'), ('-', 'Punctuation'), ('이미지', 'Noun'), ('데이터', 'Noun'), ('라', 'Josa'), ('벨링', 'Noun'), ('(', 'Punctuation'), ('폴리곤', 'Noun'), ('/', 'Punctuation'), ('비', 'Noun'), ('박스', 'Noun'), (')', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('무관', 'Noun'), ('-', 'Punctuation'), ('AI', 'Alpha'), ('/', 'Punctuation'), ('빅데이터', 'Noun'), ('-', 'Punctuation'), ('데이터', 'Noun'), ('라', 'Josa'), ('벨링', 'Noun'), ('-', 'Punctuation'), ('서울', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation'), ('AI', 'Alpha'), ('/', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('클라우드', 'Noun'), ('인프라', 'Noun'), ('클러스터', 'Noun'), ('구성', 'Noun'), ('및', 'Noun'), ('운영', 'Noun'), ('-', 'Punctuation'), ('AI', 'Alpha'), ('/', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('클라우드', 'Noun'), ('아키텍처', 'Noun'), ('설계', 'Noun'), ('및', 'Noun'), ('구축', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation'), ('AI', 'Alpha'), ('/', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('클라우드', 'Noun'), ('관련', 'Noun'), ('비즈니스', 'Noun'), ('모델', 'Noun'), ('발굴', 'Noun'), ('-', 'Punctuation'), ('AI', 'Alpha'), ('/', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('클라우드', 'Noun'), ('과제', 'Noun'), ('관리', 'Noun'), ('및', 'Noun'), ('팀', 'Noun'), ('운영', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('설문', 'Noun'), ('/', 'Punctuation'), ('통계', 'Noun'), ('/', 'Punctuation'), ('리서치', 'Noun'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('설문', 'Noun'), ('/', 'Punctuation'), ('통계', 'Noun'), ('/', 'Punctuation'), ('리서치', 'Noun'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('기획', 'Noun'), ('/', 'Punctuation'), ('전략', 'Noun'), ('/', 'Punctuation'), ('경영', 'Noun'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# ...
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('ㆍ', 'Foreign'), ('접수', 'Noun'), ('기간', 'Noun'), (':', 'Punctuation'), ('2024년', 'Number'), ('2월', 'Number'), ('6일', 'Number'), ('(', 'Punctuation'), ('화', 'Noun'), (')', 'Punctuation'), ('17시', 'Number'), ('~', 'Punctuation'), ('2024년', 'Number'), ('4월', 'Number'), ('6일', 'Number'), ('(', 'Punctuation'), ('토', 'Noun'), (')', 'Punctuation'), ('24시', 'Number'), ('ㆍ', 'Foreign'), ('접수', 'Noun'), ('방법', 'Noun'), (':', 'Punctuation'), ('사람인', 'Noun'), ('입사', 'Noun'), ('지원', 'Noun'), ('ㆍ', 'Foreign'), ('이력서', 'Noun'), ('양식', 'Noun'), (':', 'Punctuation'), ('사람인', 'Noun'), ('온라인', 'Noun'), ('이력서', 'Noun'), ('ㆍ', 'Foreign'), ('제출', 'Noun'), ('서류', 'Noun'), (':·', 'Punctuation'), ('(', 'Punctuation'), ('필수', 'Noun'), (')', 'Punctuation'), ('입사', 'Noun'), ('지원', 'Noun'), ('서', 'Josa'), ('(', 'Punctuation'), ('자기', 'Noun'), ('소개', 'Noun'), (',', 'Punctuation'), ('학력', 'Noun'), ('/', 'Punctuation'), ('경력', 'Noun'), ('소개', 'Noun'), ('내용', 'Noun'), ('등', 'Noun'), ('포함', 'Noun'), (')', 'Punctuation'), ('\n', 'Foreign'), ('·', 'Punctuation'), ('(', 'Punctuation'), ('필수', 'Noun'), (')', 'Punctuation'), ('대학교', 'Noun'), (',', 'Punctuation'), ('대학원', 'Noun'), ('성적표', 'Noun'), ('및', 'Noun'), ('졸업', 'Noun'), ('증명서', 'Noun'), ('\n', 'Foreign'), ('·', 'Punctuation'), ('(', 'Punctuation'), ('선택', 'Noun'), ('/', 'Punctuation'), ('우대', 'Noun'), (')', 'Punctuation'), ('프로젝트', 'Noun'), ('산출', 'Noun'), ('물', 'Noun'), ('또는', 'Adverb'), ('포트폴리오', 'Noun'), ('(', 'Punctuation'), ('개발', 'Noun'), ('및', 'Noun'), ('분석', 'Noun'), ('프로젝트', 'Noun'), ('의', 'Josa'), ('경우', 'Noun'), ('코드', 'Noun'), ('제출', 'Noun'), ('필수', 'Noun'), (')', 'Punctuation'), ('\n', 'Foreign'), ('·', 'Punctuation'), ('(', 'Punctuation'), ('선택', 'Noun'), ('/', 'Punctuation'), ('우대', 'Noun'), (')', 'Punctuation'), ('석사', 'Noun'), ('학위', 'Noun'), ('이상자', 'Noun'), ('는', 'Josa'), ('졸업', 'Noun'), ('논문', 'Noun'), ('\n', 'Foreign'), ('·', 'Punctuation'), ('필수', 'Noun'), ('서류', 'Noun'), ('미', 'Adjective'), ('제출', 'Noun'), ('시', 'Noun'), ('서류', 'Noun'), ('탈락', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('모집', 'Noun'), ('부문', 'Noun'), ('상', 'Suffix'), ('세', 'Modifier'), ('내용', 'Noun'), ('공통', 'Noun'), ('자격', 'Noun'), ('요건', 'Noun'), ('ㆍ', 'Foreign'), ('학력', 'Noun'), (':', 'Punctuation'), ('무관', 'Noun'), ('보안', 'Noun'), (',', 'Punctuation'), ('네트워크', 'Noun'), ('영업', 'Noun'), ('영업', 'Noun'), ('2', 'Number'), ('팀', 'Noun'), ('1', 'Number'), ('명담', 'Noun'), ('당', 'Modifier'), ('업무', 'Noun'), ('ㆍ', 'Foreign'), ('지원', 'Noun'), ('자격', 'Noun'), ('ㆍ', 'Foreign'), ('경력', 'Noun'), (':', 'Punctuation'), ('경력', 'Noun'), ('(', 'Punctuation'), ('년', 'Noun'), ('수', 'Modifier'), ('무관', 'Noun'), (')(', 'Punctuation'), ('사원', 'Noun'), (',', 'Punctuation'), ('대리', 'Noun'), (',', 'Punctuation'), ('과장', 'Noun'), ('급', 'Suffix'), (')', 'Punctuation'), ('\n            ', 'Foreign'), ('ㆍ', 'Foreign'), ('기타', 'Noun'), ('필수', 'Noun'), ('사항', 'Noun'), ('\n        ', 'Foreign'), ('우대', 'Noun'), ('사항', 'Noun'), ('ㆍ', 'Foreign'), ('2', 'Number'), ('종', 'Noun'), ('소형', 'Noun'), ('운전면허', 'Noun'), ('ㆍ', 'Foreign'), ('해당', 'Noun'), ('직무', 'Noun'), ('근무', 'Noun'), ('경험', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('공통', 'Noun'), ('자격', 'Noun'), ('요건', 'Noun'), ('ㆍ', 'Foreign'), ('학력', 'Noun'), (':', 'Punctuation'), ('무관', 'Noun'), ('AI', 'Alpha'), ('데이터', 'Noun'), ('가공', 'Noun'), ('및', 'Noun'), ('검수', 'Noun'), ('계약', 'Noun'), ('직', 'Noun'), ('시험', 'Noun'), ('평가', 'Noun'), ('연구소', 'Noun'), ('3', 'Number'), ('명담', 'Noun'), ('당', 'Modifier'), ('업무', 'Noun'), ('ㆍ', 'Foreign'), ('지원', 'Noun'), ('자격', 'Noun'), ('ㆍ', 'Foreign'), ('경력', 'Noun'), (':', 'Punctuation'), ('경력', 'Noun'), ('1년', 'Number'), ('이상', 'Noun'), ('(', 'Punctuation'), ('연구원', 'Noun'), (',', 'Punctuation'), ('선임', 'Noun'), ('연구원', 'Noun'), ('급', 'Suffix'), (')', 'Punctuation'), ('ㆍ', 'Foreign'), ('수행', 'Noun'), ('업무', 'Noun'), (':', 'Punctuation'), ('AI', 'Alpha'), ('학습', 'Noun'), ('용', 'Noun'), ('데이터', 'Noun'), ('가공', 'Noun'), ('보조', 'Noun'), ('및', 'Noun'), ('검수', 'Noun'), ('\n            ', 'Foreign'), ('ㆍ', 'Foreign'), ('기타', 'Noun'), ('필수', 'Noun'), ('사항', 'Noun'), ('\n        ', 'Foreign'), ('우대', 'Noun'), ('사항', 'Noun'), ('ㆍ', 'Foreign'), ('인근', 'Noun'), ('거주', 'Noun'), ('자', 'Suffix'), (',', 'Punctuation'), ('해당', 'Noun'), ('직무', 'Noun'), ('근무', 'Noun'), ('경험', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('모집', 'Noun'), ('부문', 'Noun'), ('상', 'Suffix'), ('세', 'Modifier'), ('내용', 'Noun'), ('공통', 'Noun'), ('자격', 'Noun'), ('요건', 'Noun'), ('ㆍ', 'Foreign'), ('학력', 'Noun'), (':', 'Punctuation'), ('대졸', 'Noun'), ('이상', 'Noun'), ('응용', 'Noun'), ('/', 'Punctuation'), ('웹', 'Noun'), ('프로그램', 'Noun'), ('/', 'Punctuation'), ('데이터베이스', 'Noun'), ('개발', 'Noun'), ('0', 'Number'), ('명담', 'Noun'), ('당', 'Modifier'), ('업무', 'Noun'), ('ㆍ', 'Foreign'), ('지원', 'Noun'), ('자격', 'Noun'), ('ㆍ', 'Foreign'), ('경력', 'Noun'), (':', 'Punctuation'), ('신입', 'Noun'), ('\xa0', 'Foreign'), ('(', 'Punctuation'), ('연구원', 'Noun'), (')', 'Punctuation'), ('\n            ', 'Foreign'), ('ㆍ', 'Foreign'), ('기타', 'Noun'), ('필수', 'Noun'), ('사항', 'Noun'), ('\n        ', 'Foreign'), ('담당', 'Noun'), ('업무', 'Noun'), ('ㆍ', 'Foreign'), ('응용프로그램', 'Noun'), ('개발', 'Noun'), ('(', 'Punctuation'), ('C', 'Alpha'), ('#,', 'Punctuation'), ('Java', 'Alpha'), (',', 'Punctuation'), ('ASP.NET', 'URL'), (',', 'Punctuation'), ('Web', 'Alpha'), ('등', 'Noun'), (')', 'Punctuation'), ('ㆍ', 'Foreign'), ('데이터베이스', 'Noun'), ('개발', 'Noun'), ('(', 'Punctuation'), ('Oralce', 'Alpha'), (',', 'Punctuation'), ('MSSQL', 'Alpha'), ('등', 'Noun'), (')', 'Punctuation'), ('우대', 'Noun'), ('사항', 'Noun'), ('ㆍ', 'Foreign'), ('컴퓨터', 'Noun'), ('/', 'Punctuation'), ('시스템', 'Noun'), ('공학', 'Noun'), (',', 'Punctuation'), ('공학', 'Noun'), ('계열', 'Noun'), (',', 'Punctuation'), ('수학', 'Noun'), ('/', 'Punctuation'), ('통계학', 'Noun'), ('ㆍ', 'Foreign'), ('TOEIC', 'Alpha'), ('00', 'Number'), ('급', 'Noun'), ('(', 'Punctuation'), ('점', 'Noun'), (')', 'Punctuation'), ('이상', 'Noun'), (',', 'Punctuation'), ('TOEFL', 'Alpha'), ('00', 'Number'), ('급', 'Noun'), ('(', 'Punctuation'), ('점', 'Noun'), (')', 'Punctuation'), ('이상', 'Noun'), ('ㆍ', 'Foreign'), ('정보처리기사', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('공통', 'Noun'), ('자격', 'Noun'), ('요건', 'Noun'), ('ㆍ', 'Foreign'), ('학력', 'Noun'), (':', 'Punctuation'), ('대졸', 'Noun'), ('이상', 'Noun'), ('(', 'Punctuation'), ('4년', 'Number'), (')(', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), ('(', 'Punctuation'), ('머신', 'Noun'), ('러닝', 'Noun'), ('딥', 'Noun'), ('러닝', 'Noun'), (')/', 'Punctuation'), ('파이썬', 'Noun'), ('/', 'Punctuation'), ('자바', 'Noun'), (')', 'Punctuation'), ('강사', 'Noun'), ('채용', 'Noun'), ('3', 'Number'), ('명담', 'Noun'), ('당', 'Modifier'), ('업무', 'Noun'), ('ㆍ', 'Foreign'), ('지원', 'Noun'), ('자격', 'Noun'), ('ㆍ', 'Foreign'), ('경력', 'Noun'), (':', 'Punctuation'), ('경력', 'Noun'), ('2년', 'Number'), ('이상', 'Noun'), ('\n            ', 'Foreign'), ('ㆍ', 'Foreign'), ('기타', 'Noun'), ('필수', 'Noun'), ('사항', 'Noun'), ('\n        ', 'Foreign'), ('우대', 'Noun'), ('사항', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('모집', 'Noun'), ('부문', 'Noun'), ('상', 'Suffix'), ('세', 'Modifier'), ('내용', 'Noun'), ('사업', 'Noun'), ('운영', 'Noun'), ('부', 'Noun'), ('[', 'Punctuation'), ('담당', 'Noun'), ('업무', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('부동산', 'Noun'), ('권리', 'Noun'), ('조사', 'Noun'), ('상품', 'Noun'), ('기획', 'Noun'), ('ㆍ', 'Foreign'), ('권리', 'Noun'), ('조사', 'Noun'), ('서비스', 'Noun'), ('운용', 'Noun'), ('및', 'Noun'), ('프로세스', 'Noun'), ('개선', 'Noun'), ('ㆍ', 'Foreign'), ('부동산', 'Noun'), ('권리', 'Noun'), ('조사', 'Noun'), ('사고', 'Noun'), ('원인', 'Noun'), ('추적', 'Noun'), ('및', 'Noun'), ('분석', 'Noun'), ('[', 'Punctuation'), ('자격', 'Noun'), ('요건', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('부동산', 'Noun'), ('권리', 'Noun'), ('조사', 'Noun'), ('상품', 'Noun'), ('및', 'Noun'), ('서비스', 'Noun'), ('기획', 'Noun'), ('경력', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('ㆍ', 'Foreign'), ('부동산', 'Noun'), ('권리', 'Noun'), ('조사', 'Noun'), ('업무', 'Noun'), ('수행', 'Noun'), ('경력', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('ㆍ', 'Foreign'), ('금융', 'Noun'), ('권', 'Suffix'), ('협업', 'Noun'), ('경험', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('[', 'Punctuation'), ('우대', 'Noun'), ('사항', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('관련', 'Noun'), ('직종', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), ('ㆍ', 'Foreign'), ('부동산', 'Noun'), ('관련', 'Noun'), ('전공자', 'Noun'), ('또는', 'Adverb'), ('관련', 'Noun'), ('자격증', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('법인', 'Noun'), ('영업', 'Noun'), ('부담', 'Noun'), ('당', 'Suffix'), ('업무', 'Noun'), ('ㆍ', 'Foreign'), ('[', 'Punctuation'), ('담당', 'Noun'), ('업무', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('전세', 'Noun'), ('대출', 'Noun'), ('관련', 'Noun'), ('금융', 'Noun'), ('권', 'Suffix'), ('B', 'Alpha'), ('2', 'Number'), ('B', 'Alpha'), ('영업', 'Noun'), ('ㆍ', 'Foreign'), ('시장', 'Noun'), ('동향', 'Noun'), ('파악', 'Noun'), (',', 'Punctuation'), ('상품', 'Noun'), ('제안', 'Noun'), (',', 'Punctuation'), ('입찰', 'Noun'), ('업무', 'Noun'), ('대응', 'Noun'), ('ㆍ', 'Foreign'), ('고객', 'Noun'), ('사별', 'Noun'), ('마케팅', 'Noun'), ('및', 'Noun'), ('신규', 'Noun'), ('거래처', 'Noun'), ('발굴', 'Noun'), ('[', 'Punctuation'), ('자격', 'Noun'), ('요건', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('부동산', 'Noun'), ('권리', 'Noun'), ('조사', 'Noun'), ('상품', 'Noun'), ('및', 'Noun'), ('서비스', 'Noun'), ('기획', 'Noun'), ('경력', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('ㆍ', 'Foreign'), ('금융', 'Noun'), ('권', 'Suffix'), ('법인', 'Noun'), ('영업', 'Noun'), ('경력', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('[', 'Punctuation'), ('우대', 'Noun'), ('사항', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('관련', 'Noun'), ('직종', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), ('ㆍ', 'Foreign'), ('부동산', 'Noun'), ('관련', 'Noun'), ('전공자', 'Noun'), ('또는', 'Adverb'), ('관련', 'Noun'), ('자격증', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('ㆍ', 'Foreign'), ('금융', 'Noun'), ('권', 'Suffix'), ('또는', 'Adverb'), ('금융', 'Noun'), ('권', 'Suffix'), ('영업', 'Noun'), ('경력', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('\n            ', 'Foreign'), ('ㆍ', 'Foreign'), ('기타', 'Noun'), ('필수', 'Noun'), ('사항', 'Noun'), ('\n        ', 'Foreign'), ('우대', 'Noun'), ('사항', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [('및', 174), ('데이터', 155), ('빅데이터', 95), ('데이터베이스', 88), ('분석', 84), ('DBA', 82), ('개발', 78), ('AI', 75), ('업무', 71), ('분', 64), ('경험', 59), ('관리', 49), ('등', 47), ('경력', 47), ('지원', 45), ('근무', 45), ('우대', 43), ('사항', 35), ('자격', 32), ('관련', 32), ('이상', 29), ('있으신', 27), ('위', 25), ('요건', 25), ('구축', 25), ('운영', 25), ('기획', 25), ('수집', 24), ('사용', 24), ('프로젝트', 24), ('시스템', 24), ('고객', 23), ('서비스', 23), ('설계', 22), ('기반', 22), ('사업', 22), ('활용', 21), ('보유', 20), ('모집', 19), ('제공', 19), ('다양한', 17), ('가능', 17), ('필수', 17), ('플랫폼', 17), ('부동산', 17), ('수행', 16), ('기술', 16), ('수', 16), ('영업', 16), ('처리', 16)]
# {'데이터베이스': 88, '분석': 84, 'DBA': 82, '개발': 78, 'AI': 75, '업무': 71, '경험': 59, '관리': 49, '경력': 47, '지원': 45, '근무': 45, '우대': 43, '사항': 35, '자격': 32, '요건': 25, '구축': 25, '운영': 25, '기획': 25, '수집': 24, '사용': 24, '프로젝트': 24, '시스템': 24, '고객': 23, '서비스': 23, '설계': 22, '기반': 22, '사업': 22, '활용': 21, '보유': 20, '모집': 19, '제공': 19, '다양한': 17, '가능': 17, '필수': 17, '플랫폼': 17, '부동산': 17, '수행': 16, '기술': 16, '수': 16, '영업': 16, '처리': 16}

# %%
def make_wordcloud(title_list, stopwords, word_count):  # 딕셔너리로 만듦
    okt = Okt()
    sentences_tag = []
    # 형태소 분석하여 리스트에 넣기
    for sentence in title_list:
        morph = okt.pos(sentence)
        sentences_tag.append(morph)
        print(morph)
        print('-' * 80)
    noun_adj_list = []
    # 명사와 형용사만 구분하여 리스트에 추가
    for sentence1 in sentences_tag:
        for word, tag in sentence1:
            if tag in ["Alpha"]:
                noun_adj_list.append(word)
    # 형태소별 count
    counts = Counter(noun_adj_list)
    tags = counts.most_common(word_count)
    print('-' * 80)
    print(tags)
    tag_dict = dict(tags)
    # 검색어 제외 방법 2: dict에서 해당 검색어 제거
    for stopword in stopwords:
        if stopword in tag_dict:
            tag_dict.pop(stopword)
    print(tag_dict)
    if platform.system() == 'Windows':
        path = r'c:\Windows\Fonts\malgun.ttf'
    elif platform.system() == 'Darwin':  # Mac OS
        path = r'/System/Library/Fonts/AppleGothic'
    else:
        path = r'/usr/share/fonts/truetype/name/NanumMyeongjo.ttf'
    img_mask = np.array(Image.open('cloud.png'))
    wordcloud = WordCloud(font_path=path, width=800, height=600,
                          background_color="white", max_font_size=200,
                          repeat=True,
                          colormap='inferno', mask=img_mask)
    cloud = wordcloud.generate_from_frequencies(tag_dict)
    plt.figure(figsize=(10, 8))
    plt.axis('off')
    plt.imshow(cloud)
    plt.show()


if __name__ == '__main__':
    #search_word = "ChatGPT"  # 검색어 지정
    #title_list = []
    stopwords = ['데이터', "빅데이터", "및", "이상", "등", "관련", "분", "위", "있으신", "or", "B"]  # wordcloud에서 제외할 단어
    # 1~200번게시글 까지 크롤링
    #get_titles(1, 200, search_word, title_list)
    # 단어 50개까지 wordcloud로 출력
    make_wordcloud(title_list, stopwords, 50)
# Out:
# [('데이터', 'Noun'), ('수집', 'Noun'), (',', 'Punctuation'), ('정제', 'Noun'), ('데이터', 'Noun'), ('분석', 'Noun'), ('인공', 'Noun'), ('지능', 'Noun'), ('개발', 'Noun'), ('논문', 'Noun'), ('연구', 'Noun')]
# --------------------------------------------------------------------------------
# [('자료', 'Noun'), ('조사', 'Noun'), ('(', 'Punctuation'), ('문헌', 'Noun'), (',', 'Punctuation'), ('설문', 'Noun'), ('등', 'Noun'), (')', 'Punctuation'), ('데이터', 'Noun'), ('분석', 'Noun'), ('(', 'Punctuation'), ('엑셀', 'Noun'), (',', 'Punctuation'), ('R', 'Alpha'), ('프로그램', 'Noun'), (',', 'Punctuation'), ('파이썬', 'Noun'), ('등', 'Noun'), (')', 'Punctuation'), ('보고서', 'Noun'), ('작성', 'Noun'), ('(', 'Punctuation'), ('아래한글', 'Noun'), (',', 'Punctuation'), ('PPT', 'Alpha'), ('등', 'Noun'), (')', 'Punctuation'), ('지원', 'Noun'), ('※', 'Foreign'), ('고용', 'Noun'), ('센터', 'Noun'), ('채용', 'Noun'), ('대행', 'Noun'), ('건', 'Noun'), ('으로', 'Josa'), ('구직', 'Noun'), ('신청', 'Noun'), ('후', 'Noun'), ('워크넷', 'Noun'), ('으로', 'Josa'), ('입사', 'Noun'), ('지원', 'Noun'), ('바랍니다', 'Verb'), ('.', 'Punctuation'), ('-', 'Punctuation'), ('실업', 'Noun'), ('급여', 'Noun'), ('구직', 'Noun'), ('활동', 'Noun'), ('을', 'Josa'), ('위', 'Noun'), ('한', 'Josa'), ('지원', 'Noun'), ('을', 'Josa'), ('자제', 'Noun'), ('부탁드리며', 'Adjective'), (',', 'Punctuation'), ('실제', 'Noun'), ('취업', 'Noun'), ('의사', 'Noun'), ('가', 'Josa'), ('있는', 'Adjective'), ('분만', 'Noun'), ('지원', 'Noun'), ('바랍니다', 'Verb'), ('.', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('브', 'Noun'), ('래', 'Josa'), ('키츠', 'Noun'), ('(', 'Punctuation'), ('주', 'Noun'), (')', 'Punctuation'), ('에서', 'Josa'), ('아래', 'Noun'), ('와', 'Josa'), ('같이', 'Adverb'), ('태블', 'Noun'), ('로', 'Josa'), ('(', 'Punctuation'), ('Tableau', 'Alpha'), (')', 'Punctuation'), ('경력', 'Noun'), ('자', 'Suffix'), ('를', 'Josa'), ('모집', 'Noun'), ('합니다', 'Verb'), ('.', 'Punctuation'), ('[', 'Punctuation'), ('회사', 'Noun'), ('소개', 'Noun'), (']', 'Punctuation'), ('‘', 'Foreign'), ('디지털', 'Noun'), ('해결', 'Noun'), ('소', 'Noun'), ('’', 'Punctuation'), ('를', 'Noun'), ('표방', 'Noun'), ('하는', 'Verb'), ('브', 'Noun'), ('래', 'Josa'), ('키츠', 'Noun'), ('(', 'Punctuation'), ('주', 'Noun'), (')', 'Punctuation'), ('는', 'Verb'), ('다양한', 'Adjective'), ('분야', 'Noun'), ('유수', 'Noun'), ('의', 'Josa'), ('고객', 'Noun'), ('사', 'Noun'), ('에', 'Josa'), ('DT', 'Alpha'), ('(', 'Punctuation'), ('Digital', 'Alpha'), ('Transformation', 'Alpha'), ('),', 'Punctuation'), ('Analytics', 'Alpha'), (',', 'Punctuation'), ('Cloud', 'Alpha'), ('등', 'Noun'), ('ERP', 'Alpha'), ('·', 'Punctuation'), ('BI', 'Alpha'), ('분야', 'Noun'), ('전반', 'Noun'), ('에', 'Josa'), ('걸쳐', 'Verb'), ('실용', 'Noun'), ('적', 'Suffix'), ('인', 'Josa'), ('솔루션', 'Noun'), ('을', 'Josa'), ('제공', 'Noun'), ('하는', 'Verb'), ('IT', 'Alpha'), ('컨설팅', 'Noun'), ('기업', 'Noun'), ('입니다', 'Adjective'), ('.', 'Punctuation'), ('2021년', 'Number'), ('창사', 'Noun'), ('이래', 'Adjective'), ('급속한', 'Adjective'), ('성장', 'Noun'), ('과', 'Josa'), ('함께', 'Adverb'), ('우리', 'Noun'), ('는', 'Josa'), ('열정', 'Noun'), ('있는', 'Adjective'), ('인재', 'Noun'), ('들', 'Suffix'), ('을', 'Josa'), ('찾아', 'Verb'), ('함께', 'Adverb'), ('성장하고자', 'Adjective'), ('합니다', 'Verb'), ('.', 'Punctuation'), ('[', 'Punctuation'), ('직무', 'Noun'), ('및', 'Noun'), ('업무', 'Noun'), ('내용', 'Noun'), (']', 'Punctuation'), ('▶', 'Foreign'), ('태블', 'Noun'), ('로', 'Josa'), ('(', 'Punctuation'), ('Tableau', 'Alpha'), (')', 'Punctuation'), ('를', 'Noun'), ('이용', 'Noun'), ('한', 'Josa'), ('데이터', 'Noun'), ('시각', 'Noun'), ('화', 'Suffix'), ('및', 'Noun'), ('분석', 'Noun'), ('작업', 'Noun'), ('수행', 'Noun'), ('▶', 'Foreign'), ('다양한', 'Adjective'), ('데이터', 'Noun'), ('소스', 'Noun'), ('로부터', 'Noun'), ('의', 'Josa'), ('데이터', 'Noun'), ('추출', 'Noun'), ('및', 'Noun'), ('가공', 'Noun'), ('▶', 'Foreign'), ('리포트', 'Noun'), ('및', 'Noun'), ('대시보드', 'Noun'), ('개발', 'Noun'), ('및', 'Noun'), ('유지', 'Noun'), ('보수', 'Noun'), ('▶', 'Foreign'), ('데이터', 'Noun'), ('분석', 'Noun'), ('결과', 'Noun'), ('에', 'Josa'), ('대한', 'Noun'), ('해석', 'Noun'), ('및', 'Noun'), ('비즈니스', 'Noun'), ('(', 'Punctuation'), ('고객', 'Noun'), ('사', 'Noun'), (')', 'Punctuation'), ('에', 'Josa'), ('제안', 'Noun'), ('[', 'Punctuation'), ('자격', 'Noun'), ('요건', 'Noun'), (']', 'Punctuation'), ('▶', 'Foreign'), ('태블', 'Noun'), ('로', 'Josa'), ('(', 'Punctuation'), ('Tableau', 'Alpha'), (')', 'Punctuation'), ('경력', 'Noun'), ('2년', 'Number'), ('이상', 'Noun'), ('✔', 'Foreign'), ('세', 'Modifier'), ('일', 'Modifier'), ('즈', 'Modifier'), ('포스', 'Noun'), ('태블', 'Noun'), ('로', 'Josa'), ('신병', 'Noun'), ('훈련소', 'Noun'), ('교육', 'Noun'), ('자료', 'Noun'), ('생', 'Noun'), ('성', 'Suffix'), ('/', 'Punctuation'), ('이해', 'Noun'), ('가능', 'Noun'), ('실력', 'Noun'), ('✔', 'Foreign'), ('태블', 'Noun'), ('로', 'Josa'), ('장표', 'Noun'), ('생', 'Noun'), ('성', 'Suffix'), ('에', 'Josa'), ('필요한', 'Adjective'), ('데이터', 'Noun'), ('셋', 'Noun'), ('(', 'Punctuation'), ('포맷', 'Noun'), (')', 'Punctuation'), ('구성', 'Noun'), ('능력', 'Noun'), ('필요', 'Noun'), ('▶', 'Foreign'), ('SQL', 'Alpha'), ('조', 'Modifier'), ('회문', 'Noun'), ('(', 'Punctuation'), ('select', 'Alpha'), (')', 'Punctuation'), ('작성', 'Noun'), ('실력', 'Noun'), ('✔', 'Foreign'), ('서브', 'Noun'), ('쿼리', 'Noun'), (',', 'Punctuation'), ('피벗', 'Noun'), ('사용', 'Noun'), ('가능', 'Noun'), ('자', 'Suffix'), ('[', 'Punctuation'), ('우대', 'Noun'), ('사항', 'Noun'), (']', 'Punctuation'), ('▶', 'Foreign'), ('태블', 'Noun'), ('로', 'Josa'), ('구축', 'Noun'), ('프로젝트', 'Noun'), ('진행', 'Noun'), ('경험', 'Noun'), ('3회', 'Number'), ('이상', 'Noun'), ('[', 'Punctuation'), ('지원', 'Noun'), ('방법', 'Noun'), ...
# --------------------------------------------------------------------------------
# [('[', 'Punctuation'), ('공통', 'Noun'), ('자격', 'Noun'), ('요건', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('학력', 'Noun'), ('/', 'Punctuation'), ('성별', 'Noun'), (':', 'Punctuation'), ('무관', 'Noun'), ('ㆍ', 'Foreign'), ('경력', 'Noun'), (':', 'Punctuation'), ('경력', 'Noun'), ('(', 'Punctuation'), ('1년', 'Number'), ('이상', 'Noun'), ('또는', 'Adverb'), ('동등', 'Noun'), ('이상', 'Noun'), ('개발', 'Noun'), ('이력', 'Noun'), (')', 'Punctuation'), ('ㆍ', 'Foreign'), ('수습', 'Noun'), (':', 'Punctuation'), ('3', 'Number'), ('개월', 'Noun'), ('[', 'Punctuation'), ('담당', 'Noun'), ('업무', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('인공', 'Noun'), ('지능', 'Noun'), ('알고리즘', 'Noun'), ('개발', 'Noun'), ('[', 'Punctuation'), ('자격', 'Noun'), ('요건', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('Linux', 'Alpha'), (',', 'Punctuation'), ('Windows', 'Alpha'), ('환경', 'Noun'), ('에서', 'Josa'), ('어플리케이션', 'Noun'), ('설계', 'Noun'), ('및', 'Noun'), ('개발', 'Noun'), ('ㆍ', 'Foreign'), ('Python', 'Alpha'), ('언어', 'Noun'), ('개발', 'Noun'), ('가능', 'Noun'), ('자', 'Suffix'), ('ㆍ', 'Foreign'), ('인공', 'Noun'), ('지능', 'Noun'), ('모델', 'Noun'), ('개발', 'Noun'), ('에', 'Josa'), ('필요한', 'Adjective'), ('기술', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('[', 'Punctuation'), ('우대', 'Noun'), ('사항', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('인공', 'Noun'), ('지능', 'Noun'), ('모델', 'Noun'), ('서비스', 'Noun'), ('화', 'Suffix'), ('경험', 'Noun'), ('이', 'Josa'), ('있으신', 'Adjective'), ('분', 'Noun'), ('ㆍ', 'Foreign'), ('인공', 'Noun'), ('지능', 'Noun'), ('관련', 'Noun'), ('학과', 'Noun'), ('석', 'Modifier'), ('박사', 'Noun'), ('우대', 'Noun'), ('ㆍ', 'Foreign'), ('열린', 'Verb'), ('마음', 'Noun'), ('으로', 'Josa'), ('목표', 'Noun'), ('를', 'Josa'), ('위', 'Noun'), ('한', 'Josa'), ('원활한', 'Adjective'), ('커뮤니케이션', 'Noun'), ('을', 'Josa'), ('즐기시는', 'Verb'), ('분', 'Noun'), ('ㆍ', 'Foreign'), ('Git', 'Alpha'), ('-', 'Punctuation'), ('hub', 'Alpha'), ('주소', 'Noun'), (',', 'Punctuation'), ('개발', 'Noun'), ('포트폴리오', 'Noun'), ('제출', 'Noun'), ('이', 'Josa'), ('가능하신', 'Adjective'), ('분', 'Noun'), ('[', 'Punctuation'), ('복리', 'Noun'), ('후생', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('모든', 'Noun'), ('임', 'Noun'), ('직원', 'Noun'), ('통신비', 'Noun'), ('제공', 'Noun'), ('ㆍ', 'Foreign'), ('모든', 'Noun'), ('임', 'Noun'), ('직원', 'Noun'), ('중식', 'Noun'), ('제공', 'Noun'), ('ㆍ', 'Foreign'), ('명절', 'Noun'), ('(', 'Punctuation'), ('설', 'Noun'), ('/', 'Punctuation'), ('추석', 'Noun'), (')', 'Punctuation'), ('선물', 'Noun'), ('지급', 'Noun'), ('ㆍ', 'Foreign'), ('경', 'Modifier'), ('조금', 'Noun'), ('지원', 'Noun'), ('ㆍ', 'Foreign'), ('야근', 'Noun'), ('시', 'Noun'), ('식대', 'Noun'), ('지원', 'Noun'), ('ㆍ', 'Foreign'), ('출퇴근시간', 'Noun'), ('유연근무제', 'Noun'), ('시행', 'Noun'), ('ㆍ', 'Foreign'), ('자율', 'Noun'), ('적', 'Suffix'), ('인', 'Josa'), ('휴가', 'Noun'), ('사용', 'Noun'), ('(', 'Punctuation'), ('연차', 'Noun'), (',', 'Punctuation'), ('반', 'Modifier'), ('차', 'Noun'), ('등', 'Noun'), (')', 'Punctuation'), ('*', 'Punctuation'), ('회사', 'Noun'), ('성장', 'Noun'), ('에', 'Josa'), ('따라', 'Verb'), ('복리', 'Noun'), ('후생', 'Noun'), ('추가', 'Noun'), ('예정', 'Noun')]
# --------------------------------------------------------------------------------
# [('○', 'Foreign'), ('데이터', 'Noun'), ('기반', 'Noun'), ('행정', 'Noun'), ('활성화', 'Noun'), ('(', 'Punctuation'), ('시행', 'Noun'), ('계획', 'Noun'), ('수립', 'Noun'), (',', 'Punctuation'), ('역량', 'Noun'), ('강화', 'Noun'), (',', 'Punctuation'), ('데이터', 'Noun'), ('공유', 'Noun'), ('등', 'Noun'), (')', 'Punctuation'), ('○', 'Foreign'), ('데이터', 'Noun'), ('기반', 'Noun'), ('행정', 'Noun'), ('실태', 'Noun'), ('점검', 'Noun'), ('대응', 'Noun'), ('○', 'Foreign'), ('공공', 'Modifier'), ('데이터', 'Noun'), ('품질', 'Noun'), ('관리', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('드라마', 'Noun'), ('제작', 'Noun'), ('현장', 'Noun'), ('에서', 'Josa'), ('함께', 'Adverb'), ('일', 'Noun'), ('할', 'Verb'), ('스텝', 'Noun'), ('모집', 'Noun'), ('합니다', 'Verb'), ('.', 'Punctuation'), ('안녕하세요', 'Adjective'), ('저희', 'Noun'), ('회사', 'Noun'), ('는', 'Josa'), ('마포구', 'Noun'), ('상암동', 'Noun'), ('에', 'Josa'), ('소재', 'Noun'), ('하고', 'Josa'), ('있으며', 'Adjective'), ('스텝', 'Noun'), ('분', 'Noun'), ('들', 'Suffix'), ('은', 'Josa'), ('촬영', 'Noun'), ('현장', 'Noun'), ('에', 'Josa'), ('따라', 'Verb'), ('상암동', 'Noun'), ('또는', 'Adverb'), ('여의도', 'Noun'), (',', 'Punctuation'), ('일산', 'Noun'), ('에서', 'Josa'), ('스텝', 'Noun'), ('버스', 'Noun'), ('를', 'Josa'), ('타고', 'Noun'), ('현장', 'Noun'), ('근무', 'Noun'), ('합니다', 'Verb'), ('.', 'Punctuation'), ('주요', 'Noun'), ('업무', 'Noun'), ('는', 'Josa'), ('현장', 'Noun'), ('데이터', 'Noun'), ('매니저', 'Noun'), ('이며', 'Josa'), ('촬영', 'Noun'), ('된', 'Verb'), ('데이터', 'Noun'), ('를', 'Josa'), ('복제', 'Noun'), ('및', 'Noun'), ('변환', 'Noun'), ('/', 'Punctuation'), ('가공', 'Noun'), ('하는', 'Verb'), ('업무', 'Noun'), ('입니다', 'Adjective'), ('.', 'Punctuation'), ('처음', 'Noun'), ('접', 'Noun'), ('하시는', 'Verb'), ('분', 'Noun'), ('들', 'Suffix'), ('을', 'Josa'), ('위해', 'Noun'), ('사내', 'Noun'), ('에서', 'Josa'), ('사전', 'Noun'), ('교육', 'Noun'), ('과', 'Josa'), ('현장', 'Noun'), ('에서', 'Josa'), ('서포터', 'Noun'), ('분', 'Suffix'), ('이', 'Josa'), ('함께', 'Adverb'), ('참가', 'Noun'), ('해', 'Verb'), ('교육', 'Noun'), ('을', 'Josa'), ('시켜', 'Verb'), ('드리기에', 'Verb'), ('기존', 'Noun'), ('의', 'Josa'), ('경험', 'Noun'), ('및', 'Noun'), ('기초', 'Noun'), ('지식', 'Noun'), ('은', 'Josa'), ('필요', 'Noun'), ('치', 'Noun'), ('않습니다', 'Verb'), ('.', 'Punctuation'), ('데이터', 'Noun'), ('매니저', 'Noun'), ('의', 'Josa'), ('역할', 'Noun'), ('을', 'Josa'), ('하다가', 'Verb'), ('촬영', 'Noun'), ('현장', 'Noun'), ('에', 'Josa'), ('익숙해', 'Adjective'), ('지시', 'Noun'), ('면', 'Josa'), ('촬영', 'Noun'), ('/', 'Punctuation'), ('편집', 'Noun'), ('/', 'Punctuation'), ('제작', 'Noun'), ('/', 'Punctuation'), ('연출', 'Noun'), ('등', 'Noun'), ('의', 'Josa'), ('타', 'Noun'), ('업무', 'Noun'), ('로', 'Josa'), ('의', 'Noun'), ('전환', 'Noun'), ('도', 'Josa'), ('가능합니다', 'Adjective'), ('.', 'Punctuation'), ('드라마', 'Noun'), ('촬영', 'Noun'), ('스텝', 'Noun'), ('분야', 'Noun'), ('의', 'Josa'), ('관심', 'Noun'), ('있는', 'Adjective'), ('분', 'Noun'), ('들', 'Suffix'), ('의', 'Josa'), ('많은', 'Adjective'), ('지원', 'Noun'), ('바랍니다', 'Verb')]
# --------------------------------------------------------------------------------
# [('국립', 'Noun'), ('금오공과대', 'Noun'), ('학교', 'Noun'), ('에서는', 'Josa'), ('2024년', 'Number'), ('국립', 'Noun'), ('대학', 'Noun'), ('육성', 'Noun'), ('사업', 'Noun'), ('업무', 'Noun'), ('추진', 'Noun'), ('을', 'Josa'), ('위해', 'Noun'), ('참신하고', 'Adjective'), ('유능한', 'Adjective'), ('인재', 'Noun'), ('를', 'Josa'), ('다음', 'Noun'), ('과', 'Josa'), ('같이', 'Adverb'), ('모집', 'Noun'), ('합니다', 'Verb'), ('.', 'Punctuation'), ('1', 'Number'), ('.', 'Punctuation'), ('채용', 'Noun'), ('분야', 'Noun'), ('및', 'Noun'), ('인원', 'Noun'), ('◎', 'Foreign'), ('전문', 'Noun'), ('계약', 'Noun'), ('직', 'Noun'), ('(', 'Punctuation'), ('데이터', 'Noun'), ('관리', 'Noun'), ('및', 'Noun'), ('분석', 'Noun'), (')', 'Punctuation'), ('1', 'Number'), ('명', 'Noun'), ('-', 'Punctuation'), ('학생', 'Noun'), ('역량', 'Noun'), ('관리', 'Noun'), ('시스템', 'Noun'), ('고도화', 'Noun'), ('2', 'Number'), ('.', 'Punctuation'), ('접수', 'Noun'), ('기간', 'Noun'), (':', 'Punctuation'), ('2024.2', 'Number'), ('.', 'Punctuation'), ('9', 'Number'), ('.(', 'Punctuation'), ('금', 'Noun'), (')', 'Punctuation'), ('~', 'Punctuation'), ('2.16', 'Number'), ('.(', 'Punctuation'), ('금', 'Noun'), (')', 'Punctuation'), ('18:00', 'Number'), ('3', 'Number'), ('.', 'Punctuation'), ('접수', 'Noun'), ('방법', 'Noun'), (':', 'Punctuation'), ('이메일', 'Noun'), ('접수', 'Noun'), ('*', 'Punctuation'), ('기타', 'Noun'), ('자세한', 'Adjective'), ('사항', 'Noun'), ('은', 'Josa'), ('붙임', 'Verb'), ('파일', 'Noun'), ('참조', 'Noun'), ('바랍니다', 'Verb'), ('.', 'Punctuation'), ('2024년', 'Number'), ('2월', 'Number'), ('8일', 'Number'), ('국립', 'Noun'), ('금오공과대', 'Noun'), ('학교', 'Noun'), ('총장', 'Noun')]
# --------------------------------------------------------------------------------
# [('공공기관', 'Noun'), ('데이터', 'Noun'), ('표준', 'Noun'), ('품질', 'Noun'), ('업무', 'Noun'), ('(', 'Punctuation'), ('가', 'Verb'), (')', 'Punctuation'), ('데이터', 'Noun'), ('사업', 'Noun'), ('수행', 'Noun'), ('경력', 'Noun'), ('최소', 'Noun'), ('3년', 'Number'), ('이상', 'Noun'), ('+', 'Punctuation'), ('PM', 'Alpha'), ('수행', 'Noun'), ('경험', 'Noun'), ('보유', 'Noun'), ('(', 'Punctuation'), ('나', 'Noun'), (')', 'Punctuation'), ('데이터', 'Noun'), ('관리', 'Noun'), ('체계', 'Noun'), ('구축', 'Noun'), ('컨설팅', 'Noun'), (',', 'Punctuation'), ('데이터', 'Noun'), ('표준', 'Noun'), ('수립', 'Noun'), (',', 'Punctuation'), ('데이터', 'Noun'), ('품질', 'Noun'), ('진단', 'Noun'), (',', 'Punctuation'), ('데이터', 'Noun'), ('개발', 'Noun'), ('등', 'Noun'), ('데이터', 'Noun'), ('관련', 'Noun'), ('사업', 'Noun'), ('유', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), ('(', 'Punctuation'), ('다', 'Adverb'), (')', 'Punctuation'), ('빅데이터', 'Noun'), ('분석', 'Noun'), ('및', 'Noun'), ('플랫폼', 'Noun'), ('구축', 'Noun'), ('사업', 'Noun'), ('유', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('분석', 'Noun'), ('기술', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('(', 'Punctuation'), ('R', 'Alpha'), (',', 'Punctuation'), ('파이썬', 'Noun'), ('등', 'Noun'), (')', 'Punctuation'), ('(', 'Punctuation'), ('라', 'Josa'), (')', 'Punctuation'), ('KS', 'Alpha'), ('_', 'Punctuation'), ('META', 'Alpha'), ('_', 'Punctuation'), ('DQ', 'Alpha'), ('솔루션', 'Noun'), ('의', 'Josa'), ('고도화', 'Noun'), ('및', 'Noun'), ('유지관리', 'Noun'), ('를', 'Josa'), ('위', 'Noun'), ('한', 'Josa'), ('개발', 'Noun'), ('인력', 'Noun'), ('(', 'Punctuation'), ('마', 'Noun'), (')', 'Punctuation'), ('데이터', 'Noun'), ('관련', 'Noun'), ('자격증', 'Noun'), ('소지', 'Noun'), ('자', 'Suffix'), ('우대', 'Noun'), ('(', 'Punctuation'), ('DAP', 'Alpha'), (',', 'Punctuation'), ('ADP', 'Alpha'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('분석', 'Noun'), ('기사', 'Noun'), (',', 'Punctuation'), ('DQC', 'Alpha'), ('-', 'Punctuation'), ('V', 'Alpha'), ('등', 'Noun'), (')', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('ㆍ', 'Foreign'), ('자동차', 'Noun'), ('데이터', 'Noun'), ('비교', 'Noun'), ('업무', 'Noun'), ('로', 'Josa'), (',', 'Punctuation'), ('자동차', 'Noun'), ('전장', 'Noun'), ('에', 'Josa'), ('대한', 'Noun'), ('이해도', 'Noun'), ('가', 'Josa'), ('있는', 'Adjective'), ('분과', 'Noun'), ('엑셀', 'Noun'), ('등', 'Noun'), ('기본', 'Noun'), ('적', 'Suffix'), ('인', 'Josa'), ('문서', 'Noun'), ('작성', 'Noun'), ('을', 'Josa'), ('할', 'Verb'), ('수', 'Noun'), ('있는', 'Adjective'), ('분', 'Noun'), ('을', 'Josa'), ('모집', 'Noun'), ('하고', 'Josa'), ('있습니다', 'Adjective'), ('.', 'Punctuation'), ('ㆍ', 'Foreign'), ('새로운', 'Adjective'), ('프로젝트', 'Noun'), ('인', 'Josa'), ('만큼', 'Noun'), ('데이터', 'Noun'), ('분석', 'Noun'), ('에', 'Josa'), ('대해', 'Noun'), ('같이', 'Adverb'), ('배우고', 'Verb'), ('업무', 'Noun'), ('에', 'Josa'), ('실행', 'Noun'), ('할', 'Verb'), ('예정', 'Noun'), ('입니다', 'Adjective'), ('.', 'Punctuation'), ('부담', 'Noun'), ('없이', 'Adverb'), ('지원', 'Noun'), ('해', 'Verb'), ('주세요', 'Verb'), ('.', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation'), ('신입', 'Noun'), (':', 'Punctuation'), ('연봉', 'Noun'), ('2,500', 'Number'), ('만원', 'Noun'), ('은', 'Josa'), ('기본', 'Noun'), ('급', 'Suffix'), ('2,280', 'Number'), ('만원', 'Noun'), ('+', 'Punctuation'), ('상여금', 'Noun'), ('과', 'Josa'), ('식대', 'Noun'), ('가', 'Josa'), ('포함', 'Noun'), ('된', 'Verb'), ('금액', 'Noun'), ('입니다', 'Adjective'), ('.', 'Punctuation'), (':', 'Punctuation'), ('인', 'Noun'), ('센티', 'Noun'), ('브', 'Noun'), ('별도', 'Noun'), ('.', 'Punctuation'), ('[', 'Punctuation'), ('인턴', 'Noun'), ('기간', 'Noun'), (':', 'Punctuation'), ('2', 'Number'), ('개월', 'Noun'), ('이내', 'Noun'), ('기본', 'Noun'), ('급', 'Suffix'), ('월', 'Noun'), ('174', 'Number'), ('만원', 'Noun'), (']', 'Punctuation'), ('-', 'Punctuation'), ('경력', 'Noun'), ('직', 'Noun'), (':', 'Punctuation'), ('입찰', 'Noun'), ('경력', 'Noun'), ('있으신', 'Adjective'), ('분', 'Noun'), ('은', 'Josa'), ('상호', 'Noun'), ('협의', 'Noun'), ('가능', 'Noun'), ('ㆍ', 'Foreign'), ('공공기관', 'Noun'), ('전자', 'Noun'), ('입찰', 'Noun'), ('금액', 'Noun'), ('분석', 'Noun'), ('및', 'Noun'), ('원', 'Modifier'), ('격투', 'Noun'), ('찰', 'Noun'), ('.', 'Punctuation'), ('-', 'Punctuation'), ('나라장터', 'Noun'), (',', 'Punctuation'), ('국방부', 'Noun'), (',', 'Punctuation'), ('한전', 'Noun'), ('등', 'Noun'), ('관공서', 'Noun'), ('전자', 'Noun'), ('입찰', 'Noun'), ('발주', 'Noun'), ('공고', 'Noun'), ('분석', 'Noun'), ('업무', 'Noun'), ('및', 'Noun'), ('업체', 'Noun'), ('관리', 'Noun'), ('입니다', 'Adjective'), ('.', 'Punctuation'), ('ㆍ', 'Foreign'), ('전자', 'Noun'), ('입찰', 'Noun'), ('분석', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), ('우대', 'Noun'), ('.', 'Punctuation'), ('-', 'Punctuation'), ('신입', 'Noun'), ('도', 'Josa'), ('충분히', 'Adjective'), ('가능합니다', 'Adjective'), ('.', 'Punctuation'), ('하지만', 'Conjunction'), ('이', 'Determiner'), ('쪽', 'Noun'), ('계통', 'Noun'), ('에서는', 'Josa'), ('영업', 'Noun'), ('직원', 'Noun'), ('들', 'Suffix'), ('은', 'Josa'), ('구인', 'Noun'), ('하', 'Suffix'), ('지만', 'Josa'), ('분석', 'Noun'), ('업무', 'Noun'), ('는', 'Josa'), ('배울', 'Verb'), ('기회', 'Noun'), ('가', 'Josa'), ('없습니다', 'Adjective'), ('.', 'Punctuation'), ('저희', 'Noun'), ('도', 'Josa'), ('경력', 'Noun'), ('직', 'Noun'), ('만', 'Josa'), ('채용', 'Noun'), ('하다가', 'Verb'), ('신입', 'Noun'), ('도', 'Josa'), ('채용', 'Noun'), ('할려고', 'Verb'), ('하는', 'Verb'), ('거니', 'Eomi'), ('많은', 'Adjective'), ('지원', 'Noun'), ('바랍니다', 'Verb'), ('~', 'Punctuation'), ('ㆍ', 'Foreign'), ('인근', 'Noun'), ('거주', 'Noun'), ('자', 'Suffix'), ('ㆍ', 'Foreign'), ('착실하고', 'Adjective'), ('책임감', 'Noun'), ('있는', 'Adjective'), ('분', 'Noun'), ('.', 'Punctuation'), ('ㆍ', 'Foreign'), ('다른', 'Modifier'), ('뭔가', 'Noun'), ('를', 'Josa'), ('찾고', 'Verb'), ('계시는', 'Adjective'), ('분', 'Noun'), ('.', 'Punctuation'), ('ㆍ', 'Foreign'), ('점심', 'Noun'), ('시간', 'Noun'), ('11시', 'Number'), ('45분', 'Number'), ('~', 'Punctuation'), ('13시', 'Number'), ('15분', 'Number'), ('1시간', 'Number'), ('30분', 'Number'), ('으로', 'Foreign'), ('충분한', 'Adjective'), ('휴식', 'Noun'), ('.', 'Punctuation'), ('ㆍ', 'Foreign'), ('월', 'Noun'), ('~', 'Punctuation'), ('금', 'Noun'), ('(', 'Punctuation'), ('주', 'Noun'), ('5일', 'Number'), ('근무', 'Noun'), (')', 'Punctuation'), ('ㆍ', 'Foreign'), ('9시', 'Number'), ('출근', 'Noun'), ('~', 'Punctuation'), ('오후', 'Noun'), ('6시', 'Number'), ('퇴근', 'Noun'), ('(', 'Punctuation'), ('점심시간', 'Noun'), ('1시간', 'Number'), ('30분', 'Number'), ('포함', 'Foreign'), (')', 'Punctuation'), ('ㆍ', 'Foreign'), ('주', 'Noun'), ('5일', 'Number'), ('만', 'Foreign'), ('근무', 'Noun'), ('합니다', 'Verb'), ('.', 'Punctuation'), ('ㆍ', 'Foreign'), ('야근', 'Noun'), ('없고', 'Adjective'), (',', 'Punctuation'), ('주말', 'Noun'), ('근무', 'Noun'), ('없습니다', 'Adjective'), ('.', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('[', 'Punctuation'), ('모집', 'Noun'), ('부문', 'Noun'), ('및', 'Noun'), ('상세', 'Noun'), ('내용', 'Noun'), (']', 'Punctuation'), ('-', 'Punctuation'), ('공통', 'Noun'), ('자격', 'Noun'), ('요건', 'Noun'), ('ㆍ', 'Foreign'), ('학력', 'Noun'), (':', 'Punctuation'), ('대졸', 'Noun'), ('이상', 'Noun'), ('(', 'Punctuation'), ('2', 'Number'), (',', 'Punctuation'), ('3년', 'Number'), (')', 'Punctuation'), ('[', 'Punctuation'), ('Database', 'Alpha'), ('기술', 'Noun'), ('엔지니어', 'Noun'), ('신입', 'Noun'), ('및', 'Noun'), ('경력', 'Noun'), ('직', 'Noun'), ('채용', 'Noun'), ('\t ', 'Foreign'), ('2', 'Number'), ('명', 'Noun'), (']', 'Punctuation'), ('-', 'Punctuation'), ('지원', 'Noun'), ('자격', 'Noun'), ('ㆍ', 'Foreign'), ('경력', 'Noun'), (':', 'Punctuation'), ('신입', 'Noun'), ('/', 'Punctuation'), ('경력', 'Noun'), ('2년', 'Number'), ('~', 'Punctuation'), ('5년', 'Number'), ('(', 'Punctuation'), ('면접', 'Noun'), ('후', 'Noun'), ('결정', 'Noun'), (')', 'Punctuation'), ('ㆍ', 'Foreign'), ('관계', 'Noun'), ('형', 'Suffix'), ('데이터베이스', 'Noun'), ('구축', 'Noun'), ('경험', 'Noun'), ('ㆍ', 'Foreign'), ('DBMS', 'Alpha'), ('운영', 'Noun'), ('및', 'Noun'), ('장애', 'Noun'), ('대응', 'Noun'), ('ㆍ', 'Foreign'), ('운영체제', 'Noun'), ('및', 'Noun'), ('네트워크', 'Noun'), ('에', 'Josa'), ('대한', 'Noun'), ('이해도', 'Noun'), ('-', 'Punctuation'), ('우대', 'Noun'), ('사항', 'Noun'), ('ㆍ', 'Foreign'), ('공학', 'Noun'), ('계열', 'Noun'), (',', 'Punctuation'), ('관련', 'Noun'), ('학과', 'Noun'), ('(', 'Punctuation'), ('전산학', 'Noun'), ('과', 'Josa'), (')', 'Punctuation'), ('졸업', 'Noun'), ('자', 'Suffix'), ('ㆍ', 'Foreign'), ('SQL', 'Alpha'), ('숙련', 'Noun'), ('자', 'Suffix'), ('ㆍ', 'Foreign'), ('관련', 'Noun'), ('인증', 'Noun'), ('자격', 'Noun'), ('소지', 'Noun'), ('자', 'Suffix'), ('ㆍ', 'Foreign'), ('해당', 'Noun'), ('직무', 'Noun'), ('근무', 'Noun'), ('경험', 'Noun'), ('-', 'Punctuation'), ('복리', 'Noun'), ('후생', 'Noun'), ('ㆍ', 'Foreign'), ('건강', 'Noun'), ('보험', 'Noun'), (',', 'Punctuation'), ('국민연금', 'Noun'), (',', 'Punctuation'), ('산재', 'Noun'), ('보험', 'Noun'), (',', 'Punctuation'), ('고용보', 'Noun'), ('혐', 'Noun'), ('등', 'Noun'), ('ㆍ', 'Foreign'), ('정기', 'Noun'), ('휴가', 'Noun'), ('및', 'Noun'), ('연차', 'Noun'), ('사용', 'Noun'), ('관리', 'Noun'), ('ㆍ', 'Foreign'), ('경', 'Modifier'), ('조', 'Modifier'), ('사비', 'Noun'), ('지원', 'Noun'), ('ㆍ', 'Foreign'), ('근무시간', 'Noun'), ('및', 'Noun'), ('장소', 'Noun'), ('유연성', 'Noun'), ('제공', 'Noun'), ('ㆍ', 'Foreign'), ('업무', 'Noun'), ('관련', 'Noun'), ('교육', 'Noun'), ('및', 'Noun'), ('세미나', 'Noun'), ('참석', 'Noun'), ('기회', 'Noun'), ('제공', 'Noun'), ('ㆍ', 'Foreign'), ('사내', 'Noun'), ('우수', 'Noun'), ('인원', 'Noun'), ('에', 'Josa'), ('대한', 'Noun'), ('승진', 'Noun'), ('및', 'Noun'), ('연봉', 'Noun'), ('인상', 'Noun'), ('기회', 'Noun'), ('-', 'Punctuation'), ('근', 'Modifier'), ('무조건', 'Noun'), ('ㆍ', 'Foreign'), ('\t', 'Foreign'), ('근무', 'Noun'), ('형태', 'Noun'), ('\t', 'Foreign'), (':', 'Punctuation'), ('\t', 'Foreign'), ('정규직', 'Noun'), ('(', 'Punctuation'), ('수습', 'Noun'), ('기간', 'Noun'), (')-', 'Punctuation'), ('3', 'Number'), ('개월', 'Noun'), ('ㆍ', 'Foreign'), ('\t', 'Foreign'), ('근무', 'Noun'), ('지역', 'Noun'), ('\t', 'Foreign'), (':', 'Punctuation'), ('\t', 'Foreign'), ('(', 'Punctuation'), ('06083', 'Number'), (')', 'Punctuation'), ('서울', 'Noun'), ('강남구', 'Noun'), ('영동대로', 'Noun'), ('602', 'Number'), (',', 'Punctuation'), ('E', 'Alpha'), ('동', 'Modifier'), ('6', 'Number'), ('층', 'Noun'), ('205', 'Number'), ('호', 'Noun'), ('-', 'Punctuation'), ('서울', 'Noun'), ('9', 'Number'), ('호선', 'Noun'), ('봉은사', 'Noun'), ('에서', 'Josa'), ('100', 'Number'), ('m', 'Alpha'), ('이내', 'Noun'), ('[', 'Punctuation'), ('전형', 'Noun'), ('절차', 'Noun'), (']', 'Punctuation'), ('-', 'Punctuation'), ('서류', 'Noun'), ('전형', 'Noun'), ('1', 'Number'), ('차', 'Noun'), ('면접', 'Noun'), ('-', 'Punctuation'), ('최종', 'Noun'), ('합격', 'Noun'), ('유의사항', 'Noun'), ('ㆍ', 'Foreign'), ('입사', 'Noun'), ('지원', 'Noun'), ('서류', 'Noun'), ('에', 'Josa'), ('허위', 'Noun'), ('사실', 'Noun'), ('이', 'Josa'), ('발견', 'Noun'), ('될', 'Verb'), ('경우', 'Noun'), (',', 'Punctuation'), ('채용', 'Noun'), ('확정', 'Noun'), ('이후', 'Nou ...
# --------------------------------------------------------------------------------
# [('-', 'Punctuation'), ('데이터', 'Noun'), ('모델링', 'Noun'), ('표준', 'Noun'), ('정의', 'Noun'), ('및', 'Noun'), ('인', 'Noun'), ('스펙', 'Noun'), ('션', 'Noun'), ('수행', 'Noun'), ('-', 'Punctuation'), ('데이터', 'Noun'), ('관리', 'Noun'), ('체계', 'Noun'), ('수립', 'Noun'), ('및', 'Noun'), ('검토', 'Noun'), ('수행', 'Noun'), ('-', 'Punctuation'), ('데이터베이스', 'Noun'), ('아키텍처', 'Noun'), ('설계', 'Noun'), ('및', 'Noun'), ('검토', 'Noun'), ('수행', 'Noun'), ('-', 'Punctuation'), ('데이터베이스', 'Noun'), ('아', 'Exclamation'), ('카이', 'Noun'), ('빙', 'Noun'), ('정책', 'Noun'), ('수립', 'Noun'), ('및', 'Noun'), ('검토', 'Noun'), ('-', 'Punctuation'), ('메타데이터', 'Noun'), ('표준화', 'Noun'), ('수행', 'Noun'), ('-', 'Punctuation'), ('성능', 'Noun'), ('개선', 'Noun'), ('및', 'Noun'), ('튜닝', 'Noun'), ('정책', 'Noun'), ('/', 'Punctuation'), ('가이드', 'Noun'), ('관리', 'Noun'), ('-', 'Punctuation'), ('프로젝트', 'Noun'), ('기획', 'Noun'), ('및', 'Noun'), ('구축', 'Noun'), ('수행', 'Noun')]
# --------------------------------------------------------------------------------
# [('※', 'Foreign'), ('YOLO', 'Alpha'), ('기반', 'Noun'), ('이미지', 'Noun'), ('/', 'Punctuation'), ('영상', 'Noun'), ('실시간', 'Noun'), ('분석', 'Noun'), (',', 'Punctuation'), ('AIoT', 'Alpha'), ('융합', 'Noun'), ('기술', 'Noun'), ('개발', 'Noun'), ('[', 'Punctuation'), ('빅데이터', 'Noun'), ('플랫폼', 'Noun'), ('구축', 'Noun'), ('>', 'Punctuation'), ('빅데이터', 'Noun'), ('플랫폼', 'Noun'), ('아키텍처', 'Noun'), ('설계', 'Noun'), (']', 'Punctuation'), ('빅데이터', 'Noun'), ('플랫폼', 'Noun'), ('인프라', 'Noun'), ('구조', 'Noun'), ('설계', 'Noun'), ('하기', 'Verb'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('입출력', 'Noun'), ('구조', 'Noun'), ('설계', 'Noun'), ('하기', 'Verb'), ('[', 'Punctuation'), ('빅데이터', 'Noun'), ('플랫폼', 'Noun'), ('구축', 'Noun'), ('>', 'Punctuation'), ('빅데이터', 'Noun'), ('수집', 'Noun'), ('시스템', 'Noun'), ('개발', 'Noun'), (']', 'Punctuation'), ('빅데이터', 'Noun'), ('수집', 'Noun'), ('시스템', 'Noun'), ('설계', 'Noun'), ('하기', 'Verb'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('수집', 'Noun'), ('시스템', 'Noun'), ('구성', 'Noun'), ('하기', 'Verb'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('수집', 'Noun'), ('·', 'Punctuation'), ('변환', 'Noun'), ('모듈', 'Noun'), ('개발', 'Noun'), ('하기', 'Verb'), (',', 'Punctuation'), ('수집', 'Noun'), ('데이터', 'Noun'), ('검증', 'Noun'), ('모듈', 'Noun'), ('개발', 'Noun'), ('하기', 'Verb'), ('[', 'Punctuation'), ('빅데이터', 'Noun'), ('플랫폼', 'Noun'), ('구축', 'Noun'), ('>', 'Punctuation'), ('빅데이터', 'Noun'), ('분석', 'Noun'), ('시스템', 'Noun'), ('개발', 'Noun'), (']', 'Punctuation'), ('빅데이터', 'Noun'), ('분석', 'Noun'), ('시스템', 'Noun'), ('설계', 'Noun'), ('하기', 'Verb'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('분석', 'Noun'), ('시스템', 'Noun'), ('구성', 'Noun'), ('하기', 'Verb'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('분석', 'Noun'), ('모듈', 'Noun'), ('개발', 'Noun'), ('하기', 'Verb'), ('[', 'Punctuation'), ('빅데이터', 'Noun'), ('플랫폼', 'Noun'), ('구축', 'Noun'), ('>', 'Punctuation'), ('빅데이터', 'Noun'), ('플랫폼', 'Noun'), ('테스트', 'Noun'), (']', 'Punctuation'), ('빅데이터', 'Noun'), ('플랫폼', 'Noun'), ('테스트', 'Noun'), ('설계', 'Noun'), ('하기', 'Verb'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('플랫폼', 'Noun'), ('기능', 'Noun'), ('테스트', 'Noun'), ('하기', 'Verb'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('플랫폼', 'Noun'), ('비', 'Noun'), ('기능', 'Noun'), ('테스트', 'Noun'), ('하기', 'Verb')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation'), ('SQL', 'Alpha'), ('을', 'Josa'), ('사용', 'Noun'), ('한', 'Josa'), ('데이터', 'Noun'), ('추출', 'Noun'), ('및', 'Noun'), ('전', 'Modifier'), ('처리', 'Noun'), ('를', 'Josa'), ('통한', 'Noun'), ('지표', 'Noun'), ('관리', 'Noun'), ('-', 'Punctuation'), ('데이터', 'Noun'), ('시각', 'Noun'), ('화', 'Suffix'), ('및', 'Noun'), ('대시보드', 'Noun'), ('(', 'Punctuation'), ('Tableau', 'Alpha'), ('등', 'Noun'), (')', 'Punctuation'), ('제작', 'Noun'), ('및', 'Noun'), ('운영', 'Noun'), ('-', 'Punctuation'), ('분석', 'Noun'), ('요건', 'Noun'), ('기획', 'Noun'), ('및', 'Noun'), ('데이터', 'Noun'), ('수집', 'Noun'), ('관리', 'Noun'), ('-', 'Punctuation'), ('데이터', 'Noun'), ('에', 'Josa'), ('기반', 'Noun'), ('한', 'Josa'), ('가설', 'Noun'), ('수립', 'Noun'), ('및', 'Noun'), ('검증', 'Noun'), ('-', 'Punctuation'), ('각종', 'Noun'), ('지표', 'Noun'), ('정의', 'Noun'), ('및', 'Noun'), ('트래킹', 'Noun'), ('자동화', 'Noun')]
# --------------------------------------------------------------------------------
# [('<', 'Punctuation'), ('모집', 'Noun'), ('분야', 'Noun'), ('>', 'Punctuation'), ('Bioinformatics', 'Alpha'), ('(', 'Punctuation'), ('생물정보학', 'Noun'), (')', 'Punctuation'), ('데이터', 'Noun'), ('처리', 'Noun'), ('및', 'Noun'), ('분석', 'Noun'), ('<', 'Punctuation'), ('담당', 'Noun'), ('업무', 'Noun'), ('>', 'Punctuation'), ('암', 'Noun'), ('유전체', 'Noun'), (',', 'Punctuation'), ('전사체', 'Noun'), (',', 'Punctuation'), ('단백체', 'Noun'), (',', 'Punctuation'), ('대사체', 'Noun'), ('등', 'Noun'), ('공공', 'Noun'), ('팬', 'Noun'), ('오믹스', 'Noun'), ('데이터', 'Noun'), ('확보', 'Noun'), ('암', 'Noun'), ('팬', 'Noun'), ('오믹스', 'Noun'), ('데이터', 'Noun'), ('처리', 'Noun'), ('파이프라인', 'Noun'), ('구축', 'Noun'), ('및', 'Noun'), ('최적화', 'Noun'), ('암', 'Noun'), ('팬', 'Noun'), ('오믹스', 'Noun'), ('데이터', 'Noun'), ('모델링', 'Noun'), ('을', 'Josa'), ('통한', 'Noun'), ('신규', 'Noun'), ('바이오', 'Noun'), ('마커', 'Adverb'), ('발굴', 'Noun'), ('및', 'Noun'), ('치료', 'Noun'), ('내', 'Determiner'), ('성', 'Noun'), ('기전', 'Noun'), ('규명', 'Noun'), ('<', 'Punctuation'), ('공통', 'Noun'), ('자격', 'Noun'), ('요건', 'Noun'), ('>', 'Punctuation'), ('생물정보학', 'Noun'), (',', 'Punctuation'), ('유전학', 'Noun'), (',', 'Punctuation'), ('컴퓨터공학', 'Noun'), ('및', 'Noun'), ('유사', 'Noun'), ('학문', 'Noun'), ('전공자', 'Noun'), ('Python', 'Alpha'), (',', 'Punctuation'), ('R', 'Alpha'), (',', 'Punctuation'), ('MATLAB', 'Alpha'), ('및', 'Noun'), ('기타', 'Noun'), ('프로그래밍', 'Noun'), ('언어', 'Noun'), ('를', 'Josa'), ('활용', 'Noun'), ('한', 'Josa'), ('유전체', 'Noun'), ('분석', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), ('<', 'Punctuation'), ('개별', 'Noun'), ('자격', 'Noun'), ('요건', 'Noun'), ('>', 'Punctuation'), ('책임', 'Noun'), ('급', 'Suffix'), ('–', 'Foreign'), ('연봉', 'Noun'), ('6,000', 'Number'), ('~', 'Punctuation'), ('8,000만원', 'Number'), ('박사', 'Noun'), ('이상', 'Noun'), ('및', 'Noun'), ('동', 'Modifier'), ('종업', 'Noun'), ('계', 'Suffix'), ('경력', 'Noun'), ('6년', 'Number'), ('이상', 'Noun'), ('선임', 'Noun'), ('급', 'Suffix'), ('–', 'Foreign'), ('연봉', 'Noun'), ('4,000', 'Number'), ('~', 'Punctuation'), ('6,000만원', 'Number'), ('석사', 'Noun'), ('이상', 'Noun'), ('및', 'Noun'), ('동', 'Modifier'), ('종업', 'Noun'), ('계', 'Suffix'), ('경력', 'Noun'), ('2년', 'Number'), ('이상', 'Noun'), ('<', 'Punctuation'), ('우대', 'Noun'), ('사항', 'Noun'), ('>', 'Punctuation'), ('NGS', 'Alpha'), ('(', 'Punctuation'), ('Next', 'Alpha'), ('-', 'Punctuation'), ('Generation', 'Alpha'), ('Sequencing', 'Alpha'), (')', 'Punctuation'), ('데이터', 'Noun'), ('처리', 'Noun'), ('및', 'Noun'), ('분석', 'Noun'), ('유', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), ('Mass', 'Alpha'), ('spectrometry', 'Alpha'), ('데이터', 'Noun'), ('처리', 'Noun'), ('및', 'Noun'), ('분석', 'Noun'), ('유', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), ('암', 'Modifier'), ('유전체', 'Noun'), ('포함', 'Noun'), ('한', 'Josa'), ('관련', 'Noun'), ('연구', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), ('<', 'Punctuation'), ('근무', 'Noun'), ('환경', 'Noun'), ('>', 'Punctuation'), ('근무', 'Noun'), ('지역', 'Noun'), (':', 'Punctuation'), ('서울시', 'Noun'), ('서초구', 'Noun'), ('태봉로', 'Noun'), ('114', 'Number'), (',', 'Punctuation'), ('AI', 'Alpha'), ('양재', 'Noun'), ('허브', 'Noun'), ('807', 'Number'), ('호', 'Noun'), ('근무시간', 'Noun'), (':', 'Punctuation'), ('오전', 'Noun'), ('9시', 'Number'), ('~', 'Punctuation'), ('오후', 'Noun'), ('6시', 'Number'), ('(', 'Punctuation'), ('휴게', 'Noun'), ('시간', 'Noun'), ('1시간', 'Number'), (')', 'Punctuation'), ('<', 'Punctuation'), ('복리', 'Noun'), ('후생', 'Noun'), ('>', 'Punctuation'), ('자율', 'Noun'), ('복장', 'Noun'), ('자유로운', 'Adjective'), ('연차', 'Noun'), ('/', 'Punctuation'), ('반', 'Modifier'), ('차', 'Noun'), ('사용', 'Noun'), ('식대', 'Noun'), ('지원', 'Noun'), ('구내식당', 'Noun'), ('이용', 'Noun'), ('가능', 'Noun'), ('사내', 'Noun'), ('카페테리아', 'Noun'), ('이용', 'Noun'), ('가능', 'Noun'), ('직무', 'Noun'), ('관련', 'Noun'), ('자기계발', 'Noun'), ('비', 'Noun'), ('지원', 'Noun'), ('근로자', 'Noun'), ('여름', 'Noun'), ('휴가', 'Noun'), ('비', 'Noun'), ('지원', 'Noun'), ('경조사', 'Noun'), ('지원', 'Noun'), ('제도', 'Noun'), ('명절', 'Noun'), ('선물', 'Noun'), ('제공', 'Noun'), ('출산전후', 'Noun'), ('휴가', 'Noun'), (',', 'Pu ...
# --------------------------------------------------------------------------------
# [('데이터', 'Noun'), ('엔지니어링', 'Noun'), (':', 'Punctuation'), ('데이터', 'Noun'), ('의', 'Josa'), ('수집', 'Noun'), ('/', 'Punctuation'), ('가공', 'Noun'), ('/', 'Punctuation'), ('적재', 'Noun'), ('및', 'Noun'), ('pipeline', 'Alpha'), ('관리', 'Noun')]
# --------------------------------------------------------------------------------
# [('▶', 'Foreign'), ('자금세탁', 'Noun'), ('방지', 'Noun'), ('(', 'Punctuation'), ('AML', 'Alpha'), (')', 'Punctuation'), ('데이터', 'Noun'), ('분석', 'Noun'), ('–', 'Foreign'), ('거래', 'Noun'), ('모니터링', 'Noun'), ('시스템', 'Noun'), ('검증', 'Noun'), (',', 'Punctuation'), ('룰', 'Noun'), ('최적화', 'Noun'), (',', 'Punctuation'), ('STR', 'Alpha'), ('/', 'Punctuation'), ('CTR', 'Alpha'), ('데이터', 'Noun'), ('검증', 'Noun'), (',', 'Punctuation'), ('위험', 'Noun'), ('평가', 'Noun'), ('모델링', 'Noun'), ('▶', 'Foreign'), ('컴플라이언스', 'Noun'), ('업무', 'Noun'), ('프로세스', 'Noun'), ('및', 'Noun'), ('화면', 'Noun'), ('설계', 'Noun'), (',', 'Punctuation'), ('데이터', 'Noun'), ('및', 'Noun'), ('IT', 'Alpha'), ('개발', 'Noun'), ('요건', 'Noun'), ('정의', 'Noun'), ('-', 'Punctuation'), ('금융', 'Noun'), ('정보', 'Noun'), ('자동', 'Noun'), ('교환', 'Noun'), ('(', 'Punctuation'), ('FATCA', 'Alpha'), ('/', 'Punctuation'), ('CRS', 'Alpha'), (')', 'Punctuation'), ('시스템', 'Noun'), ('-', 'Punctuation'), ('금융기관', 'Noun'), ('내부통제', 'Noun'), ('시스템', 'Noun'), ('-', 'Punctuation'), ('금융기관', 'Noun'), ('이', 'Determiner'), ('상거래', 'Noun'), ('탐지', 'Noun'), ('(', 'Punctuation'), ('FDS', 'Alpha'), (')', 'Punctuation'), ('시스템', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('Position', 'Alpha'), ('•', 'Foreign'), ('\t', 'Foreign'), ('소속', 'Noun'), (':', 'Punctuation'), ('전략기획', 'Noun'), ('팀', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('직위', 'Noun'), (':', 'Punctuation'), ('협의', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('연봉', 'Noun'), (':', 'Punctuation'), ('협의', 'Noun'), ('Job', 'Alpha'), ('Description', 'Alpha'), ('•', 'Foreign'), ('\t', 'Foreign'), ('빅데이터', 'Noun'), ('를', 'Josa'), ('이용', 'Noun'), ('한', 'Josa'), ('데이터', 'Noun'), ('관리', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('비즈니스', 'Noun'), ('프로젝트', 'Noun'), ('관리', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('비즈니스', 'Noun'), ('중', 'Noun'), (',', 'Punctuation'), ('장기', 'Noun'), ('전략', 'Noun'), ('수립', 'Noun'), ('및', 'Noun'), ('실행', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('브랜드', 'Noun'), ('및', 'Noun'), ('제품', 'Noun'), ('캠페인', 'Noun'), ('관리', 'Noun'), ('지원', 'Noun'), ('자격', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('화장품', 'Noun'), ('외', 'Noun'), ('다양한', 'Adjective'), ('산업', 'Noun'), ('계', 'Suffix'), ('경험', 'Noun'), ('보유', 'Noun'), ('하신', 'Verb'), ('분', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('마케팅', 'Noun'), ('관련', 'Noun'), ('업무', 'Noun'), ('경험', 'Noun'), ('있으신', 'Adjective'), ('분', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('다양한', 'Adjective'), ('프로젝트', 'Noun'), ('의', 'Josa'), ('PM', 'Alpha'), ('경험', 'Noun'), ('있으신', 'Adjective'), ('분', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('빅데이터', 'Noun'), ('를', 'Josa'), ('이용', 'Noun'), ('한', 'Josa'), ('전략', 'Noun'), ('기획', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), ('•', 'Foreign'), ('\t', 'Foreign'), ('데이터', 'Noun'), ('활용', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), ('우대', 'Noun'), ('사항', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('다양한', 'Adjective'), ('업종', 'Noun'), ('관련', 'Noun'), ('경력', 'Noun'), ('우대', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('외국어', 'Noun'), ('(', 'Punctuation'), ('영어', 'Noun'), ('/', 'Punctuation'), ('중국어', 'Noun'), ('/', 'Punctuation'), ('일본어', 'Noun'), (')', 'Punctuation'), ('능통', 'Noun'), ('자', 'Suffix'), ('우대', 'Noun'), ('근', 'Modifier'), ('무조건', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('근무', 'Noun'), ('형태', 'Noun'), (':', 'Punctuation'), ('정규직', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('근무', 'Noun'), ('일시', 'Noun'), (':', 'Punctuation'), ('주', 'Noun'), ('5일', 'Number'), ('(', 'Punctuation'), ('월', 'Noun'), ('~', 'Punctuation'), ('금', 'Noun'), (')', 'Punctuation'), ('•', 'Foreign'), ('\t', 'Foreign'), ('근무시간', 'Noun'), (':', 'Punctuation'), ('오전', 'Noun'), ('9시', 'Number'), ('~', 'Punctuation'), ('6시', 'Number'), ('(', 'Punctuation'), ('월', 'Noun'), ('~', 'Punctuation'), ('금', 'Noun'), (')', 'Punctuation'), ('•', 'Foreign'), ('\t', 'Foreign'), ('급여', 'Noun'), (':', 'Punctuation'), ('협의', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('근무', 'Noun'), ('지역', 'Noun'), (':', 'Punctuation'), ('서울', 'Noun'), ('강남구', 'Noun'), ('-', 'Punctuation'), ('서울', 'Noun'), ('7', 'Number'), ('호선', 'Noun'), ('강남구청역', 'Noun'), ('에서', 'Josa'), ('50', 'Number'), ('m', 'Alpha'), ('이내', 'Noun'), ('•', 'Foreign'), ('\t', 'Foreign'), ('복리', 'Noun'), ('후생', 'Noun'), (':', 'Punctuation'), ('4', 'Number'), ('대', 'Modifier'), ('보험', 'Noun'), (',', 'Punctuation'), ('건강검진', 'Noun'), (',', 'Punctuation'), ('생일', 'Noun'), ('휴가', 'Noun'), (',', 'Punctuation'), ('문화', 'Noun'), ('회식', 'Noun'), ('(', 'Punctuation'), ('월', 'Noun'), ('1회', 'Number'), ('전시회', 'Noun'), ('관람', 'Noun'), ('),', 'Punctuation'), ('간식', 'Noun'), ('외', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('네트워크', 'Noun'), ('/', 'Punctuation'), ('서버', 'Noun'), ('/', 'Punctuation'), ('보안', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('웹', 'Noun'), ('개발', 'Noun'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('웹', 'Noun'), ('기획', 'Noun'), ('/', 'Punctuation'), ('PM', 'Alpha'), ('/', 'Punctuation'), ('웹마케팅', 'Noun'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation'), ('데이터', 'Noun'), ('구축', 'Noun'), ('-', 'Punctuation'), ('이미지', 'Noun'), ('데이터', 'Noun'), ('라', 'Josa'), ('벨링', 'Noun'), ('(', 'Punctuation'), ('폴리곤', 'Noun'), ('/', 'Punctuation'), ('비', 'Noun'), ('박스', 'Noun'), (')', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('무관', 'Noun'), ('-', 'Punctuation'), ('AI', 'Alpha'), ('/', 'Punctuation'), ('빅데이터', 'Noun'), ('-', 'Punctuation'), ('데이터', 'Noun'), ('라', 'Josa'), ('벨링', 'Noun'), ('-', 'Punctuation'), ('서울', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation'), ('AI', 'Alpha'), ('/', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('클라우드', 'Noun'), ('인프라', 'Noun'), ('클러스터', 'Noun'), ('구성', 'Noun'), ('및', 'Noun'), ('운영', 'Noun'), ('-', 'Punctuation'), ('AI', 'Alpha'), ('/', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('클라우드', 'Noun'), ('아키텍처', 'Noun'), ('설계', 'Noun'), ('및', 'Noun'), ('구축', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation'), ('AI', 'Alpha'), ('/', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('클라우드', 'Noun'), ('관련', 'Noun'), ('비즈니스', 'Noun'), ('모델', 'Noun'), ('발굴', 'Noun'), ('-', 'Punctuation'), ('AI', 'Alpha'), ('/', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('클라우드', 'Noun'), ('과제', 'Noun'), ('관리', 'Noun'), ('및', 'Noun'), ('팀', 'Noun'), ('운영', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('설문', 'Noun'), ('/', 'Punctuation'), ('통계', 'Noun'), ('/', 'Punctuation'), ('리서치', 'Noun'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('설문', 'Noun'), ('/', 'Punctuation'), ('통계', 'Noun'), ('/', 'Punctuation'), ('리서치', 'Noun'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('기획', 'Noun'), ('/', 'Punctuation'), ('전략', 'Noun'), ('/', 'Punctuation'), ('경영', 'Noun'), (',', 'Punctuation'), ('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('DBA', 'Alpha'), ('/', 'Punctuation'), ('데이터베이스', 'Noun')]
# --------------------------------------------------------------------------------
# ...
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('ㆍ', 'Foreign'), ('접수', 'Noun'), ('기간', 'Noun'), (':', 'Punctuation'), ('2024년', 'Number'), ('2월', 'Number'), ('6일', 'Number'), ('(', 'Punctuation'), ('화', 'Noun'), (')', 'Punctuation'), ('17시', 'Number'), ('~', 'Punctuation'), ('2024년', 'Number'), ('4월', 'Number'), ('6일', 'Number'), ('(', 'Punctuation'), ('토', 'Noun'), (')', 'Punctuation'), ('24시', 'Number'), ('ㆍ', 'Foreign'), ('접수', 'Noun'), ('방법', 'Noun'), (':', 'Punctuation'), ('사람인', 'Noun'), ('입사', 'Noun'), ('지원', 'Noun'), ('ㆍ', 'Foreign'), ('이력서', 'Noun'), ('양식', 'Noun'), (':', 'Punctuation'), ('사람인', 'Noun'), ('온라인', 'Noun'), ('이력서', 'Noun'), ('ㆍ', 'Foreign'), ('제출', 'Noun'), ('서류', 'Noun'), (':·', 'Punctuation'), ('(', 'Punctuation'), ('필수', 'Noun'), (')', 'Punctuation'), ('입사', 'Noun'), ('지원', 'Noun'), ('서', 'Josa'), ('(', 'Punctuation'), ('자기', 'Noun'), ('소개', 'Noun'), (',', 'Punctuation'), ('학력', 'Noun'), ('/', 'Punctuation'), ('경력', 'Noun'), ('소개', 'Noun'), ('내용', 'Noun'), ('등', 'Noun'), ('포함', 'Noun'), (')', 'Punctuation'), ('\n', 'Foreign'), ('·', 'Punctuation'), ('(', 'Punctuation'), ('필수', 'Noun'), (')', 'Punctuation'), ('대학교', 'Noun'), (',', 'Punctuation'), ('대학원', 'Noun'), ('성적표', 'Noun'), ('및', 'Noun'), ('졸업', 'Noun'), ('증명서', 'Noun'), ('\n', 'Foreign'), ('·', 'Punctuation'), ('(', 'Punctuation'), ('선택', 'Noun'), ('/', 'Punctuation'), ('우대', 'Noun'), (')', 'Punctuation'), ('프로젝트', 'Noun'), ('산출', 'Noun'), ('물', 'Noun'), ('또는', 'Adverb'), ('포트폴리오', 'Noun'), ('(', 'Punctuation'), ('개발', 'Noun'), ('및', 'Noun'), ('분석', 'Noun'), ('프로젝트', 'Noun'), ('의', 'Josa'), ('경우', 'Noun'), ('코드', 'Noun'), ('제출', 'Noun'), ('필수', 'Noun'), (')', 'Punctuation'), ('\n', 'Foreign'), ('·', 'Punctuation'), ('(', 'Punctuation'), ('선택', 'Noun'), ('/', 'Punctuation'), ('우대', 'Noun'), (')', 'Punctuation'), ('석사', 'Noun'), ('학위', 'Noun'), ('이상자', 'Noun'), ('는', 'Josa'), ('졸업', 'Noun'), ('논문', 'Noun'), ('\n', 'Foreign'), ('·', 'Punctuation'), ('필수', 'Noun'), ('서류', 'Noun'), ('미', 'Adjective'), ('제출', 'Noun'), ('시', 'Noun'), ('서류', 'Noun'), ('탈락', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('모집', 'Noun'), ('부문', 'Noun'), ('상', 'Suffix'), ('세', 'Modifier'), ('내용', 'Noun'), ('공통', 'Noun'), ('자격', 'Noun'), ('요건', 'Noun'), ('ㆍ', 'Foreign'), ('학력', 'Noun'), (':', 'Punctuation'), ('무관', 'Noun'), ('보안', 'Noun'), (',', 'Punctuation'), ('네트워크', 'Noun'), ('영업', 'Noun'), ('영업', 'Noun'), ('2', 'Number'), ('팀', 'Noun'), ('1', 'Number'), ('명담', 'Noun'), ('당', 'Modifier'), ('업무', 'Noun'), ('ㆍ', 'Foreign'), ('지원', 'Noun'), ('자격', 'Noun'), ('ㆍ', 'Foreign'), ('경력', 'Noun'), (':', 'Punctuation'), ('경력', 'Noun'), ('(', 'Punctuation'), ('년', 'Noun'), ('수', 'Modifier'), ('무관', 'Noun'), (')(', 'Punctuation'), ('사원', 'Noun'), (',', 'Punctuation'), ('대리', 'Noun'), (',', 'Punctuation'), ('과장', 'Noun'), ('급', 'Suffix'), (')', 'Punctuation'), ('\n            ', 'Foreign'), ('ㆍ', 'Foreign'), ('기타', 'Noun'), ('필수', 'Noun'), ('사항', 'Noun'), ('\n        ', 'Foreign'), ('우대', 'Noun'), ('사항', 'Noun'), ('ㆍ', 'Foreign'), ('2', 'Number'), ('종', 'Noun'), ('소형', 'Noun'), ('운전면허', 'Noun'), ('ㆍ', 'Foreign'), ('해당', 'Noun'), ('직무', 'Noun'), ('근무', 'Noun'), ('경험', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('공통', 'Noun'), ('자격', 'Noun'), ('요건', 'Noun'), ('ㆍ', 'Foreign'), ('학력', 'Noun'), (':', 'Punctuation'), ('무관', 'Noun'), ('AI', 'Alpha'), ('데이터', 'Noun'), ('가공', 'Noun'), ('및', 'Noun'), ('검수', 'Noun'), ('계약', 'Noun'), ('직', 'Noun'), ('시험', 'Noun'), ('평가', 'Noun'), ('연구소', 'Noun'), ('3', 'Number'), ('명담', 'Noun'), ('당', 'Modifier'), ('업무', 'Noun'), ('ㆍ', 'Foreign'), ('지원', 'Noun'), ('자격', 'Noun'), ('ㆍ', 'Foreign'), ('경력', 'Noun'), (':', 'Punctuation'), ('경력', 'Noun'), ('1년', 'Number'), ('이상', 'Noun'), ('(', 'Punctuation'), ('연구원', 'Noun'), (',', 'Punctuation'), ('선임', 'Noun'), ('연구원', 'Noun'), ('급', 'Suffix'), (')', 'Punctuation'), ('ㆍ', 'Foreign'), ('수행', 'Noun'), ('업무', 'Noun'), (':', 'Punctuation'), ('AI', 'Alpha'), ('학습', 'Noun'), ('용', 'Noun'), ('데이터', 'Noun'), ('가공', 'Noun'), ('보조', 'Noun'), ('및', 'Noun'), ('검수', 'Noun'), ('\n            ', 'Foreign'), ('ㆍ', 'Foreign'), ('기타', 'Noun'), ('필수', 'Noun'), ('사항', 'Noun'), ('\n        ', 'Foreign'), ('우대', 'Noun'), ('사항', 'Noun'), ('ㆍ', 'Foreign'), ('인근', 'Noun'), ('거주', 'Noun'), ('자', 'Suffix'), (',', 'Punctuation'), ('해당', 'Noun'), ('직무', 'Noun'), ('근무', 'Noun'), ('경험', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('모집', 'Noun'), ('부문', 'Noun'), ('상', 'Suffix'), ('세', 'Modifier'), ('내용', 'Noun'), ('공통', 'Noun'), ('자격', 'Noun'), ('요건', 'Noun'), ('ㆍ', 'Foreign'), ('학력', 'Noun'), (':', 'Punctuation'), ('대졸', 'Noun'), ('이상', 'Noun'), ('응용', 'Noun'), ('/', 'Punctuation'), ('웹', 'Noun'), ('프로그램', 'Noun'), ('/', 'Punctuation'), ('데이터베이스', 'Noun'), ('개발', 'Noun'), ('0', 'Number'), ('명담', 'Noun'), ('당', 'Modifier'), ('업무', 'Noun'), ('ㆍ', 'Foreign'), ('지원', 'Noun'), ('자격', 'Noun'), ('ㆍ', 'Foreign'), ('경력', 'Noun'), (':', 'Punctuation'), ('신입', 'Noun'), ('\xa0', 'Foreign'), ('(', 'Punctuation'), ('연구원', 'Noun'), (')', 'Punctuation'), ('\n            ', 'Foreign'), ('ㆍ', 'Foreign'), ('기타', 'Noun'), ('필수', 'Noun'), ('사항', 'Noun'), ('\n        ', 'Foreign'), ('담당', 'Noun'), ('업무', 'Noun'), ('ㆍ', 'Foreign'), ('응용프로그램', 'Noun'), ('개발', 'Noun'), ('(', 'Punctuation'), ('C', 'Alpha'), ('#,', 'Punctuation'), ('Java', 'Alpha'), (',', 'Punctuation'), ('ASP.NET', 'URL'), (',', 'Punctuation'), ('Web', 'Alpha'), ('등', 'Noun'), (')', 'Punctuation'), ('ㆍ', 'Foreign'), ('데이터베이스', 'Noun'), ('개발', 'Noun'), ('(', 'Punctuation'), ('Oralce', 'Alpha'), (',', 'Punctuation'), ('MSSQL', 'Alpha'), ('등', 'Noun'), (')', 'Punctuation'), ('우대', 'Noun'), ('사항', 'Noun'), ('ㆍ', 'Foreign'), ('컴퓨터', 'Noun'), ('/', 'Punctuation'), ('시스템', 'Noun'), ('공학', 'Noun'), (',', 'Punctuation'), ('공학', 'Noun'), ('계열', 'Noun'), (',', 'Punctuation'), ('수학', 'Noun'), ('/', 'Punctuation'), ('통계학', 'Noun'), ('ㆍ', 'Foreign'), ('TOEIC', 'Alpha'), ('00', 'Number'), ('급', 'Noun'), ('(', 'Punctuation'), ('점', 'Noun'), (')', 'Punctuation'), ('이상', 'Noun'), (',', 'Punctuation'), ('TOEFL', 'Alpha'), ('00', 'Number'), ('급', 'Noun'), ('(', 'Punctuation'), ('점', 'Noun'), (')', 'Punctuation'), ('이상', 'Noun'), ('ㆍ', 'Foreign'), ('정보처리기사', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('공통', 'Noun'), ('자격', 'Noun'), ('요건', 'Noun'), ('ㆍ', 'Foreign'), ('학력', 'Noun'), (':', 'Punctuation'), ('대졸', 'Noun'), ('이상', 'Noun'), ('(', 'Punctuation'), ('4년', 'Number'), (')(', 'Punctuation'), ('빅데이터', 'Noun'), ('/', 'Punctuation'), ('AI', 'Alpha'), ('(', 'Punctuation'), ('머신', 'Noun'), ('러닝', 'Noun'), ('딥', 'Noun'), ('러닝', 'Noun'), (')/', 'Punctuation'), ('파이썬', 'Noun'), ('/', 'Punctuation'), ('자바', 'Noun'), (')', 'Punctuation'), ('강사', 'Noun'), ('채용', 'Noun'), ('3', 'Number'), ('명담', 'Noun'), ('당', 'Modifier'), ('업무', 'Noun'), ('ㆍ', 'Foreign'), ('지원', 'Noun'), ('자격', 'Noun'), ('ㆍ', 'Foreign'), ('경력', 'Noun'), (':', 'Punctuation'), ('경력', 'Noun'), ('2년', 'Number'), ('이상', 'Noun'), ('\n            ', 'Foreign'), ('ㆍ', 'Foreign'), ('기타', 'Noun'), ('필수', 'Noun'), ('사항', 'Noun'), ('\n        ', 'Foreign'), ('우대', 'Noun'), ('사항', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('모집', 'Noun'), ('부문', 'Noun'), ('상', 'Suffix'), ('세', 'Modifier'), ('내용', 'Noun'), ('사업', 'Noun'), ('운영', 'Noun'), ('부', 'Noun'), ('[', 'Punctuation'), ('담당', 'Noun'), ('업무', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('부동산', 'Noun'), ('권리', 'Noun'), ('조사', 'Noun'), ('상품', 'Noun'), ('기획', 'Noun'), ('ㆍ', 'Foreign'), ('권리', 'Noun'), ('조사', 'Noun'), ('서비스', 'Noun'), ('운용', 'Noun'), ('및', 'Noun'), ('프로세스', 'Noun'), ('개선', 'Noun'), ('ㆍ', 'Foreign'), ('부동산', 'Noun'), ('권리', 'Noun'), ('조사', 'Noun'), ('사고', 'Noun'), ('원인', 'Noun'), ('추적', 'Noun'), ('및', 'Noun'), ('분석', 'Noun'), ('[', 'Punctuation'), ('자격', 'Noun'), ('요건', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('부동산', 'Noun'), ('권리', 'Noun'), ('조사', 'Noun'), ('상품', 'Noun'), ('및', 'Noun'), ('서비스', 'Noun'), ('기획', 'Noun'), ('경력', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('ㆍ', 'Foreign'), ('부동산', 'Noun'), ('권리', 'Noun'), ('조사', 'Noun'), ('업무', 'Noun'), ('수행', 'Noun'), ('경력', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('ㆍ', 'Foreign'), ('금융', 'Noun'), ('권', 'Suffix'), ('협업', 'Noun'), ('경험', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('[', 'Punctuation'), ('우대', 'Noun'), ('사항', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('관련', 'Noun'), ('직종', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), ('ㆍ', 'Foreign'), ('부동산', 'Noun'), ('관련', 'Noun'), ('전공자', 'Noun'), ('또는', 'Adverb'), ('관련', 'Noun'), ('자격증', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('법인', 'Noun'), ('영업', 'Noun'), ('부담', 'Noun'), ('당', 'Suffix'), ('업무', 'Noun'), ('ㆍ', 'Foreign'), ('[', 'Punctuation'), ('담당', 'Noun'), ('업무', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('전세', 'Noun'), ('대출', 'Noun'), ('관련', 'Noun'), ('금융', 'Noun'), ('권', 'Suffix'), ('B', 'Alpha'), ('2', 'Number'), ('B', 'Alpha'), ('영업', 'Noun'), ('ㆍ', 'Foreign'), ('시장', 'Noun'), ('동향', 'Noun'), ('파악', 'Noun'), (',', 'Punctuation'), ('상품', 'Noun'), ('제안', 'Noun'), (',', 'Punctuation'), ('입찰', 'Noun'), ('업무', 'Noun'), ('대응', 'Noun'), ('ㆍ', 'Foreign'), ('고객', 'Noun'), ('사별', 'Noun'), ('마케팅', 'Noun'), ('및', 'Noun'), ('신규', 'Noun'), ('거래처', 'Noun'), ('발굴', 'Noun'), ('[', 'Punctuation'), ('자격', 'Noun'), ('요건', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('부동산', 'Noun'), ('권리', 'Noun'), ('조사', 'Noun'), ('상품', 'Noun'), ('및', 'Noun'), ('서비스', 'Noun'), ('기획', 'Noun'), ('경력', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('ㆍ', 'Foreign'), ('금융', 'Noun'), ('권', 'Suffix'), ('법인', 'Noun'), ('영업', 'Noun'), ('경력', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('[', 'Punctuation'), ('우대', 'Noun'), ('사항', 'Noun'), (']', 'Punctuation'), ('ㆍ', 'Foreign'), ('관련', 'Noun'), ('직종', 'Noun'), ('경험', 'Noun'), ('자', 'Suffix'), ('ㆍ', 'Foreign'), ('부동산', 'Noun'), ('관련', 'Noun'), ('전공자', 'Noun'), ('또는', 'Adverb'), ('관련', 'Noun'), ('자격증', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('ㆍ', 'Foreign'), ('금융', 'Noun'), ('권', 'Suffix'), ('또는', 'Adverb'), ('금융', 'Noun'), ('권', 'Suffix'), ('영업', 'Noun'), ('경력', 'Noun'), ('보유', 'Noun'), ('자', 'Suffix'), ('\n            ', 'Foreign'), ('ㆍ', 'Foreign'), ('기타', 'Noun'), ('필수', 'Noun'), ('사항', 'Noun'), ('\n        ', 'Foreign'), ('우대', 'Noun'), ('사항', 'Noun')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('-', 'Punctuation')]
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [('DBA', 82), ('AI', 75), ('Python', 9), ('PM', 8), ('AWS', 8), ('CRM', 8), ('SQL', 7), ('B', 7), ('or', 7), ('Java', 6), ('R', 5), ('Tableau', 5), ('BI', 5), ('API', 5), ('DB', 4), ('UI', 4), ('UX', 4), ('Analytics', 3), ('IT', 3), ('js', 3), ('Spring', 3), ('C', 3), ('Time', 3), ('ERP', 2), ('Linux', 2), ('ADP', 2), ('m', 2), ('PR', 2), ('A', 2), ('RDBMS', 2), ('Node', 2), ('Hadoop', 2), ('Spark', 2), ('Django', 2), ('Docker', 2), ('Door', 2), ('Jenkins', 2), ('React', 2), ('HTML', 2), ('CSS', 2), ('Google', 2), ('O', 2), ('JQuery', 2), ('Vue', 2), ('JS', 2), ('Zingchart', 2), ('AM', 2), ('Vision', 2), ('Series', 2), ('NLP', 2)]
# {'DBA': 82, 'AI': 75, 'Python': 9, 'PM': 8, 'AWS': 8, 'CRM': 8, 'SQL': 7, 'Java': 6, 'R': 5, 'Tableau': 5, 'BI': 5, 'API': 5, 'DB': 4, 'UI': 4, 'UX': 4, 'Analytics': 3, 'IT': 3, 'js': 3, 'Spring': 3, 'C': 3, 'Time': 3, 'ERP': 2, 'Linux': 2, 'ADP': 2, 'm': 2, 'PR': 2, 'A': 2, 'RDBMS': 2, 'Node': 2, 'Hadoop': 2, 'Spark': 2, 'Django': 2, 'Docker': 2, 'Door': 2, 'Jenkins': 2, 'React': 2, 'HTML': 2, 'CSS': 2, 'Google': 2, 'O': 2, 'JQuery': 2, 'Vue': 2, 'JS': 2, 'Zingchart': 2, 'AM': 2, 'Vision': 2, 'Series': 2, 'NLP': 2}

# %% [markdown]
# ## 경력조건 비율 알아보기

# %%
AI_df["경력조건"].value_counts()
# Out:
# 무관                       92
# 경력 (최소 12개월 이상)          15
# 신입, 경력 (연수무관)            10
# 관계없음                     10
# 경력 (최소 3년 이상)             9
# 경력 (최소 5년 이상)             8
# 경력 (최소 1년 이상)             7
# 신입                        7
# 경력 (최소 7년 이상)             6
# 경력 (최소 2년 이상)             6
# 경력 (최소 1년 이상) 우대          4
# 경력 (최소 8년 이상)             4
# 경력 (최소 10년 이상)            3
# 신입, 경력 (최소 1년 이상)         2
# -                         2
# 경력 (최소 4년 이상)             2
# 신입/경력                     2
# 경력 (최소 5년 이상) 필수          1
# 경력 (최소 6년 이상)             1
# 경력                        1
# 경력 (최소 8년 이상) 필수          1
# 경력 (최소 3년 이상) 우대          1
# 경력 (최소 2년 이상) 필수          1
# 경력 (최소 2년 이상) 우대          1
# 경력 (최소 1년 이상) 필수          1
# 경력 (연수무관)                 1
# 신입, 경력 (최소 2년 이상)         1
# 신입, 경력 (최소 8년 3개월 이상)     1
# Name: 경력조건, dtype: int64

# %%
sum(list(AI_df["경력조건"].value_counts()))
# Out:
# 200

# %%
ratio = [(92+20), 200-112]
labels = ['신입/무관', '경력']

pie_graph(ratio, labels)

# %% [markdown]
# ## 학력 비율알아보기

# %%
AI_df["학력"].value_counts()
# Out:
# 학력무관                 104
# 대졸(4년)                51
# 석사                    17
# 대졸(2~3년)              11
# 고졸                     4
# -                      3
# 대졸(4년) ~ 박사            3
# 석사 ~ 박사                3
# 대졸(2~3년) ~ 대졸(4년)      1
# 대졸(2~3년) ~ 박사          1
# 대졸(4년) ~ 석사            1
# 박사                     1
# Name: 학력, dtype: int64

# %%
ratio = [104+4, (21+11+3), (17+10)]
labels = ['학력무관', '대졸(전문대 및 4년)', "석사 이상"]
pie_graph(ratio, labels)

# %%
AI_df["전공"].value_counts()
# Out:
# -                                                   191
# 정보·통신공학(학과 : 데이터정보학과) 통계학(학과 : 데이터경영학과)               1
# 연극·영화(학과 : 영화(편집)) 전산학·컴퓨터공학(학과 : 영화영상ㆍ멀티미디어공학부)      1
# 전산학·컴퓨터공학(학과 : 컴퓨터공학과군)                               1
# 전산학·컴퓨터공학(학과 : 전산학전공) 전자공학(학과 : 전기전자및컴퓨터공학부)          1
# 전산학·컴퓨터공학(학과 : 정보전산학과)                                1
# 전산학·컴퓨터공학(학과 : IT정보공학부(컴퓨터시스템공학,소프트웨어공학))             1
# 전산학·컴퓨터공학(학과 : 컴퓨터과학과) 응용 소프트웨어 공학(학과 : 소프트웨어학과)      1
# 통계학(학과 : 통계정보학과) 전산학·컴퓨터공학(학과 : 정보·경영대학 컴퓨터학과)        1
# 전산학·컴퓨터공학(학과 : 컴퓨터공학과) 전산학·컴퓨터공학(학과 : 인공지능전공)         1
# Name: 전공, dtype: int64

# %% [markdown]
# <hr><hr><hr><hr><hr><hr><hr>
